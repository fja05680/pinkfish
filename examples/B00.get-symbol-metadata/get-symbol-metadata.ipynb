# %% [markdown]
# # Get Symbol Metadata
#
# A useful utility for demonstating the use of the get_symbol_metadata function.  Use this notebook to get the start date, end date and how many years of timeseries for all the symbols in your data cache.

# %%
import pandas as pd
import pinkfish as pf

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# increase display of dataframe rows
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# Get metadata for the symbols below.
# Time series will be fetched for any symbols not already cached.

# %%
df = pf.get_symbol_metadata(symbols=['msft', 'orcl', 'tsla'])
df.sort_values('num_years', ascending=False).reset_index(drop=True)
# Out:
#   symbol  start_date    end_date  num_years
# 0   ORCL  1986-03-12  2023-12-28      37.80
# 1   MSFT  1986-03-13  2023-12-28      37.79
# 2   TSLA  2010-06-29  2023-12-28      13.50

# %% [markdown]
# Get metadata for all symbols in the cache directory

# %%
df = pf.get_symbol_metadata(dir_name='data')
df.sort_values('num_years', ascending=False).reset_index(drop=True)
# Out:
#      symbol  start_date    end_date  num_years
# 0     ^GSPC  1927-12-30  2023-12-28      96.00
# 1      ORCL  1986-03-12  2023-12-28      37.80
# 2      MSFT  1986-03-13  2023-12-28      37.79
# 3       SPY  1993-01-29  2023-12-28      30.91
# 4       NLY  1997-10-08  2023-12-28      26.22
# 5       XLY  1998-12-22  2023-12-28      25.02
# 6       XLI  1998-12-22  2023-12-28      25.02
# 7       XLK  1998-12-22  2023-12-28      25.02
# 8       XLV  1998-12-22  2023-12-28      25.02
# 9       XLE  1998-12-22  2023-12-28      25.02
# 10      XLU  1998-12-22  2023-12-28      25.02
# 11      XLP  1998-12-22  2023-12-28      25.02
# 12      XLB  1998-12-22  2023-12-28      25.02
# 13      XLF  1998-12-22  2023-12-28      25.02
# 14      QQQ  1999-03-10  2023-12-28      24.80
# 15      IYR  2000-06-19  2023-12-28      23.52
# 16     CL=F  2000-08-23  2023-12-28      23.35
# 17     GC=F  2000-08-30  2023-12-28      23.33
# 18     ES=F  2000-09-18  2023-12-28      23.27
# 19      IEF  2002-07-30  2023-12-28      21.41
# 20      TLT  2002-07-30  2023-12-28      21.41
# 21      LQD  2002-07-30  2023-12-28      21.41
# 22      EEM  2003-04-14  2023-12-28      20.71
# 23      AGG  2003-09-29  2023-12-28      20.25
# 24      TIP  2003-12-05  2023-12-28      20.06
# 25      VNQ  2004-09-29  2023-12-28      19.24
# 26      GLD  2004-11-18  2023-12-28      19.11
# 27      DBC  2006-02-06  2023-12-28      17.89
# 28      VEU  2007-03-08  2023-12-28      16.81
# 29      PFF  2007-03-30  2023-12-28      16.75
# 30      BSV  2007-04-10  2023-12-28      16.72
# 31      BIL  2007-05-30  2023-12-28      16.58
# 32      JNK  2007-12-04  2023-12-28      16.07
# 33      PGX  2008-01-31  2023-12-28      15.91
# 34     ACWI  2008-03-28  2023-12-28      15.75
# 35      SLY  2008-01-02  2023-06-09      15.43
# 36     TSLA  2010-06-29  2023-12-28      13.50
# 37     BOND  2012-03-01  2023-12-28      11.83
# 38  BTC-USD  2014-09-17  2023-12-29       9.28
