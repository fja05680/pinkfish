# %% [markdown]
# # Get Symbol Metadata
#
# A useful utility for demonstating the use of the get_symbol_metadata function.  Use this notebook to get the start date, end date and how many years of timeseries for all the symbols in your data cache.

# %%
import pandas as pd
import pinkfish as pf

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# increase display of dataframe rows
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# Get metadata for the symbols below.
# Time series will be fetched for any symbols not already cached.

# %%
df = pf.get_symbol_metadata(symbols=['msft', 'orcl', 'tsla'])
df.sort_values('num_years', ascending=False).reset_index(drop=True)
# Out:
#   symbol  start_date    end_date  num_years
# 0   ORCL  1986-03-12  2023-08-01      37.39
# 1   MSFT  1986-03-13  2023-08-01      37.39
# 2   TSLA  2010-06-29  2023-08-01      13.09

# %% [markdown]
# Get metadata for all symbols in the cache directory

# %%
df = pf.get_symbol_metadata(dir_name='data')
df.sort_values('num_years', ascending=False).reset_index(drop=True)
# Out:
#      symbol  start_date    end_date  num_years
# 0     ^GSPC  1927-12-30  2023-08-01      95.59
# 1      ORCL  1986-03-12  2023-08-01      37.39
# 2      MSFT  1986-03-13  2023-08-01      37.39
# 3       SPY  1993-01-29  2023-08-01      30.50
# 4       NLY  1997-10-08  2023-08-01      25.81
# 5       XLE  1998-12-22  2023-08-01      24.61
# 6       XLI  1998-12-22  2023-08-01      24.61
# 7       XLY  1998-12-22  2023-08-01      24.61
# 8       XLU  1998-12-22  2023-08-01      24.61
# 9       XLF  1998-12-22  2023-08-01      24.61
# 10      XLP  1998-12-22  2023-08-01      24.61
# 11      XLV  1998-12-22  2023-08-01      24.61
# 12      XLB  1998-12-22  2023-08-01      24.61
# 13      XLK  1998-12-22  2023-08-01      24.61
# 14      QQQ  1999-03-10  2023-08-01      24.39
# 15      IYR  2000-06-19  2023-08-01      23.12
# 16      IEF  2002-07-30  2023-08-01      21.01
# 17      TLT  2002-07-30  2023-08-01      21.01
# 18      LQD  2002-07-30  2023-08-01      21.01
# 19      EEM  2003-04-14  2023-08-01      20.30
# 20      AGG  2003-09-29  2023-08-01      19.84
# 21      TIP  2003-12-05  2023-08-01      19.66
# 22      VNQ  2004-09-29  2023-08-01      18.84
# 23      GLD  2004-11-18  2023-08-01      18.70
# 24      DBC  2006-02-06  2023-08-01      17.48
# 25      VEU  2007-03-08  2023-08-01      16.40
# 26      PFF  2007-03-30  2023-08-01      16.34
# 27      BSV  2007-04-10  2023-08-01      16.31
# 28      BIL  2007-05-30  2023-08-01      16.17
# 29      JNK  2007-12-04  2023-08-01      15.66
# 30      PGX  2008-01-31  2023-08-01      15.50
# 31      SLY  2008-01-02  2023-06-09      15.43
# 32     ACWI  2008-03-28  2023-08-01      15.34
# 33     TSLA  2010-06-29  2023-08-01      13.09
# 34     BOND  2012-03-01  2023-08-01      11.42
# 35  BTC-USD  2014-09-17  2023-08-02       8.87
