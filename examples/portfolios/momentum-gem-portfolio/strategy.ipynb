# %% [markdown]
# # Global Equities Momentum (GEM)
#
# Gary Antonacci’s Dual Momentum approach is simple: by combining both relative momentum and absolute momentum (i.e. trend following), Dual Momentum seeks to rotate into areas of relative strength while preserving the flexibility to shift entirely to safety assets (e.g. short-term U.S. Treasury bills) during periods of pervasive, negative trends.
#
# Antonacci’s Global Equities Momentum (GEM) portfolio builds a portfolio with three assets: U.S. stocks, international stocks and U.S. bonds. For the retail investor he recommends using low-cost ETFs: for example, VOO for U.S. stocks; VEU for non-U.S. stocks and AGG for U.S. aggregate bonds.  Compare against a global equities benchmark like the ACWI ETF.
#
# Antonacci named his system “Dual Momentum” because he uses both relative momentum (the measure of the performance of an asset relative to another asset) and absolute momentum ( the measure of performance relative to the risk-free rate – absolute excess return.)  To keep the process very simple to implement, he used a 12-month look-back period and an easy to execute buy and sell system.
#
# Every month the investor places all funds in the equity ETF that has the best 12-month performance relative to the other equity ETFs, unless the absolute performance is worse than the return of six-month U.S. Treasuries (as measured by BIL ETF).  If absolute performance is below the BIL ETF, then the investor places all funds in AGG, the aggregate bond index.
#
# https://www.theemergingmarketsinvestor.com/using-momentum-in-emerging-markets/
# https://blog.thinknewfound.com/2019/01/fragility-case-study-dual-momentum-gem/
# https://seekingalpha.com/article/4010394-prospecting-dual-momentum-gem
#
#
# ![](GEM-rules2.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

import pinkfish as pf
import strategy

# Format price data.
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

pd. set_option('display.max_rows', None)

# %%
# Set size of inline plots.
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
symbols = {'US STOCKS' : 'SPY',  'US BONDS' : 'AGG', 'EX-US STOCKS' : 'VEU', 'T-BILL': 'BIL'}

capital = 10000
start = datetime.datetime(1900, 1, 1)
#start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()
end = datetime.datetime(2018, 1, 1)

# %%
options = {
    'use_adj' : True,
    'use_cache' : True,
    'lookback': 12,
    'margin': 1,
}
options
# Out:
# {'use_adj': True, 'use_cache': True, 'lookback': 12, 'margin': 1}

# %% [markdown]
# Run Strategy

# %%
s = strategy.Strategy(symbols, capital, start, end, options)
s.run()

# %% [markdown]
# View logs

# %%
s.rlog.head(100)
# Out:
#          date  seq_num  price  shares entry_exit direction symbol
# 0  2008-11-03        0  56.63     176      entry      LONG    AGG
# 1  2009-10-01        1  65.53     176       exit      LONG    AGG
# 0  2009-10-01        2  25.42     455      entry      LONG    VEU
# 1  2010-05-03        3  27.17     455       exit      LONG    VEU
# 0  2010-05-03        4  90.42     136      entry      LONG    SPY
# 1  2011-02-01        5  99.74     136       exit      LONG    SPY
# 2  2011-02-01        6  31.08     438      entry      LONG    VEU
# 3  2011-03-01        7  30.85     438       exit      LONG    VEU
# 2  2011-03-01        8  99.89     135      entry      LONG    SPY
# 3  2011-04-01        9 102.02     135       exit      LONG    SPY
# 4  2011-04-01       10  31.52     438      entry      LONG    VEU
# 5  2011-07-01       11  31.80     438       exit      LONG    VEU
# 4  2011-07-01       12 103.12     135      entry      LONG    SPY
# 5  2011-10-03       13  85.09     135       exit      LONG    SPY
# 2  2011-10-03       14  74.04     155      entry      LONG    AGG
# 3  2011-11-01       15  74.19     155       exit      LONG    AGG
# 6  2011-11-01       16  94.43     122      entry      LONG    SPY
# 7  2013-01-02       17 116.29     122       exit      LONG    SPY
# 6  2013-01-02       18  31.33     453      entry      LONG    VEU
# 7  2013-02-01       19  31.85     453       exit      LONG    VEU
# 8  2013-02-01       20 120.42     119      entry      LONG    SPY
# 9  2013-05-01       21 126.58     119       exit      LONG    SPY
# 8  2013-05-01       22  32.23     470      entry      LONG    VEU
# 9  2013-06-03       23  31.65     470       exit      LONG    VEU
# 10 2013-06-03       24 131.44     113      entry      LONG    SPY
# 11 2015-09-01       25 160.30     113       exit      LONG    SPY
# 4  2015-09-01       26  80.80     224      entry      LONG    AGG
# 5  2015-10-01       27  81.28     224       exit      LONG    AGG
# 12 2015-10-01       28 161.43     113      entry      LONG    SPY
# 13 2016-02-01       29 163.68     113       exit      LONG    SPY
# 6  2016-02-01       30  81.70     226      entry      LONG    AGG
# 7  2016-04-01       31  83.17     226       exit      LONG    AGG
# 14 2016-04-01       32 175.80     107      entry      LONG    SPY
# 15 2016-05-02       33 176.69     107       exit      LONG    SPY
# 8  2016-05-02       34  83.40     227      entry      LONG    AGG
# 9  2016-06-01       35  83.42     227       exit      LONG    AGG
# 16 2016-06-01       36 178.64     106      entry      LONG    SPY
# 17 2017-06-01       37 211.03     106       exit      LONG    SPY
# 10 2017-06-01       38  38.60     580      entry      LONG    VEU
# 11 2017-12-29       39  42.75     580       exit      LONG    VEU

# %%
s.tlog.tail()
# Out:
#   entry_date  entry_price  exit_date  exit_price  pl_points  pl_cash  qty  \
# 3 2016-02-01        81.70 2016-04-01       83.17       1.47   332.82  226
# 7 2016-04-01       175.80 2016-05-02      176.69       0.89    95.46  107
# 4 2016-05-02        83.40 2016-06-01       83.42       0.02     4.76  227
# 8 2016-06-01       178.64 2017-06-01      211.03      32.38  3432.62  106
# 5 2017-06-01        38.60 2017-12-29       42.75       4.15  2405.92  580
#
#    cumul_total direction symbol
# 3      8856.74      LONG    AGG
# 7      8952.20      LONG    SPY
# 4      8956.96      LONG    AGG
# 8     12389.57      LONG    SPY
# 5     14795.49      LONG    VEU

# %%
s.dbal.tail()
# Out:
#                high      low    close  shares     cash  leverage state
# date
# 2017-12-22 24636.91 24636.91 24636.91     580     1.68      1.00     -
# 2017-12-26 24641.44 24641.44 24641.44     580     1.68      1.00     -
# 2017-12-27 24695.81 24695.81 24695.81     580     1.68      1.00     -
# 2017-12-28 24763.78 24763.78 24763.78     580     1.68      1.00     -
# 2017-12-29 24795.49 24795.49 24795.49       0 24795.49      1.00     X

# %% [markdown]
# Generate strategy stats - display all available stats

# %%
pf.print_full(s.stats)
# Out:
# start                                                  2008-10-30
# end                                                    2017-12-29
# beginning_balance                                           10000
# ending_balance                                           24795.49
# total_net_profit                                         14795.49
# gross_profit                                             17599.86
# gross_loss                                               -2804.37
# profit_factor                                                6.28
# return_on_initial_capital                                  147.95
# annual_return_rate                                          10.42
# trading_period                           9 years 1 months 29 days
# pct_time_in_market                                          99.91
# margin                                                          1
# avg_leverage                                                 1.00
# max_leverage                                                 1.00
# min_leverage                                                 1.00
# total_num_trades                                               20
# trades_per_year                                              2.18
# num_winning_trades                                             17
# num_losing_trades                                               3
# num_even_trades                                                 0
# pct_profitable_trades                                       85.00
# avg_profit_per_trade                                       739.77
# avg_profit_per_winning_trade                              1035.29
# avg_loss_per_losing_trade                                 -934.79
# ratio_avg_profit_win_loss                                    1.11
# largest_profit_winning_trade                              3432.62
# largest_loss_losing_trade                                -2434.72
# num_winning_points                                         121.59
# num_losing_points                                          -18.84
# total_net_points                                           102.76
# avg_points                                                   5.14
# largest_points_winning_trade                                32.38
# largest_points_losing_trade                                -18.03
# avg_pct_gain_per_trade                                       5.06
# largest_pct_winning_trade                                   23.15
# largest_pct_losing_trade                                   -17.49
# expected_shortfall                                              0
# max_consecutive_winning_trades                                  8
# max_consecutive_losing_trades                                   1
# avg_bars_winning_trades                                    130.41
# avg_bars_losing_trades                                      36.00
# max_closed_out_drawdown                                    -23.67
# max_closed_out_drawdown_peak_date                      2011-04-29
# max_closed_out_drawdown_trough_date                    2011-11-25
# max_closed_out_drawdown_recovery_date                  2013-02-01
# drawdown_loss_period                                          210
# drawdown_recovery_period                                      434
# annualized_return_over_max_drawdown                          0.44
# max_intra_day_drawdown                                     -23.67
# avg_yearly_closed_out_drawdown                             -10.48
# max_yearly_closed_out_drawdown                             -23.67
# avg_monthly_closed_out_drawdown                             -3.05
# max_monthly_closed_out_drawdown                            -16.56
# avg_weekly_closed_out_drawdown                              -1.23
# max_weekly_closed_out_drawdown                             -12.81
# avg_yearly_closed_out_runup                                 19.60
# max_yearly_closed_out_runup                                 36.47
# avg_monthly_closed_out_runup                                 3.85
# max_monthly_closed_out_runup                                10.27
# avg_weekly_closed_out_runup                                  1.45
# max_weekly_closed_out_runup                                  7.64
# pct_profitable_years                                        78.55
# best_year                                                   32.07
# worst_year                                                 -11.94
# avg_year                                                     9.57
# annual_std                                                   9.30
# pct_profitable_months                                       66.83
# best_month                                                  10.27
# worst_month                                                -16.28
# avg_month                                                    0.82
# monthly_std                                                  3.43
# pct_profitable_weeks                                        60.27
# best_week                                                    7.64
# worst_week                                                 -12.81
# avg_week                                                     0.21
# weekly_std                                                   1.91
# pct_profitable_days                                         53.97
# best_day                                                     4.64
# worst_day                                                   -6.50
# avg_day                                                      0.04
# daily_std                                                    0.90
# sharpe_ratio                                                 0.76
# sharpe_ratio_max                                             0.84
# sharpe_ratio_min                                             0.69
# sortino_ratio                                                0.96
# dtype: object

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats

# %%
benchmark = pf.Benchmark('ACWI', s.capital, s.start, s.end, use_adj=True)
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                      10.42      11.10
# max_closed_out_drawdown                -23.67     -32.16
# annualized_return_over_max_drawdown      0.44       0.34
# best_month                              10.27      25.75
# worst_month                            -16.28     -21.44
# sharpe_ratio                             0.76       0.63
# sortino_ratio                            0.96       0.79
# monthly_std                              3.43       4.54
# annual_std                               9.30      13.48
