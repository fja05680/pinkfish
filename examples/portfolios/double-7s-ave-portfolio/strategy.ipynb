# %% [markdown]
# # Double 7's Average Portfolio (Short Term Trading Strategies that Work)
#
#     1. The Security is above its 200-day moving average or X-day ma
#     2. The Security closes at a X-day low, buy.
#     3. If the Security closes at a X-day high, sell your long position.
#
#     Instead of using a single period like 7 and allocating all of the capital to it,
#     the capital is split between the number of periods that will be used,
#     for example [5, 6, 7] = 33% each).

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd

import pinkfish as pf
import strategy

# Format price data.
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# Set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
# Symbol Lists
symbol = 'SPY'
capital = 10000
start = datetime.datetime(*pf.ALPHA_BEGIN)
#start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()

# %%
options = {
    'use_adj' : False,
    'use_cache' : True,
    'margin' : 2.0,
    'periods' : [5,6,7,8,9],
    'sma' : 70,
    'use_regime_filter' : True,
}

# %% [markdown]
# Run Strategy

# %%
s = strategy.Strategy(symbol, capital, start, end, options=options)
s.run()

# %%
s.ts
# Out:
#             SPY_8_close  SPY_5_close  SPY_9_close  SPY_6_close  SPY_7_close  \
# date
# 1993-11-11        46.38        46.38        46.38        46.38        46.38
# 1993-11-12        46.59        46.59        46.59        46.59        46.59
# 1993-11-15        46.56        46.56        46.56        46.56        46.56
# 1993-11-16        46.78        46.78        46.78        46.78        46.78
# 1993-11-17        46.53        46.53        46.53        46.53        46.53
# ...                 ...          ...          ...          ...          ...
# 2026-06-08       739.22       739.22       739.22       739.22       739.22
# 2026-06-09       737.05       737.05       737.05       737.05       737.05
# 2026-06-10       725.43       725.43       725.43       725.43       725.43
# 2026-06-11       737.76       737.76       737.76       737.76       737.76
# 2026-06-12       741.75       741.75       741.75       741.75       741.75
#
#             regime    sma  period_high5  period_low5  period_high6  \
# date
# 1993-11-11    1.00  46.11         46.50        46.06         46.50
# 1993-11-12    2.00  46.13         46.59        46.12         46.59
# 1993-11-15    3.00  46.16         46.59        46.16         46.59
# 1993-11-16    4.00  46.18         46.78        46.38         46.78
# 1993-11-17    5.00  46.20         46.78        46.38         46.78
# ...            ...    ...           ...          ...           ...
# 2026-06-08   43.00 702.02        759.57       737.55        759.57
# 2026-06-09   44.00 702.75        757.09       737.05        759.57
# 2026-06-10   45.00 703.31        757.09       725.43        757.09
# 2026-06-11   46.00 704.13        739.22       725.43        757.09
# 2026-06-12   47.00 704.94        741.75       725.43        741.75
#
#             period_low6  period_high7  period_low7  period_high8  period_low8  \
# date
# 1993-11-11        45.84         46.50        45.84         46.94        45.84
# 1993-11-12        46.06         46.59        45.84         46.59        45.84
# 1993-11-15        46.12         46.59        46.06         46.59        45.84
# 1993-11-16        46.16         46.78        46.12         46.78        46.06
# 1993-11-17        46.38         46.78        46.16         46.78        46.12
# ...                 ...           ...          ...           ...          ...
# 2026-06-08       737.55        759.57       737.55        759.57       737.55
# 2026-06-09       737.05        759.57       737.05        759.57       737.05
# 2026-06-10       725.43        759.57       725.43        759.57       725.43
# 2026-06-11       725.43        757.09       725.43        759.57       725.43
# 2026-06-12       725.43        757.09       725.43        757.09       725.43
#
#             period_high9  period_low9
# date
# 1993-11-11         46.97        45.84
# 1993-11-12         46.94        45.84
# 1993-11-15         46.59        45.84
# 1993-11-16         46.78        45.84
# 1993-11-17         46.78        46.06
# ...                  ...          ...
# 2026-06-08        759.57       737.55
# 2026-06-09        759.57       737.05
# 2026-06-10        759.57       725.43
# 2026-06-11        759.57       725.43
# 2026-06-12        759.57       725.43
#
# [8201 rows x 17 columns]

# %% [markdown]
# View log DataFrames: raw trade log, trade log, and daily balance

# %%
s.rlog.head()
# Out:
#         date  seq_num  price  shares entry_exit direction symbol
# 0 1993-11-18        0  46.41      86      entry      LONG  SPY_5
# 0 1993-11-19        1  46.31      86      entry      LONG  SPY_8
# 0 1993-11-19        2  46.31      86      entry      LONG  SPY_6
# 0 1993-11-19        3  46.31      86      entry      LONG  SPY_7
# 0 1993-11-22        4  46.03      85      entry      LONG  SPY_9

# %%
s.tlog.tail()
# Out:
#     entry_date  entry_price  exit_date  exit_price  pl_points  pl_cash  qty  \
# 514 2026-06-03       754.24 2026-06-12      741.75     -12.49 -6045.16  484
# 299 2026-06-05       737.55 2026-06-12      741.75       4.20  2062.21  491
# 254 2026-06-05       737.55 2026-06-12      741.75       4.20  2062.21  491
# 424 2026-06-05       737.55 2026-06-12      741.75       4.20  2062.21  491
# 349 2026-06-05       737.55 2026-06-12      741.75       4.20  2062.21  491
#
#      cumul_total direction symbol
# 514    897534.51      LONG  SPY_5
# 299    899596.72      LONG  SPY_8
# 254    901658.92      LONG  SPY_9
# 424    903721.13      LONG  SPY_6
# 349    905783.34      LONG  SPY_7

# %%
s.dbal.tail()
# Out:
#                 high       low     close  shares       cash  leverage state
# date
# 2026-06-08 909589.82 909589.82 909589.82    2448 -900020.66      1.99     -
# 2026-06-09 904277.71 904277.71 904277.71    2448 -900020.66      2.00     -
# 2026-06-10 875831.96 875831.96 875831.96    2448 -900020.66      2.03     -
# 2026-06-11 906015.84 906015.84 906015.84    2448 -900020.66      1.99     -
# 2026-06-12 915783.34 915783.34 915783.34       0  915783.34      1.00     X

# %% [markdown]
# Generate strategy stats - display all available stats

# %%
pf.print_full(s.stats)
# Out:
# start                                                  1993-11-11
# end                                                    2026-06-12
# beginning_balance                                           10000
# ending_balance                                          915783.34
# total_net_profit                                        905783.34
# gross_profit                                           1861015.54
# gross_loss                                             -955232.20
# profit_factor                                                1.95
# return_on_initial_capital                                 9057.83
# annual_return_rate                                          14.87
# trading_period                           32 years 7 months 1 days
# pct_time_in_market                                          43.45
# margin                                                       2.00
# avg_leverage                                                 1.25
# max_leverage                                                 2.39
# min_leverage                                                 1.00
# total_num_trades                                             1845
# trades_per_year                                             56.62
# num_winning_trades                                           1417
# num_losing_trades                                             422
# num_even_trades                                                 6
# pct_profitable_trades                                       76.80
# avg_profit_per_trade                                       490.94
# avg_profit_per_winning_trade                              1313.35
# avg_loss_per_losing_trade                                -2263.58
# ratio_avg_profit_win_loss                                    0.58
# largest_profit_winning_trade                              9609.58
# largest_loss_losing_trade                               -43512.56
# num_winning_points                                        4268.35
# num_losing_points                                        -1996.40
# total_net_points                                          2271.95
# avg_points                                                   1.23
# largest_points_winning_trade                                22.40
# largest_points_losing_trade                                -72.28
# avg_pct_gain_per_trade                                       0.66
# largest_pct_winning_trade                                    6.92
# largest_pct_losing_trade                                   -21.67
# expected_shortfall                                          -8.39
# max_consecutive_winning_trades                                 55
# max_consecutive_losing_trades                                  10
# avg_bars_winning_trades                                      6.25
# avg_bars_losing_trades                                      14.15
# max_closed_out_drawdown                                    -33.92
# max_closed_out_drawdown_peak_date                      2020-02-05
# max_closed_out_drawdown_trough_date                    2020-03-23
# max_closed_out_drawdown_recovery_date                  2021-05-24
# drawdown_loss_period                                           47
# drawdown_recovery_period                                      427
# annualized_return_over_max_drawdown                          0.44
# max_intra_day_drawdown                                     -33.92
# avg_yearly_closed_out_drawdown                             -13.17
# max_yearly_closed_out_drawdown                             -33.92
# avg_monthly_closed_out_drawdown                             -3.14
# max_monthly_closed_out_drawdown                            -32.52
# avg_weekly_closed_out_drawdown                              -1.06
# max_weekly_closed_out_drawdown                             -25.99
# avg_yearly_closed_out_runup                                 27.62
# max_yearly_closed_out_runup                                 75.70
# avg_monthly_closed_out_runup                                 4.17
# max_monthly_closed_out_runup                                23.98
# avg_weekly_closed_out_runup                                  1.39
# max_weekly_closed_out_runup                                 16.91
# pct_profitable_years                                        85.39
# best_year                                                   75.70
# worst_year                                                 -25.93
# avg_year                                                    16.03
# annual_std                                                  16.43
# pct_profitable_months                                       65.41
# best_month                                                  23.98
# worst_month                                                -32.52
# avg_month                                                    1.19
# monthly_std                                                  4.07
# pct_profitable_weeks                                        42.81
# best_week                                                   16.91
# worst_week                                                 -25.99
# avg_week                                                     0.30
# weekly_std                                                   2.39
# pct_profitable_days                                         24.46
# best_day                                                    12.49
# worst_day                                                  -14.47
# avg_day                                                      0.06
# daily_std                                                    1.24
# sharpe_ratio                                                 0.81
# sharpe_ratio_max                                             0.84
# sharpe_ratio_min                                             0.77
# sortino_ratio                                                0.67
# dtype: object

# %% [markdown]
# View Performance by Symbol

# %%
weights = {symbol: 1 / len(s.symbols) for symbol in s.symbols}
totals = s.portfolio.performance_per_symbol(weights=weights)
totals
# Out:
#        cumul_total  weight  pct_cumul_total  relative_performance
# SPY_8  $156,383.28    0.20             0.17                  0.86
# SPY_5  $191,944.37    0.20             0.21                  1.06
# SPY_9  $171,438.64    0.20             0.19                  0.95
# SPY_6  $198,826.88    0.20             0.22                  1.10
# SPY_7  $187,190.16    0.20             0.21                  1.03
# TOTAL  $905,783.34    1.00             1.00                  1.00

# %%
corr_df = s.portfolio.correlation_map(s.ts)
corr_df
# Out:
#        SPY_8  SPY_5  SPY_9  SPY_6  SPY_7
# SPY_8   1.00   1.00   1.00   1.00   1.00
# SPY_5   1.00   1.00   1.00   1.00   1.00
# SPY_9   1.00   1.00   1.00   1.00   1.00
# SPY_6   1.00   1.00   1.00   1.00   1.00
# SPY_7   1.00   1.00   1.00   1.00   1.00

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats

# %%
benchmark = pf.Benchmark(symbol, s.capital, s.start, s.end, use_adj=True)
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                      14.87      10.83
# max_closed_out_drawdown                -33.92     -55.16
# annualized_return_over_max_drawdown      0.44       0.20
# best_month                              23.98      23.59
# worst_month                            -32.52     -30.98
# sharpe_ratio                             0.81       0.64
# sortino_ratio                            0.67       0.82
# monthly_std                              4.07       4.48
# annual_std                              16.43      16.92

# %% [markdown]
# Analysis: Kelly Criterian

# %%
kelly = pf.kelly_criterion(s.stats, benchmark.stats)
kelly
# Out:
# sharpe_ratio            0.81
# sharpe_ratio_max        0.84
# sharpe_ratio_min        0.77
# strategy risk           0.16
# instrument risk         0.17
# optimal target risk     0.81
# half kelly criterion    0.40
# aggressive leverage     4.76
# moderate leverage       2.38
# conservative leverage   2.27
# dtype: float64
