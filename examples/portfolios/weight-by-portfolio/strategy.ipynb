# %% [markdown]
# # Weight By Portfolio Strategy
#
# Basic buy and hold that allows weighting by user specified weights, Equal, Sharpe Ratio, Annual Returns, Std Dev, Vola, or DS Vola.
#
# Rebalance is yearly, monthly, weekly, or daily.  Option to sell all shares of an investment is regime turns negative.

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd

import pinkfish as pf
import strategy

# Format price data.
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# Set size of inline plots.
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
# Symbol Lists.
SP500_Sectors = \
    {'XLB': None, 'XLE': None, 'XLF': None, 'XLI': None,
     'XLK': None, 'XLP': None, 'XLU': None, 'XLV': None, 'XLY': None}

Mixed_Asset_Classes = \
    {'IWB': None, 'SPY': None, 'VGK': None, 'IEV': None,
     'EWJ': None, 'EPP': None, 'IEF': None, 'SHY': None, 'GLD': None}
FANG_Stocks = \
    {'FB': None, 'AMZN': None, 'NFLX': None, 'GOOG': None}

Stocks_Bonds_Gold = \
    {'SPY': None, 'QQQ': None, 'TLT': None, 'GLD': None}

Stocks_Bonds = \
    {'SPY': 0.50, 'AGG': 0.50}

# Pick one of the above.
weights = Stocks_Bonds_Gold
symbols = list(weights)

capital = 100_000
start = datetime.datetime(*pf.ALPHA_BEGIN)
#start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()

# %%
weight_by_choices = ('equal', 'sharpe', 'ret', 'sd', 'vola', 'ds_vola')
rebalance_choices = ('yearly', 'monthly', 'weekly', 'daily')

options = {
    'use_adj'           : True,
    'use_cache'         : True,
    'margin'            : 1,
    'weights'           : weights,
    'weight_by'         : 'vola',
    'rebalance'         : 'monthly',
    'use_regime_filter' : False
}

# %% [markdown]
# Run Strategy

# %%
s = strategy.Strategy(symbols, capital, start, end, options=options)
s.run()
# Out:
# 2007-11-20 GLD:14.9 QQQ:14.7 SPY:20.1 TLT:50.0 cash:  0.1 total: 100.0
# 2007-12-03 GLD:14.5 QQQ:14.8 SPY:19.4 TLT:46.6 cash:  4.6 total: 100.0
# 2008-01-02 GLD:20.2 QQQ:14.6 SPY:19.0 TLT:28.3 cash: 18.0 total: 100.0
# 2008-02-01 GLD:24.8 QQQ:18.1 SPY:21.7 TLT:35.2 cash:  0.2 total: 100.0
# 2008-03-03 GLD:24.6 QQQ:19.7 SPY:20.8 TLT:26.8 cash:  8.1 total: 100.0
# 2008-04-01 GLD:21.4 QQQ:18.8 SPY:21.8 TLT:37.9 cash:  0.0 total: 100.0
# 2008-05-01 GLD:18.3 QQQ:16.7 SPY:25.6 TLT:39.3 cash:  0.0 total: 100.0
# 2008-06-02 GLD:15.9 QQQ:20.3 SPY:25.3 TLT:36.0 cash:  2.6 total: 100.0
# 2008-07-01 GLD:17.9 QQQ:16.3 SPY:22.9 TLT:42.8 cash:  0.2 total: 100.0
# 2008-08-01 GLD:17.6 QQQ:16.2 SPY:20.8 TLT:36.9 cash:  8.5 total: 100.0
# 2008-09-02 GLD:15.5 QQQ:19.9 SPY:22.4 TLT:42.2 cash:  0.1 total: 100.0
# 2008-10-01 GLD:17.3 QQQ:17.4 SPY:20.1 TLT:41.2 cash:  3.9 total: 100.0
# 2008-11-03 GLD:19.5 QQQ:10.8 SPY: 9.5 TLT:60.1 cash:  0.0 total: 100.0
# 2008-12-01 GLD:19.1 QQQ: 8.2 SPY: 7.4 TLT:40.6 cash: 24.8 total: 100.0
# 2009-01-02 GLD:28.2 QQQ:19.0 SPY:12.6 TLT:31.1 cash:  9.1 total: 100.0
# 2009-02-02 GLD:23.4 QQQ:22.0 SPY:21.8 TLT:32.6 cash:  0.2 total: 100.0
# 2009-03-02 GLD:25.4 QQQ:21.0 SPY:19.7 TLT:30.6 cash:  3.2 total: 100.0
# 2009-04-01 GLD:27.5 QQQ:18.7 SPY:17.2 TLT:35.1 cash:  1.6 total: 100.0
# 2009-05-01 GLD:25.1 QQQ:20.7 SPY:18.4 TLT:35.8 cash:  0.0 total: 100.0
# 2009-06-01 GLD:26.8 QQQ:20.5 SPY:19.1 TLT:23.1 cash: 10.5 total: 100.0
# 2009-07-01 GLD:26.0 QQQ:24.5 SPY:24.4 TLT:25.0 cash:  0.1 total: 100.0
# 2009-08-03 GLD:25.4 QQQ:23.8 SPY:25.3 TLT:19.9 cash:  5.7 total: 100.0
# 2009-09-01 GLD:31.4 QQQ:21.4 SPY:22.4 TLT:24.1 cash:  0.8 total: 100.0
# 2009-10-01 GLD:27.4 QQQ:22.0 SPY:23.8 TLT:26.7 cash:  0.2 total: 100.0
# 2009-11-02 GLD:26.3 QQQ:24.3 SPY:22.4 TLT:26.8 cash:  0.2 total: 100.0
# 2009-12-01 GLD:22.4 QQQ:19.9 SPY:21.3 TLT:36.0 cash:  0.5 total: 100.0
# 2010-01-04 GLD:12.9 QQQ:26.8 SPY:25.5 TLT:29.2 cash:  5.7 total: 100.0
# 2010-02-01 GLD:18.7 QQQ:20.5 SPY:24.6 TLT:33.6 cash:  2.6 total: 100.0
# 2010-03-01 GLD:18.7 QQQ:23.4 SPY:23.9 TLT:32.5 cash:  1.6 total: 100.0
# 2010-04-01 GLD:14.9 QQQ:29.7 SPY:24.7 TLT:23.8 cash:  6.9 total: 100.0
# 2010-05-03 GLD:21.3 QQQ:20.6 SPY:20.6 TLT:33.4 cash:  4.1 total: 100.0
# 2010-06-01 GLD:26.4 QQQ:17.9 SPY:19.8 TLT:29.5 cash:  6.4 total: 100.0
# 2010-07-01 GLD:24.0 QQQ:20.1 SPY:21.4 TLT:34.3 cash:  0.2 total: 100.0
# 2010-08-02 GLD:23.2 QQQ:20.5 SPY:20.6 TLT:28.8 cash:  6.9 total: 100.0
# 2010-09-01 GLD:30.6 QQQ:17.7 SPY:18.4 TLT:17.6 cash: 15.7 total: 100.0
# 2010-10-01 GLD:33.1 QQQ:24.7 SPY:24.6 TLT:17.6 cash:  0.1 total: 100.0
# 2010-11-01 GLD:17.1 QQQ:25.4 SPY:32.8 TLT:24.4 cash:  0.3 total: 100.0
# 2010-12-01 GLD:17.5 QQQ:25.4 SPY:28.1 TLT:22.3 cash:  6.8 total: 100.0
# 2011-01-03 GLD:16.6 QQQ:29.4 SPY:32.3 TLT:11.9 cash:  9.7 total: 100.0
# 2011-02-01 GLD:20.2 QQQ:23.3 SPY:31.5 TLT:24.6 cash:  0.4 total: 100.0
# 2011-03-01 GLD:21.4 QQQ:19.2 SPY:23.5 TLT:26.1 cash:  9.8 total: 100.0
# 2011-04-01 GLD:29.8 QQQ:19.6 SPY:22.7 TLT:27.7 cash:  0.1 total: 100.0
# 2011-05-02 GLD:20.5 QQQ:24.7 SPY:27.7 TLT:24.2 cash:  3.0 total: 100.0
# 2011-06-01 GLD:21.4 QQQ:21.8 SPY:25.3 TLT:31.4 cash:  0.2 total: 100.0
# 2011-07-01 GLD:21.0 QQQ:18.6 SPY:22.4 TLT:27.8 cash: 10.1 total: 100.0
# 2011-08-01 GLD:32.2 QQQ:18.2 SPY:21.1 TLT:22.3 cash:  6.2 total: 100.0
# 2011-09-01 GLD:28.9 QQQ:21.1 SPY:21.5 TLT:28.3 cash:  0.2 total: 100.0
# 2011-10-03 GLD:22.2 QQQ:24.7 SPY:20.0 TLT:26.0 cash:  7.1 total: 100.0
# 2011-11-01 GLD:28.7 QQQ:22.8 SPY:22.0 TLT:21.6 cash:  4.9 total: 100.0
# 2011-12-01 GLD:26.5 QQQ:19.4 SPY:20.2 TLT:33.7 cash:  0.1 total: 100.0
# 2012-01-03 GLD:20.6 QQQ:23.3 SPY:20.7 TLT:25.9 cash:  9.5 total: 100.0
# 2012-02-01 GLD:19.2 QQQ:30.4 SPY:25.1 TLT:17.0 cash:  8.3 total: 100.0
# 2012-03-01 GLD:12.0 QQQ:29.9 SPY:37.0 TLT:20.9 cash:  0.1 total: 100.0
# 2012-04-02 GLD:11.6 QQQ:29.7 SPY:28.5 TLT:20.5 cash:  9.6 total: 100.0
# 2012-05-01 GLD:21.2 QQQ:20.5 SPY:26.0 TLT:24.3 cash:  8.0 total: 100.0
# 2012-06-01 GLD:19.9 QQQ:22.5 SPY:28.3 TLT:29.1 cash:  0.1 total: 100.0
# 2012-07-02 GLD:19.3 QQQ:20.4 SPY:24.0 TLT:29.3 cash:  7.0 total: 100.0
# 2012-08-01 GLD:26.1 QQQ:19.9 SPY:23.4 TLT:28.0 cash:  2.6 total: 100.0
# 2012-09-04 GLD:20.1 QQQ:27.1 SPY:26.1 TLT:16.7 cash: 10.0 total: 100.0
# 2012-10-01 GLD:25.5 QQQ:23.5 SPY:29.2 TLT:21.6 cash:  0.2 total: 100.0
# 2012-11-01 GLD:25.3 QQQ:20.5 SPY:26.6 TLT:20.7 cash:  7.0 total: 100.0
# 2012-12-03 GLD:27.9 QQQ:19.8 SPY:21.7 TLT:30.6 cash:  0.0 total: 100.0
# 2013-01-02 GLD:27.4 QQQ:17.8 SPY:23.1 TLT:25.3 cash:  6.4 total: 100.0
# 2013-02-01 GLD:23.1 QQQ:23.7 SPY:28.5 TLT:20.2 cash:  4.5 total: 100.0
# 2013-03-01 GLD:24.0 QQQ:23.1 SPY:25.9 TLT:27.0 cash:  0.0 total: 100.0
# 2013-04-01 GLD:24.1 QQQ:22.7 SPY:26.8 TLT:19.9 cash:  6.6 total: 100.0
# 2013-05-01 GLD:11.0 QQQ:25.8 SPY:30.3 TLT:32.7 cash:  0.1 total: 100.0
# 2013-06-03 GLD:10.8 QQQ:27.2 SPY:30.5 TLT:19.9 cash: 11.5 total: 100.0
# 2013-07-01 GLD:15.7 QQQ:29.0 SPY:27.2 TLT:28.0 cash:  0.1 total: 100.0
# 2013-08-01 GLD:15.0 QQQ:30.1 SPY:29.1 TLT:16.7 cash:  9.1 total: 100.0
# 2013-09-03 GLD:19.3 QQQ:26.0 SPY:32.0 TLT:22.6 cash:  0.1 total: 100.0
# 2013-10-01 GLD:10.5 QQQ:32.6 SPY:31.7 TLT:25.1 cash:  0.0 total: 100.0
# 2013-11-01 GLD:10.3 QQQ:22.9 SPY:26.2 TLT:32.6 cash:  8.0 total: 100.0
# 2013-12-02 GLD:17.8 QQQ:23.9 SPY:27.2 TLT:22.0 cash:  9.2 total: 100.0
# 2014-01-02 GLD:14.7 QQQ:29.3 SPY:27.6 TLT:28.3 cash:  0.1 total: 100.0
# 2014-02-03 GLD:15.1 QQQ:19.2 SPY:23.0 TLT:36.8 cash:  5.9 total: 100.0
# 2014-03-03 GLD:21.2 QQQ:19.8 SPY:23.5 TLT:30.6 cash:  4.9 total: 100.0
# 2014-04-01 GLD:20.5 QQQ:21.2 SPY:27.5 TLT:26.2 cash:  4.6 total: 100.0
# 2014-05-01 GLD:24.8 QQQ:14.6 SPY:23.0 TLT:35.3 cash:  2.3 total: 100.0
# 2014-06-02 GLD:21.9 QQQ:19.1 SPY:23.3 TLT:24.8 cash: 10.9 total: 100.0
# 2014-07-01 GLD:14.8 QQQ:30.3 SPY:30.9 TLT:21.6 cash:  2.5 total: 100.0
# 2014-08-01 GLD:16.9 QQQ:22.6 SPY:28.9 TLT:27.6 cash:  4.2 total: 100.0
# 2014-09-02 GLD:20.0 QQQ:23.1 SPY:28.1 TLT:19.0 cash:  9.9 total: 100.0
# 2014-10-01 GLD:29.6 QQQ:19.9 SPY:25.9 TLT:21.8 cash:  2.8 total: 100.0
# 2014-11-03 GLD:29.1 QQQ:16.0 SPY:19.0 TLT:35.7 cash:  0.1 total: 100.0
# 2014-12-01 GLD: 7.7 QQQ:28.3 SPY:28.2 TLT:23.6 cash: 12.2 total: 100.0
# 2015-01-02 GLD:19.5 QQQ:25.4 SPY:25.9 TLT:27.0 cash:  2.2 total: 100.0
# 2015-02-02 GLD:22.4 QQQ:23.8 SPY:25.3 TLT:26.6 cash:  1.8 total: 100.0
# 2015-03-02 GLD:21.6 QQQ:27.0 SPY:26.7 TLT:17.3 cash:  7.4 total: 100.0
# 2015-04-01 GLD:24.4 QQQ:25.7 SPY:26.5 TLT:23.3 cash:  0.1 total: 100.0
# 2015-05-01 GLD:19.4 QQQ:23.1 SPY:33.5 TLT:24.0 cash:  0.0 total: 100.0
# 2015-06-01 GLD:19.5 QQQ:23.4 SPY:31.4 TLT:17.0 cash:  8.7 total: 100.0
# 2015-07-01 GLD:28.3 QQQ:22.9 SPY:26.6 TLT:16.7 cash:  5.5 total: 100.0
# 2015-08-03 GLD:26.7 QQQ:22.0 SPY:27.5 TLT:23.7 cash:  0.1 total: 100.0
# 2015-09-01 GLD:29.3 QQQ:14.4 SPY:16.9 TLT:31.7 cash:  7.6 total: 100.0
# 2015-10-01 GLD:31.1 QQQ:19.6 SPY:17.0 TLT:25.9 cash:  6.4 total: 100.0
# 2015-11-02 GLD:24.7 QQQ:21.0 SPY:25.9 TLT:28.2 cash:  0.1 total: 100.0
# 2015-12-01 GLD:23.7 QQQ:21.2 SPY:24.0 TLT:30.4 cash:  0.7 total: 100.0
# 2016-01-04 GLD:24.5 QQQ:20.0 SPY:22.9 TLT:32.6 cash:  0.1 total: 100.0
# 2016-02-01 GLD:25.7 QQQ:15.2 SPY:19.1 TLT:35.4 cash:  4.6 total: 100.0
# 2016-03-01 GLD:21.8 QQQ:20.2 SPY:23.2 TLT:32.1 cash:  2.7 total: 100.0
# 2016-04-01 GLD:15.7 QQQ:25.8 SPY:26.7 TLT:27.4 cash:  4.4 total: 100.0
# 2016-05-02 GLD:19.3 QQQ:22.9 SPY:29.9 TLT:27.9 cash:  0.0 total: 100.0
# 2016-06-01 GLD:18.1 QQQ:21.6 SPY:26.6 TLT:30.4 cash:  3.3 total: 100.0
# 2016-07-01 GLD:22.4 QQQ:20.5 SPY:25.1 TLT:30.3 cash:  1.8 total: 100.0
# 2016-08-01 GLD:17.4 QQQ:27.9 SPY:25.4 TLT:18.6 cash: 10.7 total: 100.0
# 2016-09-01 GLD:18.0 QQQ:31.4 SPY:31.8 TLT:16.7 cash:  2.0 total: 100.0
# 2016-10-03 GLD:20.0 QQQ:20.1 SPY:21.9 TLT:26.9 cash: 11.1 total: 100.0
# 2016-11-01 GLD:27.0 QQQ:21.1 SPY:25.3 TLT:23.4 cash:  3.1 total: 100.0
# 2016-12-01 GLD:24.3 QQQ:21.6 SPY:31.9 TLT:18.9 cash:  3.4 total: 100.0
# 2017-01-03 GLD:21.2 QQQ:25.0 SPY:29.7 TLT:24.0 cash:  0.1 total: 100.0
# 2017-02-01 GLD:17.7 QQQ:29.7 SPY:29.2 TLT:16.6 cash:  6.8 total: 100.0
# 2017-03-01 GLD:21.4 QQQ:32.8 SPY:29.6 TLT:15.3 cash:  0.9 total: 100.0
# 2017-04-03 GLD:20.8 QQQ:28.1 SPY:29.9 TLT:20.9 cash:  0.2 total: 100.0
# 2017-05-01 GLD:20.8 QQQ:27.5 SPY:29.4 TLT:21.0 cash:  1.3 total: 100.0
# 2017-06-01 GLD:21.8 QQQ:20.6 SPY:27.1 TLT:29.6 cash:  0.9 total: 100.0
# 2017-07-03 GLD:22.2 QQQ:14.5 SPY:33.1 TLT:26.8 cash:  3.3 total: 100.0
# 2017-08-01 GLD:25.3 QQQ:15.6 SPY:33.2 TLT:20.8 cash:  5.1 total: 100.0
# 2017-09-01 GLD:24.4 QQQ:16.5 SPY:24.5 TLT:34.2 cash:  0.4 total: 100.0
# 2017-10-02 GLD:17.9 QQQ:22.6 SPY:25.3 TLT:19.6 cash: 14.7 total: 100.0
# 2017-11-01 GLD:22.9 QQQ:16.3 SPY:37.2 TLT:23.4 cash:  0.2 total: 100.0
# 2017-12-01 GLD:22.7 QQQ:16.3 SPY:34.0 TLT:21.2 cash:  5.8 total: 100.0
# 2018-01-02 GLD:23.4 QQQ:20.5 SPY:35.4 TLT:19.6 cash:  1.1 total: 100.0
# 2018-02-01 GLD:24.3 QQQ:21.0 SPY:27.1 TLT:24.3 cash:  3.3 total: 100.0
# 2018-03-01 GLD:27.6 QQQ:13.6 SPY:15.3 TLT:34.9 cash:  8.7 total: 100.0
# 2018-04-02 GLD:28.3 QQQ:12.1 SPY:16.1 TLT:43.4 cash:  0.0 total: 100.0
# 2018-05-01 GLD:27.9 QQQ:12.8 SPY:16.8 TLT:33.0 cash:  9.4 total: 100.0
# 2018-06-01 GLD:33.5 QQQ:16.4 SPY:17.1 TLT:21.4 cash: 11.6 total: 100.0
# 2018-07-02 GLD:27.7 QQQ:17.0 SPY:27.8 TLT:27.4 cash:  0.1 total: 100.0
# 2018-08-01 GLD:27.1 QQQ:15.6 SPY:27.6 TLT:27.5 cash:  2.1 total: 100.0
# 2018-09-04 GLD:17.0 QQQ:23.5 SPY:29.7 TLT:29.8 cash:  0.1 total: 100.0
# 2018-10-01 GLD:17.0 QQQ:16.3 SPY:33.9 TLT:24.5 cash:  8.3 total: 100.0
# 2018-11-01 GLD:26.9 QQQ:10.5 SPY:15.6 TLT:43.0 cash:  4.0 total: 100.0
# 2018-12-03 GLD:30.6 QQQ: 8.6 SPY:12.6 TLT:47.0 cash:  1.2 total: 100.0
# 2019-01-02 GLD:32.5 QQQ: 7.6 SPY:11.2 TLT:37.6 cash: 11.1 total: 100.0
# 2019-02-01 GLD:33.4 QQQ:12.7 SPY:17.3 TLT:35.5 cash:  1.1 total: 100.0
# 2019-03-01 GLD:21.1 QQQ:23.3 SPY:20.7 TLT:26.8 cash:  8.1 total: 100.0
# 2019-04-01 GLD:28.4 QQQ:19.3 SPY:23.6 TLT:28.3 cash:  0.3 total: 100.0
# 2019-05-01 GLD:23.1 QQQ:24.9 SPY:23.9 TLT:22.5 cash:  5.5 total: 100.0
# 2019-06-03 GLD:30.0 QQQ:14.4 SPY:19.7 TLT:35.9 cash:  0.0 total: 100.0
# 2019-07-01 GLD:20.7 QQQ:19.4 SPY:25.5 TLT:31.5 cash:  2.9 total: 100.0
# 2019-08-01 GLD:16.5 QQQ:25.5 SPY:25.9 TLT:23.5 cash:  8.6 total: 100.0
# 2019-09-03 GLD:25.7 QQQ:18.3 SPY:21.0 TLT:27.6 cash:  7.5 total: 100.0
# 2019-10-01 GLD:21.6 QQQ:23.8 SPY:26.8 TLT:19.0 cash:  8.8 total: 100.0
# 2019-11-01 GLD:29.5 QQQ:21.4 SPY:27.3 TLT:21.6 cash:  0.2 total: 100.0
# 2019-12-02 GLD:21.6 QQQ:26.6 SPY:30.3 TLT:16.1 cash:  5.4 total: 100.0
# 2020-01-02 GLD:26.8 QQQ:23.0 SPY:30.8 TLT:17.3 cash:  2.0 total: 100.0
# 2020-02-03 GLD:29.0 QQQ:19.4 SPY:23.7 TLT:25.1 cash:  2.8 total: 100.0
# 2020-03-02 GLD:29.2 QQQ:15.4 SPY:18.0 TLT:37.2 cash:  0.2 total: 100.0
# 2020-04-01 GLD:30.1 QQQ:13.3 SPY:14.8 TLT:24.6 cash: 17.2 total: 100.0
# 2020-05-01 GLD:30.9 QQQ:15.8 SPY:16.7 TLT:36.5 cash:  0.1 total: 100.0
# 2020-06-01 GLD:29.7 QQQ:18.1 SPY:17.6 TLT:25.6 cash:  9.1 total: 100.0
# 2020-07-01 GLD:36.5 QQQ:17.2 SPY:15.5 TLT:30.6 cash:  0.2 total: 100.0
# 2020-08-03 GLD:28.0 QQQ:14.6 SPY:25.0 TLT:32.2 cash:  0.2 total: 100.0
# 2020-09-01 GLD:12.0 QQQ:20.0 SPY:37.5 TLT:27.6 cash:  2.9 total: 100.0
# 2020-10-01 GLD:14.7 QQQ:10.8 SPY:16.3 TLT:44.0 cash: 14.2 total: 100.0
# 2020-11-02 GLD:28.9 QQQ:11.0 SPY:16.3 TLT:36.8 cash:  7.0 total: 100.0
# 2020-12-01 GLD:21.3 QQQ:20.0 SPY:22.9 TLT:29.2 cash:  6.6 total: 100.0
# 2021-01-04 GLD:19.4 QQQ:21.7 SPY:27.6 TLT:31.2 cash:  0.1 total: 100.0
# 2021-02-01 GLD:18.6 QQQ:17.4 SPY:24.1 TLT:36.0 cash:  4.0 total: 100.0
# 2021-03-01 GLD:21.9 QQQ:18.1 SPY:25.9 TLT:26.3 cash:  7.8 total: 100.0
# 2021-04-01 GLD:27.7 QQQ:15.0 SPY:30.4 TLT:26.8 cash:  0.2 total: 100.0
# 2021-05-03 GLD:23.5 QQQ:19.3 SPY:28.9 TLT:27.3 cash:  1.0 total: 100.0
# 2021-06-01 GLD:25.7 QQQ:14.9 SPY:21.5 TLT:33.1 cash:  4.8 total: 100.0
# 2021-07-01 GLD:19.2 QQQ:25.2 SPY:22.2 TLT:21.4 cash: 12.2 total: 100.0
# 2021-08-02 GLD:31.0 QQQ:25.3 SPY:22.1 TLT:17.6 cash:  4.0 total: 100.0
# 2021-09-01 GLD:17.1 QQQ:25.0 SPY:33.4 TLT:24.4 cash:  0.1 total: 100.0
# 2021-10-01 GLD:17.2 QQQ:24.4 SPY:26.6 TLT:24.3 cash:  7.4 total: 100.0
# 2021-11-01 GLD:24.0 QQQ:25.0 SPY:27.4 TLT:19.4 cash:  4.2 total: 100.0
# 2021-12-01 GLD:28.0 QQQ:22.1 SPY:28.9 TLT:20.2 cash:  0.8 total: 100.0
# 2022-01-03 GLD:28.5 QQQ:16.3 SPY:23.4 TLT:23.7 cash:  8.1 total: 100.0
# 2022-02-01 GLD:33.1 QQQ:14.7 SPY:22.3 TLT:29.8 cash:  0.1 total: 100.0
# 2022-03-01 GLD:35.7 QQQ:13.6 SPY:20.5 TLT:27.3 cash:  2.9 total: 100.0
# 2022-04-01 GLD:27.3 QQQ:17.6 SPY:25.0 TLT:30.0 cash:  0.2 total: 100.0
# 2022-05-02 GLD:29.0 QQQ:13.9 SPY:19.5 TLT:29.0 cash:  8.6 total: 100.0
# 2022-06-01 GLD:37.7 QQQ:13.4 SPY:17.8 TLT:26.1 cash:  5.0 total: 100.0
# 2022-07-01 GLD:40.1 QQQ:15.6 SPY:17.3 TLT:24.9 cash:  2.1 total: 100.0
# 2022-08-01 GLD:32.6 QQQ:17.4 SPY:24.3 TLT:25.5 cash:  0.1 total: 100.0
# 2022-09-01 GLD:33.2 QQQ:16.9 SPY:21.1 TLT:23.2 cash:  5.6 total: 100.0
# 2022-10-03 GLD:34.2 QQQ:19.3 SPY:22.3 TLT:24.0 cash:  0.2 total: 100.0
# 2022-11-01 GLD:34.1 QQQ:16.2 SPY:20.2 TLT:26.1 cash:  3.4 total: 100.0
# 2022-12-01 GLD:32.5 QQQ:17.3 SPY:23.5 TLT:26.5 cash:  0.2 total: 100.0
# 2023-01-03 GLD:31.6 QQQ:19.2 SPY:22.9 TLT:21.9 cash:  4.3 total: 100.0
# 2023-02-01 GLD:32.5 QQQ:19.2 SPY:25.8 TLT:22.4 cash:  0.1 total: 100.0
# 2023-03-01 GLD:29.8 QQQ:16.5 SPY:27.2 TLT:26.3 cash:  0.0 total: 100.0
# 2023-04-03 GLD:23.9 QQQ:23.4 SPY:26.7 TLT:24.5 cash:  1.6 total: 100.0
# 2023-05-01 GLD:25.6 QQQ:22.6 SPY:28.3 TLT:20.1 cash:  3.4 total: 100.0
# 2023-06-01 GLD:27.6 QQQ:19.3 SPY:26.0 TLT:27.1 cash:  0.0 total: 100.0
# 2023-07-03 GLD:26.6 QQQ:18.0 SPY:29.5 TLT:21.3 cash:  4.5 total: 100.0
# 2023-08-01 GLD:25.5 QQQ:19.6 SPY:34.6 TLT:19.9 cash:  0.4 total: 100.0
# 2023-09-01 GLD:26.4 QQQ:16.3 SPY:24.0 TLT:17.9 cash: 15.5 total: 100.0
# 2023-10-02 GLD:33.7 QQQ:20.0 SPY:27.1 TLT:19.0 cash:  0.2 total: 100.0
# 2023-11-01 GLD:28.6 QQQ:23.0 SPY:30.1 TLT:17.5 cash:  0.7 total: 100.0
# 2023-12-01 GLD:25.7 QQQ:24.9 SPY:31.6 TLT:16.3 cash:  1.4 total: 100.0
# 2024-01-02 GLD:22.3 QQQ:24.8 SPY:34.3 TLT:18.4 cash:  0.2 total: 100.0
# 2024-02-01 GLD:21.7 QQQ:20.4 SPY:27.2 TLT:20.2 cash: 10.5 total: 100.0
# 2024-03-01 GLD:30.6 QQQ:19.8 SPY:28.0 TLT:21.3 cash:  0.3 total: 100.0
# 2024-04-01 GLD:25.8 QQQ:20.1 SPY:30.8 TLT:23.2 cash:  0.2 total: 100.0
# 2024-05-01 GLD:21.6 QQQ:20.9 SPY:29.2 TLT:27.9 cash:  0.3 total: 100.0
# 2024-06-03 GLD:16.6 QQQ:26.0 SPY:29.4 TLT:21.9 cash:  6.1 total: 100.0
# 2024-07-01 GLD:14.9 QQQ:23.7 SPY:40.2 TLT:15.8 cash:  5.5 total: 100.0
# 2024-08-01 GLD:20.6 QQQ:15.6 SPY:25.6 TLT:34.6 cash:  3.5 total: 100.0
# 2024-09-03 GLD:24.0 QQQ:15.3 SPY:25.5 TLT:28.8 cash:  6.4 total: 100.0
# 2024-10-01 GLD:23.9 QQQ:17.4 SPY:27.0 TLT:31.5 cash:  0.2 total: 100.0
# 2024-11-01 GLD:25.0 QQQ:17.9 SPY:27.5 TLT:26.6 cash:  3.1 total: 100.0
# 2024-12-02 GLD:18.3 QQQ:24.8 SPY:29.8 TLT:22.2 cash:  5.0 total: 100.0
# 2025-01-02 GLD:23.7 QQQ:18.3 SPY:25.4 TLT:30.7 cash:  1.9 total: 100.0
# 2025-02-03 GLD:26.3 QQQ:16.5 SPY:24.2 TLT:30.3 cash:  2.7 total: 100.0
# 2025-03-03 GLD:26.0 QQQ:18.9 SPY:23.3 TLT:26.6 cash:  5.2 total: 100.0
# 2025-04-01 GLD:32.4 QQQ:14.2 SPY:19.2 TLT:33.9 cash:  0.3 total: 100.0
# 2025-05-01 GLD:27.5 QQQ:14.2 SPY:15.9 TLT:42.1 cash:  0.3 total: 100.0
# 2025-06-02 GLD:15.5 QQQ:22.5 SPY:22.4 TLT:35.6 cash:  4.0 total: 100.0
# 2025-07-01 GLD:18.7 QQQ:22.9 SPY:22.7 TLT:25.1 cash: 10.7 total: 100.0
# 2025-08-01 GLD:18.2 QQQ:28.1 SPY:28.5 TLT:21.8 cash:  3.3 total: 100.0
# 2025-09-02 GLD:20.4 QQQ:20.5 SPY:27.3 TLT:31.7 cash:  0.1 total: 100.0
# 2025-10-01 GLD:17.3 QQQ:24.4 SPY:26.8 TLT:20.2 cash: 11.2 total: 100.0
# 2025-11-03 GLD:11.0 QQQ:19.5 SPY:26.4 TLT:43.1 cash:  0.0 total: 100.0
# 2025-12-01 GLD:11.7 QQQ:16.6 SPY:23.6 TLT:39.7 cash:  8.4 total: 100.0
# 2026-01-02 GLD:13.0 QQQ:19.8 SPY:28.1 TLT:37.7 cash:  1.5 total: 100.0
# 2026-02-02 GLD: 6.7 QQQ:23.9 SPY:31.6 TLT:37.6 cash:  0.1 total: 100.0
# 2026-03-02 GLD: 7.7 QQQ:20.7 SPY:28.9 TLT:41.1 cash:  1.6 total: 100.0
# 2026-04-01 GLD: 8.8 QQQ:20.7 SPY:26.5 TLT:37.9 cash:  6.1 total: 100.0
# 2026-05-01 GLD:13.8 QQQ:18.6 SPY:24.0 TLT:42.6 cash:  1.0 total: 100.0
# 2026-06-01 GLD:14.0 QQQ:19.8 SPY:24.5 TLT:31.6 cash: 10.1 total: 100.0
# 2026-06-08 GLD: 0.0 QQQ: 0.0 SPY: 0.0 TLT: 0.0 cash: 100.0 total: 100.0

# %% [markdown]
# View log DataFrames: raw trade log, trade log, and daily balance.

# %%
s.rlog.head()
# Out:
#         date  seq_num  price  shares entry_exit direction symbol
# 0 2007-11-20        0  79.47     188      entry      LONG    GLD
# 0 2007-11-20        1  42.87     344      entry      LONG    QQQ
# 0 2007-11-20        2 102.74     196      entry      LONG    SPY
# 0 2007-11-20        3  52.74     949      entry      LONG    TLT
# 1 2007-12-03        4  78.28       1      entry      LONG    GLD

# %%
s.tlog.tail()
# Out:
#     entry_date  entry_price  exit_date  exit_price  pl_points  pl_cash  qty  \
# 221 2026-03-02        88.58 2026-06-08       84.62      -3.96  -763.62  193
# 208 2026-04-01       437.82 2026-06-08      397.27     -40.55 -1013.75   25
# 209 2026-05-01       423.18 2026-06-08      397.27     -25.91 -2409.63   93
# 222 2026-05-01        85.27 2026-06-08       84.62      -0.65  -363.95  556
# 210 2026-06-01       411.26 2026-06-08      397.27     -13.99  -237.83   17
#
#      cumul_total direction symbol
# 221    567698.75      LONG    TLT
# 208    566685.00      LONG    GLD
# 209    564275.37      LONG    GLD
# 222    563911.42      LONG    TLT
# 210    563673.59      LONG    GLD

# %%
s.dbal.tail()
# Out:
#                 high       low     close  shares      cash  leverage state
# date
# 2026-06-02 714329.49 714329.49 714329.49    3300  72221.39      1.00     -
# 2026-06-03 710848.80 710848.80 710848.80    3300  72221.39      1.00     -
# 2026-06-04 712144.33 712144.33 712144.33    3300  72221.39      1.00     -
# 2026-06-05 696097.64 696097.64 696097.64    3300  72221.39      1.00     -
# 2026-06-08 663673.59 663673.59 663673.59       0 663673.59      1.00     X

# %% [markdown]
# Generate strategy stats - display all available stats.

# %%
pf.print_full(s.stats)
# Out:
# start                                                   2007-11-20
# end                                                     2026-06-08
# beginning_balance                                           100000
# ending_balance                                           663673.59
# total_net_profit                                         563673.59
# gross_profit                                             697570.97
# gross_loss                                              -133897.38
# profit_factor                                                 5.21
# return_on_initial_capital                                   563.67
# annual_return_rate                                           10.74
# trading_period                           18 years 6 months 19 days
# pct_time_in_market                                          100.00
# margin                                                           1
# avg_leverage                                                  1.00
# max_leverage                                                  1.00
# min_leverage                                                  1.00
# total_num_trades                                               826
# trades_per_year                                              44.52
# num_winning_trades                                             625
# num_losing_trades                                              201
# num_even_trades                                                  0
# pct_profitable_trades                                        75.67
# avg_profit_per_trade                                        682.41
# avg_profit_per_winning_trade                               1116.11
# avg_loss_per_losing_trade                                  -666.16
# ratio_avg_profit_win_loss                                     1.68
# largest_profit_winning_trade                              12002.16
# largest_loss_losing_trade                                 -4943.10
# num_winning_points                                        22448.91
# num_losing_points                                         -2808.57
# total_net_points                                          19640.34
# avg_points                                                   23.78
# largest_points_winning_trade                                217.97
# largest_points_losing_trade                                 -92.73
# avg_pct_gain_per_trade                                       12.96
# largest_pct_winning_trade                                    84.01
# largest_pct_losing_trade                                    -41.89
# expected_shortfall                                          -36.98
# max_consecutive_winning_trades                                  71
# max_consecutive_losing_trades                                    9
# avg_bars_winning_trades                                     268.53
# avg_bars_losing_trades                                      246.66
# max_closed_out_drawdown                                     -24.28
# max_closed_out_drawdown_peak_date                       2021-12-27
# max_closed_out_drawdown_trough_date                     2022-11-03
# max_closed_out_drawdown_recovery_date                   2024-03-07
# drawdown_loss_period                                           311
# drawdown_recovery_period                                       490
# annualized_return_over_max_drawdown                           0.44
# max_intra_day_drawdown                                      -24.28
# avg_yearly_closed_out_drawdown                               -7.83
# max_yearly_closed_out_drawdown                              -24.28
# avg_monthly_closed_out_drawdown                              -2.21
# max_monthly_closed_out_drawdown                             -13.83
# avg_weekly_closed_out_drawdown                               -0.88
# max_weekly_closed_out_drawdown                               -9.04
# avg_yearly_closed_out_runup                                  18.28
# max_yearly_closed_out_runup                                  41.09
# avg_monthly_closed_out_runup                                  3.00
# max_monthly_closed_out_runup                                 17.37
# avg_weekly_closed_out_runup                                   1.09
# max_weekly_closed_out_runup                                   9.98
# pct_profitable_years                                         85.75
# best_year                                                    39.88
# worst_year                                                  -22.70
# avg_year                                                     12.00
# annual_std                                                   11.56
# pct_profitable_months                                        65.86
# best_month                                                   17.37
# worst_month                                                 -13.38
# avg_month                                                     0.87
# monthly_std                                                   2.71
# pct_profitable_weeks                                         59.66
# best_week                                                     9.98
# worst_week                                                   -9.04
# avg_week                                                      0.22
# weekly_std                                                    1.37
# pct_profitable_days                                          55.64
# best_day                                                      4.94
# worst_day                                                    -4.66
# avg_day                                                       0.04
# daily_std                                                     0.62
# sharpe_ratio                                                  1.10
# sharpe_ratio_max                                              1.15
# sharpe_ratio_min                                              1.04
# sortino_ratio                                                 1.51
# dtype: object

# %% [markdown]
# View Performance by Symbol

# %%
symbols_no_weights = [k for k,v in weights.items() if v is None]
symbols_weights    = {k:v for k,v in weights.items() if v is not None}
remaining_weight   = 1 - sum(symbols_weights.values())

weights_ = weights.copy()
for symbol in symbols_no_weights:
    weights_[symbol] = (1 / len(symbols_no_weights)) * remaining_weight
totals = s.portfolio.performance_per_symbol(weights=weights_)
totals
# Out:
#        cumul_total  weight  pct_cumul_total  relative_performance
# GLD    $158,708.41    0.25             0.28                  1.13
# QQQ    $212,442.88    0.25             0.38                  1.51
# SPY    $183,381.85    0.25             0.33                  1.30
# TLT      $9,140.45    0.25             0.02                  0.06
# TOTAL  $563,673.59    1.00             1.00                  1.00

# %%
corr_df = s.portfolio.correlation_map(s.ts)
corr_df
# Out:
#      GLD   QQQ   SPY   TLT
# GLD 1.00  0.04  0.05  0.17
# QQQ 0.04  1.00  0.93 -0.26
# SPY 0.05  0.93  1.00 -0.31
# TLT 0.17 -0.26 -0.31  1.00

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats.

# %%
benchmark = pf.Benchmark('SPY', s.capital, s.start, s.end, use_adj=True)
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                      10.74      11.24
# max_closed_out_drawdown                -24.28     -53.88
# annualized_return_over_max_drawdown      0.44       0.21
# best_month                              17.37      23.61
# worst_month                            -13.38     -30.98
# sharpe_ratio                             1.10       0.64
# sortino_ratio                            1.51       0.78
# monthly_std                              2.71       4.71
# annual_std                              11.56      16.10

# %% [markdown]
# Analysis: Kelly Criterian

# %%
kelly = pf.kelly_criterion(s.stats, benchmark.stats)
kelly
# Out:
# sharpe_ratio            1.10
# sharpe_ratio_max        1.15
# sharpe_ratio_min        1.04
# strategy risk           0.12
# instrument risk         0.16
# optimal target risk     1.10
# half kelly criterion    0.55
# aggressive leverage     6.81
# moderate leverage       3.40
# conservative leverage   3.23
# dtype: float64
