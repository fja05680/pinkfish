# %% [markdown]
# # Weight By Portfolio Strategy
#
# Basic buy and hold that allows weighting by user specified weights, Equal, Sharpe Ratio, Annual Returns, Std Dev, Vola, or DS Vola.
#
# Rebalance is yearly, monthly, weekly, or daily.  Option to sell all shares of an investment is regime turns negative.

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd

import pinkfish as pf
import strategy

# Format price data.
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# Set size of inline plots.
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
# Symbol Lists.
SP500_Sectors = \
    {'XLB': None, 'XLE': None, 'XLF': None, 'XLI': None,
     'XLK': None, 'XLP': None, 'XLU': None, 'XLV': None, 'XLY': None}

Mixed_Asset_Classes = \
    {'IWB': None, 'SPY': None, 'VGK': None, 'IEV': None,
     'EWJ': None, 'EPP': None, 'IEF': None, 'SHY': None, 'GLD': None}
FANG_Stocks = \
    {'FB': None, 'AMZN': None, 'NFLX': None, 'GOOG': None}

Stocks_Bonds_Gold = \
    {'SPY': None, 'QQQ': None, 'TLT': None, 'GLD': None}

Stocks_Bonds = \
    {'SPY': 0.50, 'AGG': 0.50}

# Pick one of the above.
weights = Stocks_Bonds_Gold
symbols = list(weights)

capital = 100_000
start = datetime.datetime(*pf.ALPHA_BEGIN)
#start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()

# %%
weight_by_choices = ('equal', 'sharpe', 'ret', 'sd', 'vola', 'ds_vola')
rebalance_choices = ('yearly', 'monthly', 'weekly', 'daily')

options = {
    'use_adj'           : True,
    'use_cache'         : True,
    'margin'            : 1,
    'weights'           : weights,
    'weight_by'         : 'vola',
    'rebalance'         : 'monthly',
    'use_regime_filter' : False
}

# %% [markdown]
# Run Strategy

# %%
s = strategy.Strategy(symbols, capital, start, end, options=options)
s.run()
# Out:
# 2007-11-20 TLT:46.3 GLD:16.1 QQQ:15.9 SPY:21.6 cash:  0.1 total: 100.0
# 2007-12-03 TLT:46.6 GLD:15.6 QQQ:16.0 SPY:19.4 cash:  2.4 total: 100.0
# 2008-01-02 TLT:28.3 GLD:21.6 QQQ:23.1 SPY:26.9 cash:  0.1 total: 100.0
# 2008-02-01 TLT:29.2 GLD:23.1 QQQ:18.1 SPY:21.8 cash:  7.8 total: 100.0
# 2008-03-03 TLT:26.8 GLD:24.6 QQQ:21.7 SPY:26.7 cash:  0.2 total: 100.0
# 2008-04-01 TLT:27.2 GLD:21.4 QQQ:18.8 SPY:21.8 cash: 10.8 total: 100.0
# 2008-05-01 TLT:37.3 GLD:18.3 QQQ:16.7 SPY:25.6 cash:  2.1 total: 100.0
# 2008-06-02 TLT:36.0 GLD:15.9 QQQ:21.2 SPY:26.7 cash:  0.2 total: 100.0
# 2008-07-01 TLT:37.7 GLD:17.1 QQQ:16.3 SPY:22.9 cash:  6.1 total: 100.0
# 2008-08-01 TLT:37.0 GLD:23.1 QQQ:17.1 SPY:20.8 cash:  1.9 total: 100.0
# 2008-09-02 TLT:40.4 GLD:15.4 QQQ:19.9 SPY:22.4 cash:  1.9 total: 100.0
# 2008-10-01 TLT:41.3 GLD:17.4 QQQ:20.2 SPY:20.1 cash:  1.0 total: 100.0
# 2008-11-03 TLT:46.1 GLD:16.2 QQQ:10.9 SPY: 9.5 cash: 17.3 total: 100.0
# 2008-12-01 TLT:40.6 GLD:24.9 QQQ:18.5 SPY:15.8 cash:  0.2 total: 100.0
# 2009-01-02 TLT:31.1 GLD:28.2 QQQ:18.9 SPY:21.6 cash:  0.1 total: 100.0
# 2009-02-02 TLT:29.9 GLD:23.4 QQQ:22.0 SPY:21.9 cash:  2.8 total: 100.0
# 2009-03-02 TLT:30.6 GLD:27.1 QQQ:21.7 SPY:20.5 cash:  0.1 total: 100.0
# 2009-04-01 TLT:30.8 GLD:26.3 QQQ:18.9 SPY:17.2 cash:  6.8 total: 100.0
# 2009-05-01 TLT:35.1 GLD:25.1 QQQ:20.7 SPY:18.4 cash:  0.8 total: 100.0
# 2009-06-01 TLT:23.1 GLD:36.6 QQQ:20.6 SPY:19.2 cash:  0.6 total: 100.0
# 2009-07-01 TLT:24.7 GLD:26.0 QQQ:24.5 SPY:24.4 cash:  0.4 total: 100.0
# 2009-08-03 TLT:20.0 GLD:29.1 QQQ:23.7 SPY:25.3 cash:  1.9 total: 100.0
# 2009-09-01 TLT:22.6 GLD:29.0 QQQ:21.1 SPY:22.3 cash:  5.0 total: 100.0
# 2009-10-01 TLT:26.7 GLD:27.4 QQQ:21.9 SPY:23.8 cash:  0.1 total: 100.0
# 2009-11-02 TLT:25.2 GLD:26.2 QQQ:24.3 SPY:22.4 cash:  2.0 total: 100.0
# 2009-12-01 TLT:25.3 GLD:22.9 QQQ:20.5 SPY:21.9 cash:  9.3 total: 100.0
# 2010-01-04 TLT:29.2 GLD:13.0 QQQ:26.9 SPY:30.8 cash:  0.1 total: 100.0
# 2010-02-01 TLT:29.9 GLD:12.8 QQQ:20.2 SPY:24.3 cash: 12.8 total: 100.0
# 2010-03-01 TLT:32.4 GLD:18.6 QQQ:24.5 SPY:23.9 cash:  0.7 total: 100.0
# 2010-04-01 TLT:27.0 GLD:16.9 QQQ:28.0 SPY:28.0 cash:  0.2 total: 100.0
# 2010-05-03 TLT:26.5 GLD:16.8 QQQ:20.8 SPY:20.7 cash: 15.2 total: 100.0
# 2010-06-01 TLT:29.3 GLD:32.3 QQQ:17.8 SPY:19.9 cash:  0.7 total: 100.0
# 2010-07-01 TLT:31.6 GLD:23.8 QQQ:20.0 SPY:21.4 cash:  3.1 total: 100.0
# 2010-08-02 TLT:28.5 GLD:26.8 QQQ:20.4 SPY:20.5 cash:  3.7 total: 100.0
# 2010-09-01 TLT:19.5 GLD:40.2 QQQ:19.7 SPY:20.5 cash:  0.1 total: 100.0
# 2010-10-01 TLT:17.8 GLD:31.6 QQQ:25.1 SPY:25.1 cash:  0.4 total: 100.0
# 2010-11-01 TLT:17.1 GLD:17.3 QQQ:25.4 SPY:32.8 cash:  7.4 total: 100.0
# 2010-12-01 TLT:22.1 GLD:18.8 QQQ:25.4 SPY:28.1 cash:  5.5 total: 100.0
# 2011-01-03 TLT:16.3 GLD:22.9 QQQ:30.4 SPY:30.3 cash:  0.1 total: 100.0
# 2011-02-01 TLT:15.8 GLD:20.2 QQQ:23.3 SPY:31.6 cash:  9.1 total: 100.0
# 2011-03-01 TLT:24.9 GLD:21.3 QQQ:19.4 SPY:23.7 cash: 10.7 total: 100.0
# 2011-04-01 TLT:27.7 GLD:28.7 QQQ:19.5 SPY:22.7 cash:  1.3 total: 100.0
# 2011-05-02 TLT:25.0 GLD:21.1 QQQ:25.6 SPY:28.0 cash:  0.2 total: 100.0
# 2011-06-01 TLT:26.5 GLD:21.2 QQQ:21.8 SPY:25.3 cash:  5.3 total: 100.0
# 2011-07-01 TLT:27.7 GLD:23.8 QQQ:18.6 SPY:22.4 cash:  7.5 total: 100.0
# 2011-08-01 TLT:22.2 GLD:32.5 QQQ:20.3 SPY:24.8 cash:  0.2 total: 100.0
# 2011-09-01 TLT:23.7 GLD:28.8 QQQ:21.1 SPY:21.5 cash:  5.0 total: 100.0
# 2011-10-03 TLT:26.0 GLD:22.3 QQQ:27.3 SPY:24.3 cash:  0.2 total: 100.0
# 2011-11-01 TLT:21.5 GLD:24.2 QQQ:22.8 SPY:22.0 cash:  9.6 total: 100.0
# 2011-12-01 TLT:30.5 GLD:24.4 QQQ:19.5 SPY:20.2 cash:  5.5 total: 100.0
# 2012-01-03 TLT:26.2 GLD:20.8 QQQ:26.3 SPY:26.5 cash:  0.2 total: 100.0
# 2012-02-01 TLT:19.7 GLD:22.4 QQQ:28.9 SPY:28.9 cash:  0.2 total: 100.0
# 2012-03-01 TLT:19.0 GLD:13.0 QQQ:32.2 SPY:32.2 cash:  3.6 total: 100.0
# 2012-04-02 TLT:20.6 GLD:13.5 QQQ:29.9 SPY:28.6 cash:  7.4 total: 100.0
# 2012-05-01 TLT:24.4 GLD:17.9 QQQ:20.5 SPY:26.0 cash: 11.2 total: 100.0
# 2012-06-01 TLT:29.2 GLD:20.0 QQQ:22.5 SPY:28.3 cash:  0.0 total: 100.0
# 2012-07-02 TLT:27.8 GLD:19.3 QQQ:20.4 SPY:24.1 cash:  8.5 total: 100.0
# 2012-08-01 TLT:28.0 GLD:27.7 QQQ:19.9 SPY:23.4 cash:  1.1 total: 100.0
# 2012-09-04 TLT:20.6 GLD:24.7 QQQ:27.2 SPY:27.2 cash:  0.3 total: 100.0
# 2012-10-01 TLT:19.9 GLD:25.4 QQQ:23.5 SPY:29.3 cash:  2.0 total: 100.0
# 2012-11-01 TLT:20.9 GLD:26.2 QQQ:20.8 SPY:26.9 cash:  5.3 total: 100.0
# 2012-12-03 TLT:26.4 GLD:26.0 QQQ:19.7 SPY:21.6 cash:  6.3 total: 100.0
# 2013-01-02 TLT:25.4 GLD:31.8 QQQ:17.8 SPY:23.2 cash:  1.8 total: 100.0
# 2013-02-01 TLT:24.9 GLD:25.1 QQQ:25.0 SPY:25.0 cash:  0.0 total: 100.0
# 2013-03-01 TLT:25.8 GLD:23.8 QQQ:23.0 SPY:25.8 cash:  1.6 total: 100.0
# 2013-04-01 TLT:23.8 GLD:25.3 QQQ:24.7 SPY:25.4 cash:  0.8 total: 100.0
# 2013-05-01 TLT:25.9 GLD:11.1 QQQ:25.8 SPY:30.3 cash:  6.9 total: 100.0
# 2013-06-03 TLT:21.9 GLD:13.2 QQQ:32.4 SPY:32.3 cash:  0.2 total: 100.0
# 2013-07-01 TLT:22.0 GLD:12.1 QQQ:28.9 SPY:27.1 cash:  9.9 total: 100.0
# 2013-08-01 TLT:18.1 GLD:16.2 QQQ:32.7 SPY:32.8 cash:  0.1 total: 100.0
# 2013-09-03 TLT:18.1 GLD:17.5 QQQ:25.9 SPY:31.9 cash:  6.5 total: 100.0
# 2013-10-01 TLT:24.7 GLD:11.4 QQQ:30.5 SPY:30.4 cash:  3.1 total: 100.0
# 2013-11-01 TLT:27.1 GLD:11.3 QQQ:23.1 SPY:26.3 cash: 12.2 total: 100.0
# 2013-12-02 TLT:22.6 GLD:19.9 QQQ:26.6 SPY:30.9 cash:  0.0 total: 100.0
# 2014-01-02 TLT:22.4 GLD:14.9 QQQ:28.9 SPY:27.6 cash:  6.2 total: 100.0
# 2014-02-03 TLT:30.2 GLD:15.3 QQQ:19.8 SPY:23.7 cash: 11.0 total: 100.0
# 2014-03-03 TLT:29.8 GLD:24.6 QQQ:21.3 SPY:23.7 cash:  0.5 total: 100.0
# 2014-04-01 TLT:27.2 GLD:21.3 QQQ:22.0 SPY:29.5 cash:  0.0 total: 100.0
# 2014-05-01 TLT:28.1 GLD:21.1 QQQ:15.4 SPY:24.3 cash: 11.2 total: 100.0
# 2014-06-02 TLT:26.4 GLD:23.4 QQQ:23.6 SPY:26.6 cash:  0.1 total: 100.0
# 2014-07-01 TLT:25.5 GLD:19.6 QQQ:26.8 SPY:26.7 cash:  1.5 total: 100.0
# 2014-08-01 TLT:27.5 GLD:19.2 QQQ:22.6 SPY:28.9 cash:  1.7 total: 100.0
# 2014-09-02 TLT:23.2 GLD:23.8 QQQ:23.4 SPY:25.8 cash:  3.8 total: 100.0
# 2014-10-01 TLT:22.9 GLD:28.1 QQQ:20.9 SPY:27.2 cash:  0.8 total: 100.0
# 2014-11-03 TLT:23.7 GLD:26.7 QQQ:16.2 SPY:19.2 cash: 14.2 total: 100.0
# 2014-12-01 TLT:29.5 GLD:11.2 QQQ:29.6 SPY:29.6 cash:  0.2 total: 100.0
# 2015-01-02 TLT:27.0 GLD:14.4 QQQ:25.4 SPY:25.9 cash:  7.3 total: 100.0
# 2015-02-02 TLT:26.6 GLD:23.4 QQQ:23.8 SPY:26.0 cash:  0.1 total: 100.0
# 2015-03-02 TLT:18.1 GLD:22.6 QQQ:29.6 SPY:29.6 cash:  0.1 total: 100.0
# 2015-04-01 TLT:19.2 GLD:22.9 QQQ:25.7 SPY:26.4 cash:  5.8 total: 100.0
# 2015-05-01 TLT:23.8 GLD:19.8 QQQ:23.7 SPY:31.8 cash:  0.9 total: 100.0
# 2015-06-01 TLT:16.9 GLD:26.8 QQQ:24.4 SPY:31.5 cash:  0.3 total: 100.0
# 2015-07-01 TLT:16.9 GLD:27.0 QQQ:23.4 SPY:27.1 cash:  5.8 total: 100.0
# 2015-08-03 TLT:23.7 GLD:25.0 QQQ:22.0 SPY:27.5 cash:  1.9 total: 100.0
# 2015-09-01 TLT:26.4 GLD:27.4 QQQ:14.5 SPY:16.9 cash: 14.8 total: 100.0
# 2015-10-01 TLT:25.9 GLD:31.2 QQQ:20.5 SPY:22.3 cash:  0.1 total: 100.0
# 2015-11-02 TLT:24.5 GLD:24.8 QQQ:21.0 SPY:25.9 cash:  3.8 total: 100.0
# 2015-12-01 TLT:28.8 GLD:23.6 QQQ:21.4 SPY:24.5 cash:  1.6 total: 100.0
# 2016-01-04 TLT:30.9 GLD:24.3 QQQ:20.0 SPY:22.9 cash:  1.8 total: 100.0
# 2016-02-01 TLT:34.0 GLD:25.5 QQQ:15.2 SPY:19.1 cash:  6.3 total: 100.0
# 2016-03-01 TLT:32.1 GLD:21.8 QQQ:20.2 SPY:25.7 cash:  0.2 total: 100.0
# 2016-04-01 TLT:28.1 GLD:16.1 QQQ:26.5 SPY:29.3 cash:  0.1 total: 100.0
# 2016-05-02 TLT:27.7 GLD:17.1 QQQ:22.8 SPY:29.9 cash:  2.6 total: 100.0
# 2016-06-01 TLT:28.6 GLD:18.0 QQQ:22.2 SPY:27.3 cash:  3.8 total: 100.0
# 2016-07-01 TLT:30.3 GLD:22.4 QQQ:21.0 SPY:25.2 cash:  1.2 total: 100.0
# 2016-08-01 TLT:21.5 GLD:20.0 QQQ:29.2 SPY:29.3 cash:  0.0 total: 100.0
# 2016-09-01 TLT:21.6 GLD:19.5 QQQ:25.4 SPY:25.4 cash:  8.0 total: 100.0
# 2016-10-03 TLT:26.9 GLD:21.8 QQQ:20.1 SPY:21.8 cash:  9.3 total: 100.0
# 2016-11-01 TLT:25.0 GLD:25.0 QQQ:25.0 SPY:25.0 cash:  0.1 total: 100.0
# 2016-12-01 TLT:18.9 GLD:24.3 QQQ:21.6 SPY:35.0 cash:  0.2 total: 100.0
# 2017-01-03 TLT:18.8 GLD:22.3 QQQ:23.3 SPY:26.0 cash:  9.6 total: 100.0
# 2017-02-01 TLT:21.8 GLD:23.2 QQQ:27.4 SPY:27.5 cash:  0.1 total: 100.0
# 2017-03-01 TLT:21.2 GLD:23.1 QQQ:26.0 SPY:26.0 cash:  3.7 total: 100.0
# 2017-04-03 TLT:25.0 GLD:23.3 QQQ:25.0 SPY:25.0 cash:  1.8 total: 100.0
# 2017-05-01 TLT:24.4 GLD:25.0 QQQ:25.2 SPY:25.2 cash:  0.2 total: 100.0
# 2017-06-01 TLT:24.7 GLD:24.7 QQQ:23.2 SPY:25.7 cash:  1.7 total: 100.0
# 2017-07-03 TLT:27.1 GLD:24.2 QQQ:16.6 SPY:27.8 cash:  4.4 total: 100.0
# 2017-08-01 TLT:24.9 GLD:25.0 QQQ:22.3 SPY:24.9 cash:  2.8 total: 100.0
# 2017-09-01 TLT:27.2 GLD:26.0 QQQ:18.3 SPY:27.2 cash:  1.3 total: 100.0
# 2017-10-02 TLT:24.2 GLD:22.1 QQQ:25.6 SPY:26.7 cash:  1.4 total: 100.0
# 2017-11-01 TLT:25.2 GLD:21.7 QQQ:22.2 SPY:25.9 cash:  5.1 total: 100.0
# 2017-12-01 TLT:23.9 GLD:26.0 QQQ:24.0 SPY:26.0 cash:  0.2 total: 100.0
# 2018-01-02 TLT:23.5 GLD:25.8 QQQ:24.6 SPY:25.8 cash:  0.3 total: 100.0
# 2018-02-01 TLT:22.3 GLD:25.4 QQQ:23.5 SPY:25.4 cash:  3.4 total: 100.0
# 2018-03-01 TLT:26.1 GLD:25.4 QQQ:13.6 SPY:15.3 cash: 19.6 total: 100.0
# 2018-04-02 TLT:37.8 GLD:31.1 QQQ:13.3 SPY:17.7 cash:  0.1 total: 100.0
# 2018-05-01 TLT:31.9 GLD:31.9 QQQ:14.7 SPY:21.4 cash:  0.1 total: 100.0
# 2018-06-01 TLT:23.2 GLD:27.7 QQQ:23.3 SPY:25.6 cash:  0.1 total: 100.0
# 2018-07-02 TLT:23.8 GLD:26.4 QQQ:20.6 SPY:26.4 cash:  2.8 total: 100.0
# 2018-08-01 TLT:25.9 GLD:25.8 QQQ:18.1 SPY:27.3 cash:  2.9 total: 100.0
# 2018-09-04 TLT:26.2 GLD:20.9 QQQ:25.3 SPY:26.3 cash:  1.3 total: 100.0
# 2018-10-01 TLT:25.8 GLD:21.9 QQQ:22.4 SPY:25.7 cash:  4.2 total: 100.0
# 2018-11-01 TLT:30.3 GLD:23.3 QQQ:10.9 SPY:16.4 cash: 19.0 total: 100.0
# 2018-12-03 TLT:34.8 GLD:34.8 QQQ:12.2 SPY:18.0 cash:  0.2 total: 100.0
# 2019-01-02 TLT:36.8 GLD:36.2 QQQ:10.3 SPY:13.1 cash:  3.6 total: 100.0
# 2019-02-01 TLT:32.5 GLD:32.5 QQQ:14.4 SPY:20.6 cash:  0.1 total: 100.0
# 2019-03-01 TLT:25.7 GLD:23.1 QQQ:25.6 SPY:25.5 cash:  0.1 total: 100.0
# 2019-04-01 TLT:26.4 GLD:22.4 QQQ:19.3 SPY:23.6 cash:  8.3 total: 100.0
# 2019-05-01 TLT:25.0 GLD:25.0 QQQ:25.0 SPY:25.0 cash:  0.1 total: 100.0
# 2019-06-03 TLT:27.3 GLD:26.3 QQQ:15.7 SPY:21.5 cash:  9.2 total: 100.0
# 2019-07-01 TLT:30.4 GLD:21.2 QQQ:19.8 SPY:28.6 cash:  0.0 total: 100.0
# 2019-08-01 TLT:25.1 GLD:17.7 QQQ:27.2 SPY:30.0 cash:  0.1 total: 100.0
# 2019-09-03 TLT:26.7 GLD:18.4 QQQ:18.3 SPY:21.0 cash: 15.6 total: 100.0
# 2019-10-01 TLT:19.5 GLD:22.1 QQQ:24.4 SPY:33.9 cash:  0.1 total: 100.0
# 2019-11-01 TLT:18.6 GLD:21.9 QQQ:21.8 SPY:27.8 cash:  9.9 total: 100.0
# 2019-12-02 TLT:20.2 GLD:26.5 QQQ:24.9 SPY:26.5 cash:  1.9 total: 100.0
# 2020-01-02 TLT:21.1 GLD:25.8 QQQ:25.8 SPY:25.8 cash:  1.5 total: 100.0
# 2020-02-03 TLT:23.3 GLD:25.9 QQQ:20.1 SPY:24.5 cash:  6.2 total: 100.0
# 2020-03-02 TLT:31.0 GLD:26.2 QQQ:15.5 SPY:18.1 cash:  9.2 total: 100.0
# 2020-04-01 TLT:24.4 GLD:41.3 QQQ:17.1 SPY:16.8 cash:  0.3 total: 100.0
# 2020-05-01 TLT:22.8 GLD:30.6 QQQ:15.8 SPY:16.8 cash: 14.0 total: 100.0
# 2020-06-01 TLT:25.6 GLD:29.8 QQQ:23.8 SPY:20.6 cash:  0.1 total: 100.0
# 2020-07-01 TLT:25.2 GLD:29.5 QQQ:17.3 SPY:15.6 cash: 12.5 total: 100.0
# 2020-08-03 TLT:31.9 GLD:28.1 QQQ:14.6 SPY:25.0 cash:  0.3 total: 100.0
# 2020-09-01 TLT:29.2 GLD:12.7 QQQ:21.3 SPY:36.7 cash:  0.1 total: 100.0
# 2020-10-01 TLT:29.7 GLD:12.5 QQQ:11.2 SPY:17.0 cash: 29.6 total: 100.0
# 2020-11-02 TLT:36.9 GLD:28.9 QQQ:15.1 SPY:19.0 cash:  0.1 total: 100.0
# 2020-12-01 TLT:28.7 GLD:21.2 QQQ:20.0 SPY:29.5 cash:  0.6 total: 100.0
# 2021-01-04 TLT:28.5 GLD:20.2 QQQ:22.1 SPY:28.4 cash:  0.7 total: 100.0
# 2021-02-01 TLT:28.2 GLD:19.3 QQQ:17.5 SPY:24.1 cash: 10.9 total: 100.0
# 2021-03-01 TLT:26.1 GLD:26.0 QQQ:19.6 SPY:28.2 cash:  0.2 total: 100.0
# 2021-04-01 TLT:25.6 GLD:26.0 QQQ:15.0 SPY:30.4 cash:  3.0 total: 100.0
# 2021-05-03 TLT:27.5 GLD:24.1 QQQ:17.6 SPY:27.4 cash:  3.3 total: 100.0
# 2021-06-01 TLT:30.5 GLD:25.3 QQQ:15.4 SPY:22.2 cash:  6.6 total: 100.0
# 2021-07-01 TLT:21.9 GLD:19.5 QQQ:28.4 SPY:30.0 cash:  0.1 total: 100.0
# 2021-08-02 TLT:18.7 GLD:22.8 QQQ:27.3 SPY:25.3 cash:  6.0 total: 100.0
# 2021-09-01 TLT:24.1 GLD:18.3 QQQ:26.8 SPY:28.5 cash:  2.2 total: 100.0
# 2021-10-01 TLT:24.3 GLD:20.7 QQQ:24.8 SPY:26.7 cash:  3.5 total: 100.0
# 2021-11-01 TLT:20.1 GLD:25.2 QQQ:25.8 SPY:28.8 cash:  0.0 total: 100.0
# 2021-12-01 TLT:20.2 GLD:25.7 QQQ:22.1 SPY:28.9 cash:  3.1 total: 100.0
# 2022-01-03 TLT:21.7 GLD:25.4 QQQ:16.3 SPY:23.3 cash: 13.2 total: 100.0
# 2022-02-01 TLT:29.8 GLD:32.0 QQQ:14.6 SPY:22.3 cash:  1.2 total: 100.0
# 2022-03-01 TLT:27.4 GLD:37.8 QQQ:13.7 SPY:20.5 cash:  0.7 total: 100.0
# 2022-04-01 TLT:26.6 GLD:27.4 QQQ:17.6 SPY:25.0 cash:  3.4 total: 100.0
# 2022-05-02 TLT:29.0 GLD:29.1 QQQ:14.0 SPY:19.5 cash:  8.4 total: 100.0
# 2022-06-01 TLT:26.2 GLD:40.5 QQQ:13.4 SPY:17.8 cash:  2.1 total: 100.0
# 2022-07-01 TLT:25.0 GLD:40.1 QQQ:15.6 SPY:19.2 cash:  0.1 total: 100.0
# 2022-08-01 TLT:25.1 GLD:32.6 QQQ:17.4 SPY:24.3 cash:  0.7 total: 100.0
# 2022-09-01 TLT:23.3 GLD:34.7 QQQ:16.9 SPY:21.1 cash:  4.0 total: 100.0
# 2022-10-03 TLT:24.0 GLD:34.2 QQQ:19.3 SPY:22.3 cash:  0.1 total: 100.0
# 2022-11-01 TLT:23.2 GLD:34.0 QQQ:16.2 SPY:20.1 cash:  6.6 total: 100.0
# 2022-12-01 TLT:26.5 GLD:32.5 QQQ:17.3 SPY:23.6 cash:  0.1 total: 100.0
# 2023-01-03 TLT:21.9 GLD:31.5 QQQ:20.7 SPY:25.8 cash:  0.1 total: 100.0
# 2023-02-01 TLT:21.8 GLD:31.0 QQQ:19.3 SPY:25.8 cash:  2.0 total: 100.0
# 2023-03-01 TLT:23.6 GLD:29.9 QQQ:16.5 SPY:27.3 cash:  2.7 total: 100.0
# 2023-04-03 TLT:24.4 GLD:23.8 QQQ:24.7 SPY:26.9 cash:  0.1 total: 100.0
# 2023-05-01 TLT:20.2 GLD:27.2 QQQ:22.6 SPY:30.0 cash:  0.1 total: 100.0
# 2023-06-01 TLT:19.9 GLD:26.5 QQQ:19.2 SPY:26.0 cash:  8.4 total: 100.0
# 2023-07-03 TLT:21.4 GLD:30.2 QQQ:18.1 SPY:30.2 cash:  0.1 total: 100.0
# 2023-08-01 TLT:20.6 GLD:27.2 QQQ:21.0 SPY:30.4 cash:  0.8 total: 100.0
# 2023-09-01 TLT:20.7 GLD:27.9 QQQ:18.7 SPY:27.5 cash:  5.2 total: 100.0
# 2023-10-02 TLT:19.9 GLD:30.8 QQQ:20.9 SPY:28.4 cash:  0.1 total: 100.0
# 2023-11-01 TLT:17.6 GLD:28.7 QQQ:23.0 SPY:30.7 cash:  0.1 total: 100.0
# 2023-12-01 TLT:16.4 GLD:25.9 QQQ:25.2 SPY:32.4 cash:  0.1 total: 100.0
# 2024-01-02 TLT:17.0 GLD:22.4 QQQ:25.0 SPY:33.8 cash:  1.8 total: 100.0
# 2024-02-01 TLT:18.3 GLD:21.8 QQQ:20.7 SPY:27.5 cash: 11.7 total: 100.0
# 2024-03-01 TLT:21.3 GLD:29.0 QQQ:19.8 SPY:28.1 cash:  1.9 total: 100.0
# 2024-04-01 TLT:22.2 GLD:26.3 QQQ:20.5 SPY:29.4 cash:  1.6 total: 100.0
# 2024-05-01 TLT:23.4 GLD:21.6 QQQ:21.0 SPY:29.3 cash:  4.6 total: 100.0
# 2024-06-03 TLT:23.2 GLD:17.5 QQQ:29.6 SPY:29.6 cash:  0.1 total: 100.0
# 2024-07-01 TLT:19.2 GLD:18.0 QQQ:28.8 SPY:33.9 cash:  0.2 total: 100.0
# 2024-08-01 TLT:20.2 GLD:18.5 QQQ:15.6 SPY:25.7 cash: 20.0 total: 100.0
# 2024-09-03 TLT:28.9 GLD:28.0 QQQ:17.4 SPY:25.6 cash:  0.2 total: 100.0
# 2024-10-01 TLT:28.2 GLD:23.8 QQQ:17.4 SPY:27.0 cash:  3.5 total: 100.0
# 2024-11-01 TLT:26.6 GLD:25.4 QQQ:19.8 SPY:28.1 cash:  0.1 total: 100.0
# 2024-12-02 TLT:22.2 GLD:18.4 QQQ:24.9 SPY:34.2 cash:  0.3 total: 100.0
# 2025-01-02 TLT:21.3 GLD:18.8 QQQ:18.2 SPY:25.2 cash: 16.5 total: 100.0
# 2025-02-03 TLT:30.3 GLD:26.3 QQQ:16.6 SPY:24.2 cash:  2.6 total: 100.0
# 2025-03-03 TLT:26.6 GLD:26.1 QQQ:19.6 SPY:27.5 cash:  0.2 total: 100.0
# 2025-04-01 TLT:26.5 GLD:28.0 QQQ:14.2 SPY:19.1 cash: 12.2 total: 100.0
# 2025-05-01 TLT:37.8 GLD:27.6 QQQ:14.2 SPY:15.9 cash:  4.5 total: 100.0
# 2025-06-02 TLT:35.5 GLD:15.5 QQQ:22.5 SPY:26.3 cash:  0.2 total: 100.0
# 2025-07-01 TLT:25.0 GLD:20.1 QQQ:24.2 SPY:30.5 cash:  0.3 total: 100.0
# 2025-08-01 TLT:23.0 GLD:19.2 QQQ:27.2 SPY:28.8 cash:  1.8 total: 100.0
# 2025-09-02 TLT:23.8 GLD:19.8 QQQ:21.9 SPY:28.1 cash:  6.5 total: 100.0
# 2025-10-01 TLT:25.3 GLD:21.7 QQQ:25.1 SPY:26.4 cash:  1.4 total: 100.0
# 2025-11-03 TLT:26.2 GLD:11.5 QQQ:20.3 SPY:27.5 cash: 14.4 total: 100.0
# 2025-12-01 TLT:37.2 GLD:15.5 QQQ:17.4 SPY:24.7 cash:  5.3 total: 100.0
# 2026-01-02 TLT:30.7 GLD:15.2 QQQ:23.2 SPY:30.7 cash:  0.2 total: 100.0
# 2026-02-02 TLT:30.2 GLD: 7.1 QQQ:25.1 SPY:33.2 cash:  4.4 total: 100.0
# 2026-03-02 TLT:35.4 GLD: 8.0 QQQ:21.3 SPY:29.9 cash:  5.3 total: 100.0
# 2026-04-01 TLT:38.0 GLD:10.8 QQQ:21.4 SPY:26.6 cash:  3.2 total: 100.0
# 2026-05-01 TLT:33.3 GLD:15.5 QQQ:21.7 SPY:28.0 cash:  1.5 total: 100.0
# 2026-06-01 TLT:32.0 GLD:15.7 QQQ:20.0 SPY:32.1 cash:  0.2 total: 100.0
# 2026-06-08 TLT: 0.0 GLD: 0.0 QQQ: 0.0 SPY: 0.0 cash: 100.0 total: 100.0

# %% [markdown]
# View log DataFrames: raw trade log, trade log, and daily balance.

# %%
s.rlog.head()
# Out:
#         date  seq_num  price  shares entry_exit direction symbol
# 0 2007-11-20        0  52.74     878      entry      LONG    TLT
# 0 2007-11-20        1  79.47     202      entry      LONG    GLD
# 0 2007-11-20        2  42.83     371      entry      LONG    QQQ
# 0 2007-11-20        3 102.48     211      entry      LONG    SPY
# 1 2007-12-03        4  78.28       1      entry      LONG    GLD

# %%
s.tlog.tail()
# Out:
#     entry_date  entry_price  exit_date  exit_price  pl_points  pl_cash  qty  \
# 164 2026-04-01       437.82 2026-06-08      397.27     -40.55 -2108.60   52
# 165 2026-05-01       423.18 2026-06-08      397.27     -25.91 -2513.27   97
# 218 2026-05-01       718.80 2026-06-08      737.32      18.52    55.57    3
# 166 2026-06-01       411.26 2026-06-08      397.27     -13.99  -265.81   19
# 219 2026-06-01       756.59 2026-06-08      737.32     -19.27  -693.73   36
#
#      cumul_total direction symbol
# 164    605656.34      LONG    GLD
# 165    603143.07      LONG    GLD
# 218    603198.63      LONG    SPY
# 166    602932.82      LONG    GLD
# 219    602239.09      LONG    SPY

# %%
s.dbal.tail()
# Out:
#                 high       low     close  shares      cash  leverage state
# date
# 2026-06-02 750640.06 750640.06 750640.06    3608   1675.90      1.00     -
# 2026-06-03 746440.17 746440.17 746440.17    3608   1675.90      1.00     -
# 2026-06-04 748119.32 748119.32 748119.32    3608   1675.90      1.00     -
# 2026-06-05 729231.47 729231.47 729231.47    3608   1675.90      1.00     -
# 2026-06-08 702239.09 702239.09 702239.09       0 702239.09      1.00     X

# %% [markdown]
# Generate strategy stats - display all available stats.

# %%
pf.print_full(s.stats)
# Out:
# start                                                   2007-11-20
# end                                                     2026-06-08
# beginning_balance                                           100000
# ending_balance                                           702239.09
# total_net_profit                                         602239.09
# gross_profit                                             714794.23
# gross_loss                                              -112555.14
# profit_factor                                                 6.35
# return_on_initial_capital                                   602.24
# annual_return_rate                                           11.08
# trading_period                           18 years 6 months 19 days
# pct_time_in_market                                          100.00
# margin                                                           1
# avg_leverage                                                  1.00
# max_leverage                                                  1.00
# min_leverage                                                  1.00
# total_num_trades                                               822
# trades_per_year                                              44.31
# num_winning_trades                                             644
# num_losing_trades                                              178
# num_even_trades                                                  0
# pct_profitable_trades                                        78.35
# avg_profit_per_trade                                        732.65
# avg_profit_per_winning_trade                               1109.93
# avg_loss_per_losing_trade                                  -632.33
# ratio_avg_profit_win_loss                                     1.76
# largest_profit_winning_trade                              16391.64
# largest_loss_losing_trade                                 -7711.08
# num_winning_points                                        23891.49
# num_losing_points                                         -2719.05
# total_net_points                                          21172.44
# avg_points                                                   25.76
# largest_points_winning_trade                                221.81
# largest_points_losing_trade                                 -75.15
# avg_pct_gain_per_trade                                       14.53
# largest_pct_winning_trade                                    98.54
# largest_pct_losing_trade                                    -41.05
# expected_shortfall                                          -38.03
# max_consecutive_winning_trades                                  95
# max_consecutive_losing_trades                                   14
# avg_bars_winning_trades                                     322.16
# avg_bars_losing_trades                                      315.35
# max_closed_out_drawdown                                     -24.86
# max_closed_out_drawdown_peak_date                       2021-12-27
# max_closed_out_drawdown_trough_date                     2022-11-03
# max_closed_out_drawdown_recovery_date                   2024-03-27
# drawdown_loss_period                                           311
# drawdown_recovery_period                                       510
# annualized_return_over_max_drawdown                           0.45
# max_intra_day_drawdown                                      -24.86
# avg_yearly_closed_out_drawdown                               -7.85
# max_yearly_closed_out_drawdown                              -24.86
# avg_monthly_closed_out_drawdown                              -2.24
# max_monthly_closed_out_drawdown                             -13.41
# avg_weekly_closed_out_drawdown                               -0.89
# max_weekly_closed_out_drawdown                               -8.43
# avg_yearly_closed_out_runup                                  18.59
# max_yearly_closed_out_runup                                  43.85
# avg_monthly_closed_out_runup                                  3.05
# max_monthly_closed_out_runup                                 18.63
# avg_weekly_closed_out_runup                                   1.11
# max_weekly_closed_out_runup                                   8.94
# pct_profitable_years                                         87.20
# best_year                                                    38.73
# worst_year                                                  -23.28
# avg_year                                                     12.39
# annual_std                                                   11.68
# pct_profitable_months                                        66.26
# best_month                                                   18.63
# worst_month                                                 -13.41
# avg_month                                                     0.90
# monthly_std                                                   2.76
# pct_profitable_weeks                                         59.70
# best_week                                                     8.94
# worst_week                                                   -8.30
# avg_week                                                      0.22
# weekly_std                                                    1.38
# pct_profitable_days                                          55.66
# best_day                                                      4.70
# worst_day                                                    -3.78
# avg_day                                                       0.04
# daily_std                                                     0.62
# sharpe_ratio                                                  1.11
# sharpe_ratio_max                                              1.17
# sharpe_ratio_min                                              1.06
# sortino_ratio                                                 1.54
# dtype: object

# %% [markdown]
# View Performance by Symbol

# %%
symbols_no_weights = [k for k,v in weights.items() if v is None]
symbols_weights    = {k:v for k,v in weights.items() if v is not None}
remaining_weight   = 1 - sum(symbols_weights.values())

weights_ = weights.copy()
for symbol in symbols_no_weights:
    weights_[symbol] = (1 / len(symbols_no_weights)) * remaining_weight
totals = s.portfolio.performance_per_symbol(weights=weights_)
totals
# Out:
#        cumul_total  weight  pct_cumul_total  relative_performance
# TLT      $6,405.31    0.25             0.01                  0.04
# GLD    $165,967.70    0.25             0.28                  1.10
# QQQ    $231,976.00    0.25             0.39                  1.54
# SPY    $197,890.08    0.25             0.33                  1.31
# TOTAL  $602,239.09    1.00             1.00                  1.00

# %%
corr_df = s.portfolio.correlation_map(s.ts)
corr_df
# Out:
#       TLT  GLD   QQQ   SPY
# TLT  1.00 0.17 -0.26 -0.31
# GLD  0.17 1.00  0.04  0.05
# QQQ -0.26 0.04  1.00  0.93
# SPY -0.31 0.05  0.93  1.00

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats.

# %%
benchmark = pf.Benchmark('SPY', s.capital, s.start, s.end, use_adj=True)
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                      11.08      11.18
# max_closed_out_drawdown                -24.86     -53.87
# annualized_return_over_max_drawdown      0.45       0.21
# best_month                              18.63      23.61
# worst_month                            -13.41     -30.99
# sharpe_ratio                             1.11       0.63
# sortino_ratio                            1.54       0.78
# monthly_std                              2.76       4.70
# annual_std                              11.68      16.09

# %% [markdown]
# Analysis: Kelly Criterian

# %%
kelly = pf.kelly_criterion(s.stats, benchmark.stats)
kelly
# Out:
# sharpe_ratio            1.11
# sharpe_ratio_max        1.17
# sharpe_ratio_min        1.06
# strategy risk           0.12
# instrument risk         0.16
# optimal target risk     1.11
# half kelly criterion    0.56
# aggressive leverage     6.91
# moderate leverage       3.46
# conservative leverage   3.28
# dtype: float64
