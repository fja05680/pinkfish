# %% [markdown]
# # Dual Momentum Sector Rotation (DMSR)
#
# 'Relative momentum looks at price strength with respect to other assets.
# Absolute momentum uses an asset’s own past performance to infer future
# performance. Absolute momentum can reduce downside exposure as well
# enhance returns. The best approach is to use both types of momentum
# together. That is what dual momentum is all about.'
# https://www.optimalmomentum.com/momentum/
#
# **Buy Signal**: When the S&P 500 is above its 10-month simple moving average, buy the sectors with the biggest gains over a three-month timeframe and (optionally) has positive absolute momentum.
#
# **Sell Signal**: (Optionally) Exit all positions when the S&P 500 moves below its 10-month simple moving average on a monthly closing basis, or (optionaly) exit a single position if it has negative absolute momentum.
#
# **Rebalance**: Once per month, sell sectors that fall out of the top tier (three) and buy the sectors that move into the top tier (two or three).
#
# https://school.stockcharts.com/doku.php?id=trading_strategies:sector_rotation_roc
# https://robotwealth.com/dual-momentum-review/
#
# You can reproduce the results on robowealth by setting the 'end' date to (2017, 1, 1).  You can also note that these methods have NOT done so well since 2018, and especially didn't handle the COVID downturn very well.

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd

import pinkfish as pf
import strategy

# Format price data.
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# Set size of inline plots.
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
SP500_Sectors = ['SPY', 'XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLP', 'XLU', 'XLV', 'XLY']

Other_Sectors = ['RSP', 'DIA', 'IWM', 'QQQ', 'DAX', 'EEM', 'TLT', 'GLD', 'XHB']

Diversified_Assets = ['SPY', 'TLT', 'NLY', 'GLD']

Diversified_Assets_Reddit = ['IWB', 'IEV', 'EWJ', 'EPP', 'IEF', 'SHY', 'GLD']

Robot_Dual_Momentum_Equities = ['SPY', 'CWI']

Robot_Dual_Momentum_Bonds = ['CSJ', 'HYG']

Robot_Dual_Momentum_Equities_Bonds = ['SPY', 'AGG']

Robot_Wealth = ['IWM', 'SPY', 'VGK', 'IEV', 'EWJ', 'EPP', 'IEF', 'SHY', 'GLD']


# Pick one of the above
symbols = SP500_Sectors

capital = 10000
start = datetime.datetime(2007, 1, 1)
#start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()
#end = datetime.datetime(2019, 12, 1)

# %%
options = {
    'use_adj' : True,
    'use_cache' : True,
    'lookback': 6,
    'margin': 1,
    'use_absolute_mom': False,
    'use_regime_filter': False,
    'top_tier': 2
    #'top_tier': int(len(symbols)/2)
}
options
# Out:
# {'use_adj': True,
#  'use_cache': True,
#  'lookback': 6,
#  'margin': 1,
#  'use_absolute_mom': False,
#  'use_regime_filter': False,
#  'top_tier': 2}

# %% [markdown]
# Run Strategy

# %%
s = strategy.Strategy(symbols, capital, start, end, options)
s.run()

# %% [markdown]
# View logs

# %%
s.rlog.head()
# Out:
#         date  seq_num  price  shares entry_exit direction symbol
# 0 2007-07-02        0  19.82     252      entry      LONG    XLE
# 0 2007-07-02        1  13.68     365      entry      LONG    XLB
# 1 2007-08-01        2  13.18     365       exit      LONG    XLB
# 1 2007-08-01        3  19.43       2       exit      LONG    XLE
# 0 2007-08-01        4  27.57     176      entry      LONG    XLI

# %%
s.tlog.tail()
# Out:
#    entry_date  entry_price  exit_date  exit_price  pl_points  pl_cash  qty  \
# 22 2026-04-01        50.46 2026-05-01       51.35       0.89     5.34    6
# 23 2026-04-01        50.46 2026-06-01       50.92       0.46   295.78  643
# 62 2026-05-01        58.85 2026-06-08       58.33      -0.52    -3.12    6
# 65 2026-06-01       195.76 2026-06-08      184.18     -11.58 -1910.70  165
# 63 2026-06-01        57.30 2026-06-08       58.33       1.03     5.15    5
#
#     cumul_total direction symbol
# 22     55177.37      LONG    XLB
# 23     55473.15      LONG    XLB
# 62     55470.03      LONG    XLE
# 65     53559.33      LONG    XLK
# 63     53564.48      LONG    XLE

# %%
s.dbal.tail()
# Out:
#                high      low    close  shares     cash  leverage state
# date
# 2026-06-02 65670.01 65670.01 65670.01     731   160.00      1.00     -
# 2026-06-03 65767.81 65767.81 65767.81     731   160.00      1.00     -
# 2026-06-04 65285.55 65285.55 65285.55     731   160.00      1.00     -
# 2026-06-05 62550.72 62550.72 62550.72     731   160.00      1.00     -
# 2026-06-08 63564.48 63564.48 63564.48       0 63564.48      1.00     X

# %% [markdown]
# Generate strategy stats - display all available stats

# %%
pf.print_full(s.stats)
# Out:
# start                                                    2007-06-11
# end                                                      2026-06-08
# beginning_balance                                             10000
# ending_balance                                             63564.48
# total_net_profit                                           53564.48
# gross_profit                                               84734.40
# gross_loss                                                -31169.92
# profit_factor                                                  2.72
# return_on_initial_capital                                    535.64
# annual_return_rate                                            10.23
# trading_period                           18 years 11 months 28 days
# pct_time_in_market                                            99.69
# margin                                                            1
# avg_leverage                                                   1.00
# max_leverage                                                   1.00
# min_leverage                                                   1.00
# total_num_trades                                                430
# trades_per_year                                               22.64
# num_winning_trades                                              302
# num_losing_trades                                               128
# num_even_trades                                                   0
# pct_profitable_trades                                         70.23
# avg_profit_per_trade                                         124.57
# avg_profit_per_winning_trade                                 280.58
# avg_loss_per_losing_trade                                   -243.51
# ratio_avg_profit_win_loss                                      1.15
# largest_profit_winning_trade                                7328.99
# largest_loss_losing_trade                                  -2612.15
# num_winning_points                                          1059.53
# num_losing_points                                           -289.73
# total_net_points                                             769.80
# avg_points                                                     1.79
# largest_points_winning_trade                                  30.05
# largest_points_losing_trade                                  -14.94
# avg_pct_gain_per_trade                                         4.81
# largest_pct_winning_trade                                     63.89
# largest_pct_losing_trade                                     -31.72
# expected_shortfall                                           -21.61
# max_consecutive_winning_trades                                   13
# max_consecutive_losing_trades                                    11
# avg_bars_winning_trades                                       72.07
# avg_bars_losing_trades                                        43.30
# max_closed_out_drawdown                                      -45.07
# max_closed_out_drawdown_peak_date                        2007-07-19
# max_closed_out_drawdown_trough_date                      2009-03-09
# max_closed_out_drawdown_recovery_date                    2013-01-24
# drawdown_loss_period                                            599
# drawdown_recovery_period                                       1417
# annualized_return_over_max_drawdown                            0.23
# max_intra_day_drawdown                                       -45.07
# avg_yearly_closed_out_drawdown                               -14.85
# max_yearly_closed_out_drawdown                               -45.07
# avg_monthly_closed_out_drawdown                               -4.33
# max_monthly_closed_out_drawdown                              -26.20
# avg_weekly_closed_out_drawdown                                -1.76
# max_weekly_closed_out_drawdown                               -15.94
# avg_yearly_closed_out_runup                                   26.64
# max_yearly_closed_out_runup                                   98.50
# avg_monthly_closed_out_runup                                   5.18
# max_monthly_closed_out_runup                                  30.82
# avg_weekly_closed_out_runup                                    2.00
# max_weekly_closed_out_runup                                   17.74
# pct_profitable_years                                          88.38
# best_year                                                     84.53
# worst_year                                                   -39.39
# avg_year                                                      11.76
# annual_std                                                    14.53
# pct_profitable_months                                         63.23
# best_month                                                    25.24
# worst_month                                                  -26.20
# avg_month                                                      0.90
# monthly_std                                                    4.67
# pct_profitable_weeks                                          58.25
# best_week                                                     17.74
# worst_week                                                   -15.94
# avg_week                                                       0.23
# weekly_std                                                     2.51
# pct_profitable_days                                           53.91
# best_day                                                       9.22
# worst_day                                                    -11.77
# avg_day                                                        0.05
# daily_std                                                      1.23
# sharpe_ratio                                                   0.60
# sharpe_ratio_max                                               0.64
# sharpe_ratio_min                                               0.55
# sortino_ratio                                                  0.78
# dtype: object

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats

# %%
benchmark = pf.Benchmark('SPY', s.capital, s.start, s.end, use_adj=True)
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                      10.23      10.76
# max_closed_out_drawdown                -45.07     -54.86
# annualized_return_over_max_drawdown      0.23       0.20
# best_month                              25.24      23.49
# worst_month                            -26.20     -30.96
# sharpe_ratio                             0.60       0.62
# sortino_ratio                            0.78       0.76
# monthly_std                              4.67       4.68
# annual_std                              14.53      16.77
