# %% [markdown]
# # Monthly SMA
#
# The Monthly SMA.
#
# Entry and Exit Points
# Entry (Buy Signal): Buy when the S&P 500 closes above the 10-month moving
# average at the end of the month.
#
# Exit (Sell Signal): Sell when the S&P 500 closes below the 10-month moving
# average at the end of the month.

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd

import pinkfish as pf
import strategy

# Format price data
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# Set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
symbol = '^GSPC'
#symbol = 'SPY'
#symbol = 'ES=F'
#symbol = 'DIA'
#symbol = 'QQQ'
#symbol = 'IWM'
#symbol = 'TLT'
#symbol = 'GLD'
#symbol = 'AAPL'
#symbol = 'BBRY'
#symbol = 'GDX'
capital = 10000
start = datetime.datetime(1900, 1, 1)
#start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()

# %%
options = {
    'use_adj' : False,
    'use_cache' : True,
    'monthly_sma' : 10
}

# %% [markdown]
# Run Strategy

# %%
s = strategy.Strategy(symbol, capital, start, end, options)
s.run()
s.ts
# Out:
#              close  adj_close      volume  monthly_sma  last_dotm
# date
# 1928-10-01   21.36      21.36           0        19.21      False
# 1928-10-02   21.26      21.26           0        19.21      False
# 1928-10-03   21.19      21.19           0        19.21      False
# 1928-10-04   21.26      21.26           0        19.21      False
# 1928-10-05   21.22      21.22           0        19.21      False
# ...            ...        ...         ...          ...        ...
# 2026-06-02 7609.78    7609.78  5904410000      6881.90      False
# 2026-06-03 7553.68    7553.68  5753860000      6881.90      False
# 2026-06-04 7584.31    7584.31  5398910000      6881.90      False
# 2026-06-05 7383.74    7383.74  5591290000      6881.90      False
# 2026-06-08 7405.73    7405.73  4898180000      6881.90      False
#
# [24536 rows x 5 columns]

# %% [markdown]
# View logs

# %%
s.tlog.tail(10)
# Out:
#    entry_date  entry_price  exit_date  exit_price  pl_points    pl_cash  qty  \
# 65 2018-11-30      2760.17 2018-12-31     2506.85    -253.32 -224694.68  887
# 66 2019-02-28      2784.49 2019-05-31     2752.06     -32.43  -25879.09  798
# 67 2019-06-28      2941.76 2020-02-28     2954.22      12.46    9307.59  747
# 68 2020-05-29      3044.31 2022-02-28     4373.94    1329.63  963981.67  725
# 69 2022-03-31      4530.41 2022-04-29     4131.93    -398.48 -278935.99  700
# 70 2022-11-30      4080.11 2022-12-30     3839.50    -240.61 -170351.96  708
# 71 2023-01-31      4076.60 2023-10-31     4193.80     117.20   78172.20  667
# 72 2023-11-30      4567.80 2025-03-31     5611.85    1044.05  640002.83  613
# 73 2025-05-30      5911.69 2026-03-31     6528.52     616.83  358378.28  581
# 74 2026-04-30      7209.01 2026-06-08     7405.73     196.72  103474.83  526
#
#     cumul_total direction symbol
# 65   2214169.04      LONG  ^GSPC
# 66   2188289.95      LONG  ^GSPC
# 67   2197597.54      LONG  ^GSPC
# 68   3161579.21      LONG  ^GSPC
# 69   2882643.22      LONG  ^GSPC
# 70   2712291.26      LONG  ^GSPC
# 71   2790463.47      LONG  ^GSPC
# 72   3430466.30      LONG  ^GSPC
# 73   3788844.57      LONG  ^GSPC
# 74   3892319.41      LONG  ^GSPC

# %%
s.dbal.tail(10)
# Out:
#                  high        low      close  shares       cash  leverage state
# date
# 2026-05-26 3961962.62 3961962.62 3961962.62     526    6905.44      1.00     -
# 2026-05-27 3962614.72 3962614.72 3962614.72     526    6905.44      1.00     -
# 2026-05-28 3985374.75 3985374.75 3985374.75     526    6905.44      1.00     -
# 2026-05-29 3994017.03 3994017.03 3994017.03     526    6905.44      1.00     -
# 2026-06-01 4004484.38 4004484.38 4004484.38     526    6905.44      1.00     -
# 2026-06-02 4009649.60 4009649.60 4009649.60     526    6905.44      1.00     -
# 2026-06-03 3980141.21 3980141.21 3980141.21     526    6905.44      1.00     -
# 2026-06-04 3996252.53 3996252.53 3996252.53     526    6905.44      1.00     -
# 2026-06-05 3890752.80 3890752.80 3890752.80     526    6905.44      1.00     -
# 2026-06-08 3902319.41 3902319.41 3902319.41       0 3902319.41      1.00     X

# %% [markdown]
# Display all available stats

# %%
pf.print_full(s.stats)
# Out:
# start                                                  1928-10-01
# end                                                    2026-06-08
# beginning_balance                                           10000
# ending_balance                                         3902319.41
# total_net_profit                                       3892319.41
# gross_profit                                           4854189.46
# gross_loss                                             -961870.06
# profit_factor                                                5.05
# return_on_initial_capital                                38923.19
# annual_return_rate                                           6.30
# trading_period                           97 years 8 months 7 days
# pct_time_in_market                                          68.28
# margin                                                          1
# avg_leverage                                                 1.00
# max_leverage                                                 1.00
# min_leverage                                                 1.00
# total_num_trades                                               75
# trades_per_year                                              0.77
# num_winning_trades                                             43
# num_losing_trades                                              32
# num_even_trades                                                 0
# pct_profitable_trades                                       57.33
# avg_profit_per_trade                                     51897.59
# avg_profit_per_winning_trade                            112888.13
# avg_loss_per_losing_trade                               -30058.44
# ratio_avg_profit_win_loss                                    3.76
# largest_profit_winning_trade                            963981.67
# largest_loss_losing_trade                              -278935.99
# num_winning_points                                        6489.98
# num_losing_points                                        -1216.22
# total_net_points                                          5273.76
# avg_points                                                  70.32
# largest_points_winning_trade                              1329.63
# largest_points_losing_trade                               -398.48
# avg_pct_gain_per_trade                                      10.20
# largest_pct_winning_trade                                  108.44
# largest_pct_losing_trade                                   -21.93
# expected_shortfall                                         -21.93
# max_consecutive_winning_trades                                  4
# max_consecutive_losing_trades                                   4
# avg_bars_winning_trades                                    350.47
# avg_bars_losing_trades                                      54.91
# max_closed_out_drawdown                                    -52.69
# max_closed_out_drawdown_peak_date                      1929-09-16
# max_closed_out_drawdown_trough_date                    1933-02-27
# max_closed_out_drawdown_recovery_date                  1936-07-14
# drawdown_loss_period                                         1260
# drawdown_recovery_period                                     1233
# annualized_return_over_max_drawdown                          0.12
# max_intra_day_drawdown                                     -52.69
# avg_yearly_closed_out_drawdown                             -10.14
# max_yearly_closed_out_drawdown                             -43.76
# avg_monthly_closed_out_drawdown                             -2.44
# max_monthly_closed_out_drawdown                            -33.68
# avg_weekly_closed_out_drawdown                              -0.92
# max_weekly_closed_out_drawdown                             -28.49
# avg_yearly_closed_out_runup                                 17.60
# max_yearly_closed_out_runup                                 69.45
# avg_monthly_closed_out_runup                                 2.94
# max_monthly_closed_out_runup                                26.56
# avg_weekly_closed_out_runup                                  1.06
# max_weekly_closed_out_runup                                 18.51
# pct_profitable_years                                        62.51
# best_year                                                   67.08
# worst_year                                                 -37.59
# avg_year                                                     7.03
# annual_std                                                  13.62
# pct_profitable_months                                       45.66
# best_month                                                  22.41
# worst_month                                                -31.84
# avg_month                                                    0.55
# monthly_std                                                  3.41
# pct_profitable_weeks                                        40.14
# best_week                                                   18.51
# worst_week                                                 -27.72
# avg_week                                                     0.14
# weekly_std                                                   1.77
# pct_profitable_days                                         36.71
# best_day                                                    12.52
# worst_day                                                  -20.45
# avg_day                                                      0.03
# daily_std                                                    0.82
# sharpe_ratio                                                 0.54
# sharpe_ratio_max                                             0.56
# sharpe_ratio_min                                             0.52
# sortino_ratio                                                0.54
# dtype: object

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats

# %%
benchmark = pf.Benchmark(symbol, s.capital, s.start, s.end, use_adj=s.options['use_adj'])
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Plot Trades

# %%
pf.plot_trades(s.dbal, benchmark=benchmark.dbal)
# benchmark.dbal[benchmark.dbal.isna().any(axis=1)]

# %%
print('trading period:  {} to {}'.format(s.stats['start'], s.stats['end']))
df = pf.summary(s.stats, benchmark.stats, metrics=pf.currency_metrics)
df
# Out:
# trading period:  1928-10-01 to 2026-06-08
#                         strategy      benchmark
# beginning_balance     $10,000.00     $10,000.00
# ending_balance     $3,902,319.41  $3,465,885.15
# total_net_profit   $3,892,319.41  $3,455,885.15
# gross_profit       $4,854,189.46  $3,455,885.15
# gross_loss          -$961,870.06          $0.00

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                       6.30       6.17
# max_closed_out_drawdown                -52.69     -86.17
# annualized_return_over_max_drawdown      0.12       0.07
# best_month                              22.41      61.42
# worst_month                            -31.84     -42.18
# sharpe_ratio                             0.54       0.41
# sortino_ratio                            0.54       0.52
# monthly_std                              3.41       5.29
# annual_std                              13.62      19.83

# %% [markdown]
# Print the raw transaction log

# %%
pd.set_option('display.max_rows', len(s.rlog))
s.rlog
# Out:
#           date  seq_num   price  shares entry_exit direction symbol
# 0   1928-10-31        0   21.68     461      entry      LONG  ^GSPC
# 1   1929-10-31        1   24.15     461       exit      LONG  ^GSPC
# 2   1932-08-31        2    8.39    1327      entry      LONG  ^GSPC
# 3   1932-11-30        3    6.55    1327       exit      LONG  ^GSPC
# 4   1932-12-30        4    6.92    1256      entry      LONG  ^GSPC
# 5   1933-02-28        5    5.66    1256       exit      LONG  ^GSPC
# 6   1933-04-28        6    7.83     908      entry      LONG  ^GSPC
# 7   1934-05-31        7    9.61     908       exit      LONG  ^GSPC
# 8   1935-04-30        8    9.28     940      entry      LONG  ^GSPC
# 9   1937-04-30        9   16.43     940       exit      LONG  ^GSPC
# 10  1938-06-30       10   11.56    1336      entry      LONG  ^GSPC
# 11  1939-03-31       11   10.98    1336       exit      LONG  ^GSPC
# 12  1939-09-29       12   12.79    1147      entry      LONG  ^GSPC
# 13  1940-04-30       13   12.19    1147       exit      LONG  ^GSPC
# 14  1940-10-31       14   11.08    1262      entry      LONG  ^GSPC
# 15  1940-11-29       15   10.57    1262       exit      LONG  ^GSPC
# 16  1941-07-31       16   10.39    1284      entry      LONG  ^GSPC
# 17  1941-10-31       17    9.50    1284       exit      LONG  ^GSPC
# 18  1942-07-31       18    8.56    1425      entry      LONG  ^GSPC
# 19  1943-11-30       19   11.02    1425       exit      LONG  ^GSPC
# 20  1944-01-31       20   11.85    1325      entry      LONG  ^GSPC
# 21  1944-02-29       21   11.82    1325       exit      LONG  ^GSPC
# 22  1944-03-31       22   12.02    1303      entry      LONG  ^GSPC
# 23  1946-08-30       23   16.65    1303       exit      LONG  ^GSPC
# 24  1947-06-30       24   15.21    1426      entry      LONG  ^GSPC
# 25  1947-09-30       25   15.11    1426       exit      LONG  ^GSPC
# 26  1947-10-31       26   15.43    1397      entry      LONG  ^GSPC
# 27  1947-11-28       27   14.98    1397       exit      LONG  ^GSPC
# 28  1947-12-31       28   15.30    1367      entry      LONG  ^GSPC
# 29  1948-01-30       29   14.68    1367       exit      LONG  ^GSPC
# 30  1948-04-30       30   15.48    1297      entry      LONG  ^GSPC
# 31  1948-09-30       31   15.49    1297       exit      LONG  ^GSPC
# 32  1948-10-29       32   16.50    1217      entry      LONG  ^GSPC
# 33  1948-11-30       33   14.75    1217       exit      LONG  ^GSPC
# 34  1949-07-29       34   15.04    1194      entry      LONG  ^GSPC
# 35  1952-04-30       35   23.32    1194       exit      LONG  ^GSPC
# 36  1952-05-29       36   23.86    1167      entry      LONG  ^GSPC
# 37  1953-03-31       37   25.29    1167       exit      LONG  ^GSPC
# 38  1953-11-30       38   24.76    1192      entry      LONG  ^GSPC
# 39  1956-09-28       39   45.35    1192       exit      LONG  ^GSPC
# 40  1957-05-31       40   47.43    1139      entry      LONG  ^GSPC
# 41  1957-08-30       41   45.22    1139       exit      LONG  ^GSPC
# 42  1958-04-30       42   43.44    1186      entry      LONG  ^GSPC
# 43  1959-09-30       43   56.88    1186       exit      LONG  ^GSPC
# 44  1959-10-30       44   57.52    1173      entry      LONG  ^GSPC
# 45  1960-01-29       45   55.61    1173       exit      LONG  ^GSPC
# 46  1960-06-30       46   56.92    1146      entry      LONG  ^GSPC
# 47  1960-07-29       47   55.51    1146       exit      LONG  ^GSPC
# 48  1960-08-31       48   56.96    1117      entry      LONG  ^GSPC
# 49  1960-09-30       49   53.52    1117       exit      LONG  ^GSPC
# 50  1960-11-30       50   55.54    1076      entry      LONG  ^GSPC
# 51  1962-04-30       51   65.24    1076       exit      LONG  ^GSPC
# 52  1962-11-30       52   62.26    1127      entry      LONG  ^GSPC
# 53  1965-06-30       53   84.12    1127       exit      LONG  ^GSPC
# 54  1965-08-31       54   87.17    1088      entry      LONG  ^GSPC
# 55  1966-03-31       55   89.23    1088       exit      LONG  ^GSPC
# 56  1966-04-29       56   91.06    1066      entry      LONG  ^GSPC
# 57  1966-05-31       57   86.13    1066       exit      LONG  ^GSPC
# 58  1967-01-31       58   86.61    1060      entry      LONG  ^GSPC
# 59  1968-01-31       59   92.24    1060       exit      LONG  ^GSPC
# 60  1968-04-30       60   97.46    1003      entry      LONG  ^GSPC
# 61  1969-02-28       61   98.13    1003       exit      LONG  ^GSPC
# 62  1969-03-28       62  101.51     970      entry      LONG  ^GSPC
# 63  1969-06-30       63   97.71     970       exit      LONG  ^GSPC
# 64  1970-09-30       64   84.30    1124      entry      LONG  ^GSPC
# 65  1971-10-29       65   94.23    1124       exit      LONG  ^GSPC
# 66  1971-12-31       66  102.09    1037      entry      LONG  ^GSPC
# 67  1973-02-28       67  111.68    1037       exit      LONG  ^GSPC
# 68  1975-01-31       68   76.98    1505      entry      LONG  ^GSPC
# 69  1975-09-30       69   83.87    1505       exit      LONG  ^GSPC
# 70  1975-10-31       70   89.04    1418      entry      LONG  ^GSPC
# 71  1976-11-30       71  102.10    1418       exit      LONG  ^GSPC
# 72  1976-12-31       72  107.46    1347      entry      LONG  ^GSPC
# 73  1977-01-31       73  102.03    1347       exit      LONG  ^GSPC
# 74  1978-04-28       74   96.83    1419      entry      LONG  ^GSPC
# 75  1978-10-31       75   93.15    1419       exit      LONG  ^GSPC
# 76  1978-12-29       76   96.11    1376      entry      LONG  ^GSPC
# 77  1979-02-28       77   96.28    1376       exit      LONG  ^GSPC
# 78  1979-03-30       78  101.59    1304      entry      LONG  ^GSPC
# 79  1979-10-31       79  101.82    1304       exit      LONG  ^GSPC
# 80  1979-11-30       80  106.16    1250      entry      LONG  ^GSPC
# 81  1980-03-31       81  102.09    1250       exit      LONG  ^GSPC
# 82  1980-05-30       82  111.24    1148      entry      LONG  ^GSPC
# 83  1981-06-30       83  131.21    1148       exit      LONG  ^GSPC
# 84  1982-08-31       84  119.51    1260      entry      LONG  ^GSPC
# 85  1984-01-31       85  163.41    1260       exit      LONG  ^GSPC
# 86  1984-08-31       86  166.68    1235      entry      LONG  ^GSPC
# 87  1985-09-30       87  182.08    1235       exit      LONG  ^GSPC
# 88  1985-10-31       88  189.82    1185      entry      LONG  ^GSPC
# 89  1986-09-30       89  231.32    1185       exit      LONG  ^GSPC
# 90  1986-10-31       90  243.98    1123      entry      LONG  ^GSPC
# 91  1986-12-31       91  242.17    1123       exit      LONG  ^GSPC
# 92  1987-01-30       92  274.08     992      entry      LONG  ^GSPC
# 93  1987-10-30       93  251.79     992       exit      LONG  ^GSPC
# 94  1988-06-30       94  273.50     914      entry      LONG  ^GSPC
# 95  1990-01-31       95  329.08     914       exit      LONG  ^GSPC
# 96  1990-03-30       96  339.94     884      entry      LONG  ^GSPC
# 97  1990-04-30       97  330.80     884       exit      LONG  ^GSPC
# 98  1990-05-31       98  361.23     810      entry      LONG  ^GSPC
# 99  1990-08-31       99  322.56     810       exit      LONG  ^GSPC
# 100 1991-01-31      100  343.93     760      entry      LONG  ^GSPC
# 101 1991-11-29      101  375.22     760       exit      LONG  ^GSPC
# 102 1991-12-31      102  417.09     683      entry      LONG  ^GSPC
# 103 1994-03-31      103  445.77     683       exit      LONG  ^GSPC
# 104 1994-08-31      104  475.49     640      entry      LONG  ^GSPC
# 105 1994-11-30      105  453.69     640       exit      LONG  ^GSPC
# 106 1994-12-30      106  459.27     633      entry      LONG  ^GSPC
# 107 1998-08-31      107  957.28     633       exit      LONG  ^GSPC
# 108 1998-10-30      108 1098.67     551      entry      LONG  ^GSPC
# 109 1999-09-30      109 1282.71     551       exit      LONG  ^GSPC
# 110 1999-10-29      110 1362.93     519      entry      LONG  ^GSPC
# 111 2000-09-29      111 1436.51     519       exit      LONG  ^GSPC
# 112 2002-03-28      112 1147.39     649      entry      LONG  ^GSPC
# 113 2002-04-30      113 1076.92     649       exit      LONG  ^GSPC
# 114 2003-04-30      114  916.92     763      entry      LONG  ^GSPC
# 115 2004-08-31      115 1104.24     763       exit      LONG  ^GSPC
# 116 2004-10-29      116 1130.20     745      entry      LONG  ^GSPC
# 117 2007-11-30      117 1481.14     745       exit      LONG  ^GSPC
# 118 2009-06-30      118  919.32    1201      entry      LONG  ^GSPC
# 119 2010-06-30      119 1030.71    1201       exit      LONG  ^GSPC
# 120 2010-07-30      120 1101.60    1123      entry      LONG  ^GSPC
# 121 2010-08-31      121 1049.33    1123       exit      LONG  ^GSPC
# 122 2010-09-30      122 1141.20    1033      entry      LONG  ^GSPC
# 123 2011-08-31      123 1218.89    1033       exit      LONG  ^GSPC
# 124 2012-01-31      124 1312.41     959      entry      LONG  ^GSPC
# 125 2015-08-31      125 1972.18     959       exit      LONG  ^GSPC
# 126 2015-10-30      126 2079.36     910      entry      LONG  ^GSPC
# 127 2015-12-31      127 2043.94     910       exit      LONG  ^GSPC
# 128 2016-03-31      128 2059.74     903      entry      LONG  ^GSPC
# 129 2018-10-31      129 2711.74     903       exit      LONG  ^GSPC
# 130 2018-11-30      130 2760.17     887      entry      LONG  ^GSPC
# 131 2018-12-31      131 2506.85     887       exit      LONG  ^GSPC
# 132 2019-02-28      132 2784.49     798      entry      LONG  ^GSPC
# 133 2019-05-31      133 2752.06     798       exit      LONG  ^GSPC
# 134 2019-06-28      134 2941.76     747      entry      LONG  ^GSPC
# 135 2020-02-28      135 2954.22     747       exit      LONG  ^GSPC
# 136 2020-05-29      136 3044.31     725      entry      LONG  ^GSPC
# 137 2022-02-28      137 4373.94     725       exit      LONG  ^GSPC
# 138 2022-03-31      138 4530.41     700      entry      LONG  ^GSPC
# 139 2022-04-29      139 4131.93     700       exit      LONG  ^GSPC
# 140 2022-11-30      140 4080.11     708      entry      LONG  ^GSPC
# 141 2022-12-30      141 3839.50     708       exit      LONG  ^GSPC
# 142 2023-01-31      142 4076.60     667      entry      LONG  ^GSPC
# 143 2023-10-31      143 4193.80     667       exit      LONG  ^GSPC
# 144 2023-11-30      144 4567.80     613      entry      LONG  ^GSPC
# 145 2025-03-31      145 5611.85     613       exit      LONG  ^GSPC
# 146 2025-05-30      146 5911.69     581      entry      LONG  ^GSPC
# 147 2026-03-31      147 6528.52     581       exit      LONG  ^GSPC
# 148 2026-04-30      148 7209.01     526      entry      LONG  ^GSPC
# 149 2026-06-08      149 7405.73     526       exit      LONG  ^GSPC
