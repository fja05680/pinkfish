# %% [markdown]
# # Momentum
#
# A stock that's going up tends to keep going up...until it doesn't.  Momentum is the theory that stocks that have recently gone up will keep going up disproportionate to their underlying value because folks are overenthusiastic about them.
#
#     On the first trading day of each week
#     1. The SPY is higher than 'lookback' months ago, buy
#     2. If the SPY is lower than 'lookback' months ago, sell your long position.
#
#     The 'lookback' time period can be random, meaning a random lookback period is used for each new position.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

import pinkfish as pf
import strategy

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
# symbol = '^GSPC'
symbol = 'SPY'
#symbol = 'DIA'
#symbol = 'QQQ'
#symbol = 'IWM'
#symbol = 'TLT'
#symbol = 'GLD'
#symbol = 'AAPL'
#symbol = 'BBRY'
#symbol = 'GDX'
#symbol = 'OIH'

capital = 10000
# start = datetime.datetime(2010, 1, 1)
start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()

# %%
options = {
    'use_adj' : True,
    'use_cache' : True,
    'lookback': 12,
    'margin': 1
}

# %% [markdown]
# Run Strategy

# %%
s = strategy.Strategy(symbol, capital, start, end, options)
s.run()

# %% [markdown]
# View logs

# %%
s.tlog.tail(10)
# Out:
#    entry_date  entry_price  exit_date  exit_price  pl_points   pl_cash  qty  \
# 12 2015-08-31       165.23 2015-12-21      170.46       5.23   2331.86  446
# 13 2015-12-28       173.45 2016-01-11      162.38     -11.07  -4849.77  438
# 14 2016-03-21       173.89 2016-03-28      172.67      -1.21   -496.88  409
# 15 2016-04-04       175.23 2016-04-11      173.33      -1.89   -763.51  403
# 16 2016-04-18       177.77 2016-05-02      176.69      -1.08   -424.06  393
# 17 2016-05-31       178.28 2016-06-27      170.46      -7.82  -3048.99  390
# 18 2016-07-05       177.98 2018-12-17      227.70      49.71  18543.69  373
# 19 2019-01-28       236.56 2020-03-09      250.61      14.05   5043.15  359
# 20 2020-04-27       263.87 2022-05-09      376.78     112.91  38502.13  341
# 21 2023-04-17       398.34 2026-06-12      741.75     343.41 110579.00  322
#
#     cumul_total direction symbol
# 12     66081.08      LONG    SPY
# 13     61231.31      LONG    SPY
# 14     60734.43      LONG    SPY
# 15     59970.91      LONG    SPY
# 16     59546.85      LONG    SPY
# 17     56497.85      LONG    SPY
# 18     75041.54      LONG    SPY
# 19     80084.69      LONG    SPY
# 20    118586.82      LONG    SPY
# 21    229165.83      LONG    SPY

# %%
s.dbal.tail()
# Out:
#                 high       low     close  shares      cash  leverage state
# date
# 2026-06-08 238351.16 238351.16 238351.16     322    322.33      1.00     -
# 2026-06-09 237652.42 237652.42 237652.42     322    322.33      1.00     -
# 2026-06-10 233910.78 233910.78 233910.78     322    322.33      1.00     -
# 2026-06-11 237881.05 237881.05 237881.05     322    322.33      1.00     -
# 2026-06-12 239165.83 239165.83 239165.83       0 239165.83      1.00     X

# %% [markdown]
# Generate strategy stats - display all available stats

# %%
pf.print_full(s.stats)
# Out:
# start                                                   1994-07-05
# end                                                     2026-06-12
# beginning_balance                                            10000
# ending_balance                                           239165.83
# total_net_profit                                         229165.83
# gross_profit                                             246918.63
# gross_loss                                               -17752.81
# profit_factor                                                13.91
# return_on_initial_capital                                  2291.66
# annual_return_rate                                           10.45
# trading_period                           31 years 11 months 7 days
# pct_time_in_market                                           81.80
# margin                                                           1
# avg_leverage                                                  1.00
# max_leverage                                                  1.00
# min_leverage                                                  1.00
# total_num_trades                                                22
# trades_per_year                                               0.69
# num_winning_trades                                              11
# num_losing_trades                                               11
# num_even_trades                                                  0
# pct_profitable_trades                                        50.00
# avg_profit_per_trade                                      10416.63
# avg_profit_per_winning_trade                              22447.15
# avg_loss_per_losing_trade                                 -1613.89
# ratio_avg_profit_win_loss                                    13.91
# largest_profit_winning_trade                             110579.00
# largest_loss_losing_trade                                 -4849.77
# num_winning_points                                          687.24
# num_losing_points                                           -40.43
# total_net_points                                            646.81
# avg_points                                                   29.40
# largest_points_winning_trade                                343.41
# largest_points_losing_trade                                 -11.07
# avg_pct_gain_per_trade                                       21.97
# largest_pct_winning_trade                                   221.42
# largest_pct_losing_trade                                     -7.47
# expected_shortfall                                               0
# max_consecutive_winning_trades                                   4
# max_consecutive_losing_trades                                    5
# avg_bars_winning_trades                                     590.18
# avg_bars_losing_trades                                        9.64
# max_closed_out_drawdown                                     -22.90
# max_closed_out_drawdown_peak_date                       2011-04-29
# max_closed_out_drawdown_trough_date                     2011-12-28
# max_closed_out_drawdown_recovery_date                   2013-04-10
# drawdown_loss_period                                           243
# drawdown_recovery_period                                       469
# annualized_return_over_max_drawdown                           0.46
# max_intra_day_drawdown                                      -22.90
# avg_yearly_closed_out_drawdown                              -10.07
# max_yearly_closed_out_drawdown                              -22.90
# avg_monthly_closed_out_drawdown                              -2.82
# max_monthly_closed_out_drawdown                             -18.93
# avg_weekly_closed_out_drawdown                               -1.13
# max_weekly_closed_out_drawdown                              -12.83
# avg_yearly_closed_out_runup                                  20.62
# max_yearly_closed_out_runup                                  55.63
# avg_monthly_closed_out_runup                                  3.61
# max_monthly_closed_out_runup                                 17.78
# avg_weekly_closed_out_runup                                   1.34
# max_weekly_closed_out_runup                                  10.48
# pct_profitable_years                                         74.20
# best_year                                                    53.26
# worst_year                                                  -18.55
# avg_year                                                     11.08
# annual_std                                                   13.96
# pct_profitable_months                                        56.16
# best_month                                                   17.78
# worst_month                                                 -18.93
# avg_month                                                     0.85
# monthly_std                                                   3.45
# pct_profitable_weeks                                         49.68
# best_week                                                     9.70
# worst_week                                                  -12.83
# avg_week                                                      0.21
# weekly_std                                                    1.85
# pct_profitable_days                                          44.91
# best_day                                                     10.48
# worst_day                                                    -7.80
# avg_day                                                       0.04
# daily_std                                                     0.88
# sharpe_ratio                                                  0.78
# sharpe_ratio_max                                              0.82
# sharpe_ratio_min                                              0.75
# sortino_ratio                                                 0.91
# dtype: object

# %% [markdown]
# Equity curve

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats

# %%
benchmark = pf.Benchmark(symbol, s.capital, s.start, s.end, use_adj=True)
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Plot Trades

# %%
pf.plot_trades(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                      10.45      11.11
# max_closed_out_drawdown                -22.90     -55.16
# annualized_return_over_max_drawdown      0.46       0.20
# best_month                              17.78      23.59
# worst_month                            -18.93     -30.98
# sharpe_ratio                             0.78       0.65
# sortino_ratio                            0.91       0.84
# monthly_std                              3.45       4.51
# annual_std                              13.96      17.05
