# %% [markdown]
# # Double 7's (Short Term Trading Strategies that Work)
#
#     1. The Security is above its 200-day moving average or X-day ma
#     2. The Security closes at a 7-day low, buy.
#     3. If the Security closes at a 7-day high, sell your long position.
#
#     (Scale in and out of trades).
#
#     'strategy.py' uses adjust_percent() approach
#     'scaling_in_out.py' uses lower level pinkfish functions

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd

import pinkfish as pf

# Format price data.
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# Set size of inline plots.
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
#symbol = '^GSPC'
symbol = 'SPY'
#symbol = 'DIA'
#symbol = 'QQQ'
#symbol = 'IWM'
#symbol = 'TLT'
#symbol = 'GLD'
#symbol = 'AAPL'
#symbol = 'BBRY'
#symbol = 'GDX'
#symbol = 'OIH'
#symbol = 'NLY'

capital = 10000
#start = datetime.datetime(2015, 1, 1)
start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()

# %%
# ************** IMPORT ONLY ONE OF THESE *************
import strategy
# import scaling_in_out as strategy

# %% [markdown]
# Run Strategy

# %%
options = {
    'use_adj' : False,
    'use_cache' : True,
    'margin' : 1,
    'period' : 7,
    'max_open_trades' : 4,
    'enable_scale_in' : True,
    'enable_scale_out' : True
}

s = strategy.Strategy(symbol, capital, start, end, options)
s.run()

# %% [markdown]
# View logs

# %%
s.rlog.head(50)
# Out:
#          date  seq_num  price  shares entry_exit direction symbol
# 0  1993-11-19        0  46.31      53      entry      LONG    SPY
# 1  1993-11-22        1  46.03      53      entry      LONG    SPY
# 2  1993-12-02        2  46.53      55       exit      LONG    SPY
# 3  1993-12-03        3  46.72      51       exit      LONG    SPY
# 4  1993-12-14        4  46.53      53      entry      LONG    SPY
# 5  1993-12-15        5  46.47      52      entry      LONG    SPY
# 6  1993-12-21        6  46.47      52      entry      LONG    SPY
# 7  1993-12-22        7  46.78      56       exit      LONG    SPY
# 8  1993-12-27        8  47.00      56       exit      LONG    SPY
# 9  1993-12-28        9  47.09      45       exit      LONG    SPY
# 10 1993-12-31       10  46.59      54      entry      LONG    SPY
# 11 1994-01-03       11  46.47      52      entry      LONG    SPY
# 12 1994-01-07       12  47.03      55       exit      LONG    SPY
# 13 1994-01-10       13  47.59      51       exit      LONG    SPY
# 14 1994-01-24       14  47.19      54      entry      LONG    SPY
# 15 1994-01-25       15  47.19      51      entry      LONG    SPY
# 16 1994-01-27       16  47.75      56       exit      LONG    SPY
# 17 1994-01-28       17  47.88      49       exit      LONG    SPY
# 18 1994-02-04       18  46.97      54      entry      LONG    SPY
# 19 1994-02-15       19  47.47      54       exit      LONG    SPY
# 20 1994-02-18       20  46.88      54      entry      LONG    SPY
# 21 1994-02-24       21  46.59      54      entry      LONG    SPY
# 22 1994-03-03       22  46.56      53      entry      LONG    SPY
# 23 1994-03-07       23  46.94      56       exit      LONG    SPY
# 24 1994-03-09       24  46.97      57       exit      LONG    SPY
# 25 1994-03-16       25  47.25      48       exit      LONG    SPY
# 26 1994-03-21       26  46.84      55      entry      LONG    SPY
# 27 1994-03-24       27  46.38      54      entry      LONG    SPY
# 28 1994-04-21       28  44.91      57       exit      LONG    SPY
# 29 1994-04-25       29  45.33      52       exit      LONG    SPY
# 30 1994-09-07       30  47.27      53      entry      LONG    SPY
# 31 1994-09-09       31  47.00      53      entry      LONG    SPY
# 32 1994-09-12       32  46.86      52      entry      LONG    SPY
# 33 1994-09-15       33  47.64      55       exit      LONG    SPY
# 34 1994-09-28       34  46.47      55       exit      LONG    SPY
# 35 1994-10-11       35  46.62      48       exit      LONG    SPY
# 36 1994-10-21       36  46.56      54      entry      LONG    SPY
# 37 1994-10-24       37  46.17      53      entry      LONG    SPY
# 38 1994-10-28       38  47.66      56       exit      LONG    SPY
# 39 1994-11-04       39  46.33      54      entry      LONG    SPY
# 40 1994-12-14       40  45.75      57       exit      LONG    SPY
# 41 1994-12-15       41  45.89      48       exit      LONG    SPY
# 42 1995-03-07       42  48.44      52      entry      LONG    SPY
# 43 1995-03-10       43  49.27      52       exit      LONG    SPY
# 44 1995-04-18       44  50.61      50      entry      LONG    SPY
# 45 1995-04-19       45  50.56      49      entry      LONG    SPY
# 46 1995-04-24       46  51.48      51       exit      LONG    SPY
# 47 1995-04-27       47  51.52      48       exit      LONG    SPY
# 48 1995-05-18       48  52.06      49      entry      LONG    SPY
# 49 1995-05-23       49  53.16      49       exit      LONG    SPY

# %%
s.tlog.tail()
# Out:
#      entry_date  entry_price  exit_date  exit_price  pl_points  pl_cash  qty  \
# 1233 2026-03-06       672.38 2026-04-09      679.91       7.53    90.36   12
# 1234 2026-03-12       666.06 2026-04-09      679.91      13.85    69.25    5
# 1235 2026-05-19       733.73 2026-05-26      750.59      16.86   286.62   17
# 1236 2026-06-05       737.55 2026-06-12      741.75       4.20    71.40   17
# 1237 2026-06-09       737.05 2026-06-12      741.75       4.70     9.40    2
#
#       cumul_total direction symbol
# 1233     41907.96      LONG    SPY
# 1234     41977.21      LONG    SPY
# 1235     42263.83      LONG    SPY
# 1236     42335.23      LONG    SPY
# 1237     42344.63      LONG    SPY

# %%
s.dbal.tail()
# Out:
#                high      low    close  shares     cash  leverage state
# date
# 2026-06-08 52292.22 52292.22 52292.22      17 39725.48      1.00     -
# 2026-06-09 52255.33 52255.33 52255.33      34 27195.63      1.00     O
# 2026-06-10 51860.25 51860.25 51860.25      51 14863.32      1.00     -
# 2026-06-11 52489.08 52489.08 52489.08      51 14863.32      1.00     -
# 2026-06-12 52613.64 52613.64 52613.64      32 28877.64      1.00     X

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats

# %%
benchmark = pf.Benchmark(symbol, capital, s.start, s.end, use_adj=False)
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Plot Trades

# %%
pf.plot_trades(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                       5.23       8.87
# max_closed_out_drawdown                -22.44     -56.42
# annualized_return_over_max_drawdown      0.23       0.16
# best_month                              12.17      23.06
# worst_month                            -21.80     -31.38
# sharpe_ratio                             0.65       0.55
# sortino_ratio                            0.49       0.70
# monthly_std                              1.80       4.48
# annual_std                               6.13      16.62

# %% [markdown]
# Plot Instrument Risk vs Strategy Risk

# %%
df = pf.volatility_graphs([s.ts, s.dbal], [symbol, 'Strategy'], points_to_plot=5000)
df
# Out:
#         SPY  Strategy
# avg    0.16      0.06
# median 0.13      0.03
# min    0.03      0.00
# max    0.96      0.62
# std    0.11      0.07
# last   0.15      0.05

# %% [markdown]
# Prettier Graphs

# %%
returns = s.dbal['close']
benchmark_returns = benchmark.dbal['close']
pf.prettier_graphs(returns, benchmark_returns, dbal_label='Strategy', benchmark_label='Benchmark', points_to_plot=5000)

# %%
pf.kelly_criterion(s.stats, benchmark.stats)
# Out:
# sharpe_ratio            0.65
# sharpe_ratio_max        0.69
# sharpe_ratio_min        0.62
# strategy risk           0.06
# instrument risk         0.17
# optimal target risk     0.65
# half kelly criterion    0.33
# aggressive leverage     3.93
# moderate leverage       1.96
# conservative leverage   1.85
# dtype: float64
