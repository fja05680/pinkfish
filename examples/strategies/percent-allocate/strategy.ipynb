# %% [markdown]
# # percent-allocate
#
# Maintain a percent allocation of a security in account
# (1) If bull regime, set target share of 70%.  Allow range of 65% to 75%.  Check daily.
# (2) If bear regime, close out position

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd

import pinkfish as pf

# Format price data
pd.options.display.float_format = '{:0.2f}'.format
pd.set_option('display.max_rows', None)

# %matplotlib inline

# %%
# Set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
#symbol = '^GSPC'
symbol = 'SPY'
#symbol = 'DIA'
#symbol = 'QQQ'
#symbol = 'IWM'
#symbol = 'TLT'
#symbol = 'GLD'
capital = 10000
#start = datetime.datetime(1900, 1, 1)
start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()

# %% [markdown]
# Define target_percent and band

# %%
options = {
    'use_adj' : True,
    'use_cache' : True,
    'target_percent' : 70/100,
    'band' : 5/100
}

# %% [markdown]
# Define Strategy Class

# %%
class Strategy:

    def __init__(self, symbol, capital, start, end, options):

        self.symbol = symbol
        self.capital = capital
        self.start = start
        self.end = end
        self.options = options
        
        self.ts = None
        self.rlog = None
        self.tlog = None
        self.dbal = None
        self.stats = None

    def _algo(self):
        pf.TradeLog.cash = self.capital

        for i, row in enumerate(self.ts.itertuples()):

            date = row.Index.to_pydatetime()
            close = row.close; 
            end_flag = pf.is_last_row(self.ts, i)
            
            share_percent = self.tlog.share_percent(close)
            target_percent = self.options['target_percent'] 
            upper_band = target_percent + self.options['band']
            lower_band = target_percent - self.options['band']
            
            # Close Out Logic
            # First we check if an existing position in symbol should be sold
            #  - sell if regime < 0 or end of data

            if (self.tlog.shares > 0
                and (row.regime < 0 or end_flag)):
                # close position
                self.tlog.adjust_percent(date, close, 0)

            # Adjust Shares Logic
            #  - Adjust Shares if regime > 0
            #            and share percent outside of target_percent band
            #            and (use_regime_filter and regime > 0)
            
            else:
                if (row.regime > 0
                    and not lower_band < share_percent < upper_band):
                    # adjust shares to target_percent
                    self.tlog.adjust_percent(date, close, target_percent)   

            # record daily balance
            self.dbal.append(date, close)

    def run(self):
        
        # Fetch and select timeseries
        self.ts = pf.fetch_timeseries(self.symbol, use_cache=self.options['use_cache'])
        self.ts = pf.select_tradeperiod(self.ts, self.start, self.end, use_adj=self.options['use_adj'])

        # Add technical indicator: 200 sma regime filter plus 3% band
        self.ts['regime'] = \
            pf.CROSSOVER(self.ts, timeperiod_fast=1, timeperiod_slow=200, band=3.0)
        
        # Finalize timeseries
        self.ts, self.start = pf.finalize_timeseries(self.ts, self.start,
                                                     dropna=True, drop_columns=['open', 'high', 'low'])

        self.tlog = pf.TradeLog(self.symbol)
        self.dbal = pf.DailyBal()

        self._algo()
        self._get_logs()
        self._get_stats()
        
    def _get_logs(self):
        self.rlog = self.tlog.get_log_raw()
        self.tlog = self.tlog.get_log()
        self.dbal = self.dbal.get_log(self.tlog)

    def _get_stats(self):
        self.stats = pf.stats(self.ts, self.tlog, self.dbal, self.capital)

# %% [markdown]
# Run Strategy

# %%
s = Strategy(symbol, capital, start, end, options)
s.run()

# %% [markdown]
# View logs

# %%
s.rlog.tail()
# Out:
#          date  seq_num  price  shares entry_exit direction symbol
# 40 2025-03-13       40 543.54     103       exit      LONG    SPY
# 41 2025-05-15       41 583.77      94      entry      LONG    SPY
# 42 2026-03-27       42 634.09      94       exit      LONG    SPY
# 43 2026-04-13       43 686.10      85      entry      LONG    SPY
# 44 2026-06-12       44 741.75      85       exit      LONG    SPY

# %%
s.tlog.tail()
# Out:
#    entry_date  entry_price  exit_date  exit_price  pl_points  pl_cash  qty  \
# 23 2022-03-29       436.75 2022-04-22      403.15     -33.60 -3494.63  104
# 24 2023-01-26       388.01 2024-03-27      510.74     122.73   981.82    8
# 25 2023-01-26       388.01 2025-03-13      543.54     155.52 16018.85  103
# 26 2025-05-15       583.77 2026-03-27      634.09      50.32  4730.28   94
# 27 2026-04-13       686.10 2026-06-12      741.75      55.65  4730.25   85
#
#     cumul_total direction symbol
# 23     51954.86      LONG    SPY
# 24     52936.68      LONG    SPY
# 25     68955.53      LONG    SPY
# 26     73685.81      LONG    SPY
# 27     78416.06      LONG    SPY

# %%
s.dbal.tail()
# Out:
#                high      low    close  shares     cash  leverage state
# date
# 2026-06-08 88201.01 88201.01 88201.01      85 25367.31      1.00     -
# 2026-06-09 88016.56 88016.56 88016.56      85 25367.31      1.00     -
# 2026-06-10 87028.86 87028.86 87028.86      85 25367.31      1.00     -
# 2026-06-11 88076.91 88076.91 88076.91      85 25367.31      1.00     -
# 2026-06-12 88416.06 88416.06 88416.06       0 88416.06      1.00     X

# %% [markdown]
# Run Benchmark

# %%
benchmark = pf.Benchmark(symbol, s.capital, s.start, s.end)
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Plot Trades

# %%
pf.plot_trades(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                       6.92       8.87
# max_closed_out_drawdown                -16.36     -56.42
# annualized_return_over_max_drawdown      0.42       0.16
# best_month                              10.68      23.06
# worst_month                            -13.97     -31.38
# sharpe_ratio                             0.80       0.55
# sortino_ratio                            0.90       0.70
# monthly_std                              2.26       4.48
# annual_std                               8.89      16.62

# %% [markdown]
# Total Number of Trades

# %%
s.stats.total_num_trades
# Out:
# 28
