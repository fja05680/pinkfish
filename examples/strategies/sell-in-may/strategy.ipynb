# %% [markdown]
# # sell-in-may-and-go-away
#
# see: https://en.wikipedia.org/wiki/Sell_in_May
#
# "Sell in May and go away" (aka the Halloween indicator) is an investment adage warning investors to divest their stock holdings in May and wait to reinvest in November.

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd

import pinkfish as pf

# Format price data
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# Set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
symbol = '^GSPC'
capital = 10000
#start = datetime.datetime(1900, 1, 1)
start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()

# %% [markdown]
# Define Strategy Class

# %%
class Strategy:

    def __init__(self, symbol, capital, start, end):
        self.symbol = symbol
        self.capital = capital
        self.start = start
        self.end = end
        
        self.ts = None
        self.rlog = None
        self.tlog = None
        self.dbal = None
        self.stats = None

    def _algo(self):
        pf.TradeLog.cash = capital

        for i, row in enumerate(self.ts.itertuples()):

            date = row.Index.to_pydatetime()
            end_flag = pf.is_last_row(self.ts, i)

            # Buy (at the close on first trading day in Nov).
            if self.tlog.shares == 0:
                if row.month == 11 and row.first_dotm:
                    self.tlog.buy(date, row.close)
            # Sell (at the close on first trading day in May).
            else:
                if ((row.month == 5 and row.first_dotm) or end_flag):
                    self.tlog.sell(date, row.close)

            # Record daily balance
            self.dbal.append(date, row.close)

    def run(self):
        
        # Fetch and select timeseries.
        self.ts = pf.fetch_timeseries(self.symbol)
        self.ts = pf.select_tradeperiod(self.ts, self.start, self.end, 
                                        use_adj=True)
        # Add calendar columns.
        self.ts = pf.calendar(self.ts)
        
        # Finalize timeseries.
        self.ts, self.start = pf.finalize_timeseries(self.ts, self.start,
                                                     drop_columns=['open', 'high', 'low'])
        
        # Create tlog and dbal objects
        self.tlog = pf.TradeLog(symbol)
        self.dbal = pf.DailyBal()
        
        # Run algorithm, get logs
        self._algo()
        self._get_logs()
        self._get_stats()

    def _get_logs(self):
        self.rlog = self.tlog.get_log_raw()
        self.tlog = self.tlog.get_log()
        self.dbal = self.dbal.get_log(self.tlog)

    def _get_stats(self):
        s.stats = pf.stats(self.ts, self.tlog, self.dbal, self.capital)

# %% [markdown]
# Run Strategy

# %%
s = Strategy(symbol, capital, start, end)
s.run()

# %% [markdown]
# Examine logs

# %%
# The raw trade log show each entry or exit entry.
s.rlog.tail()
# Out:
#           date  seq_num   price  shares entry_exit direction symbol
# 133 2024-05-01      133 5018.39     111       exit      LONG  ^GSPC
# 134 2024-11-01      134 5728.80      97      entry      LONG  ^GSPC
# 135 2025-05-01      135 5604.14      97       exit      LONG  ^GSPC
# 136 2025-11-03      136 6851.97      79      entry      LONG  ^GSPC
# 137 2026-05-01      137 7230.12      79       exit      LONG  ^GSPC

# %%
# The trade log shows matching entry and exits orders
s.tlog.tail()
# Out:
#    entry_date  entry_price  exit_date  exit_price  pl_points   pl_cash  qty  \
# 64 2021-11-01      4613.67 2022-05-02     4155.38    -458.29 -48120.45  105
# 65 2022-11-01      3856.10 2023-05-01     4167.87     311.77  35230.01  113
# 66 2023-11-01      4237.86 2024-05-01     5018.39     780.53  86638.86  111
# 67 2024-11-01      5728.80 2025-05-01     5604.14    -124.66 -12091.99   97
# 68 2025-11-03      6851.97 2026-05-01     7230.12     378.15  29873.84   79
#
#     cumul_total direction symbol
# 64    426923.48      LONG  ^GSPC
# 65    462153.50      LONG  ^GSPC
# 66    548792.36      LONG  ^GSPC
# 67    536700.37      LONG  ^GSPC
# 68    566574.21      LONG  ^GSPC

# %%
# The daily balance
s.dbal.tail()
# Out:
#                 high       low     close  shares      cash  leverage state
# date
# 2026-06-02 576574.21 576574.21 576574.21       0 576574.21      1.00     -
# 2026-06-03 576574.21 576574.21 576574.21       0 576574.21      1.00     -
# 2026-06-04 576574.21 576574.21 576574.21       0 576574.21      1.00     -
# 2026-06-05 576574.21 576574.21 576574.21       0 576574.21      1.00     -
# 2026-06-08 576574.21 576574.21 576574.21       0 576574.21      1.00     -

# %% [markdown]
# All available stastics

# %%
pf.print_full(s.stats)
# Out:
# start                                                  1957-03-04
# end                                                    2026-06-08
# beginning_balance                                           10000
# ending_balance                                          576574.21
# total_net_profit                                        566574.21
# gross_profit                                            732012.14
# gross_loss                                             -165437.93
# profit_factor                                                4.42
# return_on_initial_capital                                 5665.74
# annual_return_rate                                           6.03
# trading_period                           69 years 3 months 4 days
# pct_time_in_market                                          48.96
# margin                                                          1
# avg_leverage                                                 1.00
# max_leverage                                                 1.00
# min_leverage                                                 1.00
# total_num_trades                                               69
# trades_per_year                                              1.00
# num_winning_trades                                             51
# num_losing_trades                                              18
# num_even_trades                                                 0
# pct_profitable_trades                                       73.91
# avg_profit_per_trade                                      8211.22
# avg_profit_per_winning_trade                             14353.18
# avg_loss_per_losing_trade                                -9191.00
# ratio_avg_profit_win_loss                                    1.56
# largest_profit_winning_trade                            101478.32
# largest_loss_losing_trade                               -48120.45
# num_winning_points                                        5272.82
# num_losing_points                                        -1267.38
# total_net_points                                          4005.44
# avg_points                                                  58.05
# largest_points_winning_trade                               882.42
# largest_points_losing_trade                               -458.29
# avg_pct_gain_per_trade                                       6.54
# largest_pct_winning_trade                                   26.66
# largest_pct_losing_trade                                   -16.17
# expected_shortfall                                              0
# max_consecutive_winning_trades                                  6
# max_consecutive_losing_trades                                   2
# avg_bars_winning_trades                                    124.65
# avg_bars_losing_trades                                     124.89
# max_closed_out_drawdown                                    -34.96
# max_closed_out_drawdown_peak_date                      2007-11-06
# max_closed_out_drawdown_trough_date                    2009-03-09
# max_closed_out_drawdown_recovery_date                  2010-11-04
# drawdown_loss_period                                          489
# drawdown_recovery_period                                      605
# annualized_return_over_max_drawdown                          0.17
# max_intra_day_drawdown                                     -34.96
# avg_yearly_closed_out_drawdown                              -9.12
# max_yearly_closed_out_drawdown                             -33.82
# avg_monthly_closed_out_drawdown                             -1.77
# max_monthly_closed_out_drawdown                            -30.85
# avg_weekly_closed_out_drawdown                              -0.68
# max_weekly_closed_out_drawdown                             -17.90
# avg_yearly_closed_out_runup                                 15.33
# max_yearly_closed_out_runup                                 51.55
# avg_monthly_closed_out_runup                                 2.26
# max_monthly_closed_out_runup                                28.34
# avg_weekly_closed_out_runup                                  0.81
# max_weekly_closed_out_runup                                 19.01
# pct_profitable_years                                        73.46
# best_year                                                   49.14
# worst_year                                                 -25.26
# avg_year                                                     6.53
# annual_std                                                  10.06
# pct_profitable_months                                       35.81
# best_month                                                  23.36
# worst_month                                                -30.85
# avg_month                                                    0.51
# monthly_std                                                  2.95
# pct_profitable_weeks                                        29.74
# best_week                                                   19.01
# worst_week                                                 -17.90
# avg_week                                                     0.13
# weekly_std                                                   1.50
# pct_profitable_days                                         26.34
# best_day                                                     9.45
# worst_day                                                  -11.94
# avg_day                                                      0.03
# daily_std                                                    0.70
# sharpe_ratio                                                 0.58
# sharpe_ratio_max                                             0.61
# sharpe_ratio_min                                             0.56
# sortino_ratio                                                0.53
# dtype: object

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats

# %%
benchmark = pf.Benchmark(symbol, s.capital, s.start, s.end)
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Plot Trades

# %%
pf.plot_trades(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                       6.03       7.68
# max_closed_out_drawdown                -34.96     -56.78
# annualized_return_over_max_drawdown      0.17       0.14
# best_month                              23.36      23.49
# worst_month                            -30.85     -30.94
# sharpe_ratio                             0.58       0.54
# sortino_ratio                            0.53       0.69
# monthly_std                              2.95       4.28
# annual_std                              10.06      15.84
