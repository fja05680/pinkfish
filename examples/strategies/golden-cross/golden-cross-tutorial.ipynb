# %% [markdown]
# # Golden Cross / Death Cross S&P 500 index (^GSPC)
#
#     1. sma50>sma200, buy
#     2. sma50<sma200, sell your long position.
#
#     THIS IS MEANT FOR EDUCATIONAL PURPOSES.  The condensed version is in strategy.ipynb

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd

import pinkfish as pf

# Format price data
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# Set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
symbol = '^GSPC'
#symbol = 'SPY'
#symbol = '^DJI'
#symbol = 'DJA'
#symbol = 'DIA'
#symbol = 'QQQ'
#symbol = 'IWM'
#symbol = 'TLT'
#symbol = 'GLD'
#symbol = 'AAPL'
#symbol = 'BBRY'
capital = 10000
start = datetime.datetime(1900, 1, 1)
#start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()

# %% [markdown]
# Include dividends? (If yes, set to True)

# %%
use_adj = True

# %% [markdown]
# Fetch symbol data from internet; use cache if available.

# %%
ts = pf.fetch_timeseries(symbol)
ts.head()
# Out:
#             open  high   low  close  adj_close  volume
# date
# 1927-12-30 17.66 17.66 17.66  17.66      17.66       0
# 1928-01-03 17.76 17.76 17.76  17.76      17.76       0
# 1928-01-04 17.72 17.72 17.72  17.72      17.72       0
# 1928-01-05 17.55 17.55 17.55  17.55      17.55       0
# 1928-01-06 17.66 17.66 17.66  17.66      17.66       0

# %% [markdown]
# Select timeseries between start and end. Back adjust prices relative to adj_close for dividends and splits.

# %%
ts = pf.select_tradeperiod(ts, start, end, use_adj)
ts.head()
# Out:
#             open  high   low  close  adj_close  volume
# date
# 1927-12-30 17.66 17.66 17.66  17.66      17.66       0
# 1928-01-03 17.76 17.76 17.76  17.76      17.76       0
# 1928-01-04 17.72 17.72 17.72  17.72      17.72       0
# 1928-01-05 17.55 17.55 17.55  17.55      17.55       0
# 1928-01-06 17.66 17.66 17.66  17.66      17.66       0

# %% [markdown]
# Add technical indicator: 50 day ma and 200 day ma

# %%
sma50 = pf.SMA(ts, timeperiod=50)
ts['sma50'] = sma50

sma200 = pf.SMA(ts, timeperiod=200)
ts['sma200'] = sma200

ts.head()
# Out:
#             open  high   low  close  adj_close  volume  sma50  sma200
# date
# 1927-12-30 17.66 17.66 17.66  17.66      17.66       0    NaN     NaN
# 1928-01-03 17.76 17.76 17.76  17.76      17.76       0    NaN     NaN
# 1928-01-04 17.72 17.72 17.72  17.72      17.72       0    NaN     NaN
# 1928-01-05 17.55 17.55 17.55  17.55      17.55       0    NaN     NaN
# 1928-01-06 17.66 17.66 17.66  17.66      17.66       0    NaN     NaN

# %% [markdown]
# Finalize the time series before implementing trading strategy

# %%
ts, start = pf.finalize_timeseries(ts, start, dropna=True, drop_columns=['open', 'high', 'low'])
ts.head()
# Out:
#             close  adj_close  volume  sma50  sma200
# date
# 1928-10-16  21.72      21.72       0  20.69   19.18
# 1928-10-17  21.79      21.79       0  20.73   19.20
# 1928-10-18  21.84      21.84       0  20.78   19.22
# 1928-10-19  21.96      21.96       0  20.83   19.25
# 1928-10-22  21.81      21.81       0  20.88   19.27

# %% [markdown]
# Plot closing price along with moving averages

# %%
fig = plt.figure()
axes = fig.add_subplot(111,  ylabel='Price in $')

ts['close'].plot(ax=axes, label='close', color='k')
ts['sma50'].plot(ax=axes, label='sma50', color='r')
ts['sma200'].plot(ax=axes, label='sma200', color='b')
plt.legend(loc='best')

# %% [markdown]
# Create Trade Log (tlog); Create Daily Balance (dbal)

# %%
tlog = pf.TradeLog(symbol)
dbal = pf.DailyBal()

# %% [markdown]
# Algo: Buy when 50 day ma crosses above 200 day ma.  Sell when 50 day ma crosses below 200 day ma.

# %%
pf.TradeLog.cash = capital

import time
t0 = time.time()

"""
# This is not the fatest, but allows you the Dataframe directly (769 msec).
for i in range(len(ts.index)):

    date = ts.index[i]
    high = ts['high'][i]; low = ts['low'][i]; close = ts['close'][i]
    sma50 = ts['sma50'][i]; sma200 = ts['sma200'][i]

# This is the slowest (1.481 sec).
for i, (index, row) in enumerate(ts.iterrows()):

    date = index
    high = row['high']; low = row['low']; close = row['close']
    sma50 = row['sma50']; sma200 = row['sma200']

# Using .at[] is faster (517 msec).
for i, index in enumerate(ts.index):

    date = index
    high = ts.at[index, 'high']; low = ts.at[index, 'low']; close = ts.at[index, 'close']
    sma50 = ts.at[index, 'sma50']; sma200 = ts.at[index, 'sma200']

# Converting to dict is supposed to be fastest, but it isn't (1.215 msec).
# The looping itself is fast (129 msec), but the conversion to dict takes too long.
# Also, a new column must be created for the index, which takes time.
ts['date'] = ts.index
ts_dict = ts.to_dict('records')
for i, row in enumerate(ts_dict):

    date = row['date']
    high = row['high']; low = row['low']; close = row['close']
    sma50 = row['sma50']; sma200 = row['sma200']

# Using itertuples is by far fastest for looping (219 msec)
for i, row in enumerate(ts.itertuples()):

    date = row.Index.to_pydatetime()
    high = row.high; low = row.low; close = row.close
    sma50 = row.sma50; sma200 = row.sma200
"""

for i, row in enumerate(ts.itertuples()):

    date = row.Index.to_pydatetime()
    close = row.close
    sma50 = row.sma50; sma200 = row.sma200
    end_flag = pf.is_last_row(ts, i)
    shares = 0
    
    # Buy
    if tlog.shares == 0:
        if sma50 > sma200 and ts['sma50'].iloc[i-1] <= ts['sma200'].iloc[i-1]:
            # Enter buy in trade log
            shares = tlog.buy(date, close)  
    # Sell
    else:
        if sma50 < sma200 or end_flag:
            # Enter sell in trade log
            shares = tlog.sell(date, close)

#     if shares > 0:
#         print("{0} BUY  {1} {2} @ {3:.2f}".format(
#               date, shares, symbol, close))
#     elif shares < 0:
#         print("{0} SELL {1} {2} @ {3:.2f}".format(
#               date, -shares, symbol, close))

    # Record daily balance
    dbal.append(date, close)  

t1 = time.time()
total = t1-t0
print(total)
# Out:
# 0.2980926036834717

# %% [markdown]
# Retrieve raw log and trade log DataFrames

# %%
rlog = tlog.get_log_raw()
tlog = tlog.get_log()

# %%
rlog.tail()
# Out:
#          date  seq_num   price  shares entry_exit direction symbol
# 95 2022-03-14       95 4173.11     686       exit      LONG  ^GSPC
# 96 2023-02-02       96 4179.76     685      entry      LONG  ^GSPC
# 97 2025-04-14       97 5405.97     685       exit      LONG  ^GSPC
# 98 2025-07-01       98 6198.01     597      entry      LONG  ^GSPC
# 99 2026-06-08       99 7405.73     597       exit      LONG  ^GSPC

# %% [markdown]
# View trade log

# %%
tlog.head(50)
# Out:
#    entry_date  entry_price  exit_date  exit_price  pl_points    pl_cash   qty  \
# 0  1932-09-19         7.34 1933-03-27        6.09      -1.25   -1702.50  1362
# 1  1933-05-18         8.89 1934-05-31        9.61       0.72     671.76   933
# 2  1935-05-23        10.07 1937-05-21       16.27       6.20    5518.00   890
# 3  1938-07-27        12.25 1939-03-31       10.98      -1.27   -1501.14  1182
# 4  1939-09-18        12.47 1940-03-20       12.14      -0.33    -343.53  1041
# 5  1940-12-13        10.69 1941-02-21        9.76      -0.93   -1099.26  1182
# 6  1941-08-18        10.13 1941-11-18        9.26      -0.87    -990.93  1139
# 7  1942-08-14         8.58 1943-12-01       11.13       2.55    3133.95  1229
# 8  1944-03-13        12.24 1946-08-28       16.73       4.49    5019.82  1118
# 9  1947-07-25        16.08 1948-01-22       14.42      -1.66   -1930.58  1163
# 10 1948-05-14        16.39 1948-12-01       15.01      -1.38   -1411.74  1023
# 11 1949-08-30        15.21 1953-05-11       24.91       9.70    9797.00  1010
# 12 1953-12-21        24.95 1956-10-26       46.27      21.32   21490.56  1008
# 13 1957-06-03        47.37 1957-09-26       42.57      -4.80   -4723.20   984
# 14 1958-05-08        43.99 1959-10-30       57.52      13.53   12894.09   953
# 15 1959-12-30        59.77 1960-02-15       55.17      -4.60   -4218.20   917
# 16 1961-01-04        58.36 1962-05-07       66.02       7.66    6641.22   867
# 17 1963-01-03        63.72 1965-07-22       83.85      20.13   18076.74   898
# 18 1965-09-17        90.05 1966-04-28       91.13       1.08     902.88   836
# 19 1967-02-03        87.36 1968-02-27       90.53       3.17    2764.24   872
# 20 1968-05-17        96.90 1969-03-13       98.39       1.49    1214.35   815
# 21 1969-05-27       103.57 1969-06-23       96.23      -7.34   -5681.16   774
# 22 1970-10-22        83.38 1971-09-24       98.15      14.77   13189.61   893
# 23 1972-01-26       102.50 1973-04-18      111.54       9.04    7729.20   855
# 24 1975-03-06        83.69 1976-12-01      102.49      18.80   21431.99  1140
# 25 1977-01-04       105.70 1977-03-03      100.88      -4.82   -5326.10  1105
# 26 1978-05-22        99.09 1978-12-13       96.06      -3.03   -3408.75  1125
# 27 1979-03-21       101.25 1980-04-22      103.43       2.18    2328.24  1068
# 28 1980-06-17       116.03 1981-07-02      128.64      12.61   12004.72   952
# 29 1982-09-28       123.24 1984-02-03      160.91      37.67   37406.32   993
# 30 1984-09-12       164.68 1986-11-18      236.78      72.10   69937.01   970
# 31 1986-11-25       248.17 1987-11-05      254.48       6.31    5843.06   926
# 32 1988-06-28       272.31 1990-02-26      328.67      56.36   48751.41   865
# 33 1990-05-25       354.58 1990-09-07      323.40     -31.18  -25006.35   802
# 34 1991-02-15       369.06 1994-04-19      442.54      73.48   51582.97   702
# 35 1994-09-15       474.81 1998-09-29     1049.02     574.21  375533.35   654
# 36 1998-12-08      1181.38 1999-11-04     1362.64     181.26  105312.07   581
# 37 1999-11-11      1381.46 2000-10-30     1398.66      17.20    9855.64   573
# 38 2003-05-14       939.28 2004-08-18     1095.17     155.89  132974.18   853
# 39 2004-11-05      1166.17 2006-07-19     1259.81      93.64   75005.65   801
# 40 2006-09-12      1313.00 2007-12-21     1484.46     171.46  131681.25   768
# 41 2009-06-23       895.10 2010-07-02     1022.58     127.48  162537.05  1275
# 42 2010-10-22      1183.08 2011-08-12     1178.81      -4.27   -4705.43  1102
# 43 2012-01-31      1312.41 2015-08-28     1988.87     676.46  669018.90   989
# 44 2015-12-21      2021.15 2016-01-11     1923.67     -97.48  -94848.02   973
# 45 2016-04-25      2087.79 2018-12-07     2633.08     545.29  489125.17   897
# 46 2019-04-01      2867.19 2020-03-30     2626.65    -240.54 -197964.45   823
# 47 2020-07-09      3152.05 2022-03-14     4173.11    1021.06  700447.03   686
# 48 2023-02-02      4179.76 2025-04-14     5405.97    1226.21  839954.16   685
# 49 2025-07-01      6198.01 2026-06-08     7405.73    1207.72  721008.97   597
#
#     cumul_total direction symbol
# 0      -1702.50      LONG  ^GSPC
# 1      -1030.74      LONG  ^GSPC
# 2       4487.26      LONG  ^GSPC
# 3       2986.12      LONG  ^GSPC
# 4       2642.59      LONG  ^GSPC
# 5       1543.33      LONG  ^GSPC
# 6        552.40      LONG  ^GSPC
# 7       3686.35      LONG  ^GSPC
# 8       8706.17      LONG  ^GSPC
# 9       6775.59      LONG  ^GSPC
# 10      5363.85      LONG  ^GSPC
# 11     15160.85      LONG  ^GSPC
# 12     36651.41      LONG  ^GSPC
# 13     31928.21      LONG  ^GSPC
# 14     44822.30      LONG  ^GSPC
# 15     40604.10      LONG  ^GSPC
# 16     47245.32      LONG  ^GSPC
# 17     65322.05      LONG  ^GSPC
# 18     66224.93      LONG  ^GSPC
# 19     68989.17      LONG  ^GSPC
# 20     70203.51      LONG  ^GSPC
# 21     64522.36      LONG  ^GSPC
# 22     77711.97      LONG  ^GSPC
# 23     85441.17      LONG  ^GSPC
# 24    106873.17      LONG  ^GSPC
# 25    101547.07      LONG  ^GSPC
# 26     98138.32      LONG  ^GSPC
# 27    100466.56      LONG  ^GSPC
# 28    112471.28      LONG  ^GSPC
# 29    149877.59      LONG  ^GSPC
# 30    219814.60      LONG  ^GSPC
# 31    225657.66      LONG  ^GSPC
# 32    274409.07      LONG  ^GSPC
# 33    249402.72      LONG  ^GSPC
# 34    300985.69      LONG  ^GSPC
# 35    676519.04      LONG  ^GSPC
# 36    781831.11      LONG  ^GSPC
# 37    791686.75      LONG  ^GSPC
# 38    924660.93      LONG  ^GSPC
# 39    999666.58      LONG  ^GSPC
# 40   1131347.83      LONG  ^GSPC
# 41   1293884.89      LONG  ^GSPC
# 42   1289179.46      LONG  ^GSPC
# 43   1958198.36      LONG  ^GSPC
# 44   1863350.34      LONG  ^GSPC
# 45   2352475.50      LONG  ^GSPC
# 46   2154511.05      LONG  ^GSPC
# 47   2854958.08      LONG  ^GSPC
# 48   3694912.24      LONG  ^GSPC
# 49   4415921.21      LONG  ^GSPC

# %%
dbal = dbal.get_log(tlog)
dbal.tail()
# Out:
#                  high        low      close  shares       cash  leverage state
# date
# 2026-06-02 4547738.94 4547738.94 4547738.94     597    4700.41      1.00     -
# 2026-06-03 4514247.48 4514247.48 4514247.48     597    4700.41      1.00     -
# 2026-06-04 4532533.52 4532533.52 4532533.52     597    4700.41      1.00     -
# 2026-06-05 4412793.33 4412793.33 4412793.33     597    4700.41      1.00     -
# 2026-06-08 4425921.21 4425921.21 4425921.21       0 4425921.21      1.00     X

# %%
close = dbal['close']
close
# Out:
# date
# 1928-10-16     10000.00
# 1928-10-17     10000.00
# 1928-10-18     10000.00
# 1928-10-19     10000.00
# 1928-10-22     10000.00
#                 ...
# 2026-06-02   4547738.94
# 2026-06-03   4514247.48
# 2026-06-04   4532533.52
# 2026-06-05   4412793.33
# 2026-06-08   4425921.21
# Name: close, Length: 24526, dtype: float64

# %% [markdown]
# Generate strategy stats - display all available stats

# %%
stats = pf.stats(ts, tlog, dbal, capital)
pf.print_full(stats)
# Out:
# start                                                   1928-10-16
# end                                                     2026-06-08
# beginning_balance                                            10000
# ending_balance                                          4425921.21
# total_net_profit                                        4415921.21
# gross_profit                                            4770782.55
# gross_loss                                              -354861.34
# profit_factor                                                13.44
# return_on_initial_capital                                 44159.21
# annual_return_rate                                            6.44
# trading_period                           97 years 7 months 23 days
# pct_time_in_market                                           66.80
# margin                                                           1
# avg_leverage                                                  1.00
# max_leverage                                                  1.00
# min_leverage                                                  1.00
# total_num_trades                                                50
# trades_per_year                                               0.51
# num_winning_trades                                              34
# num_losing_trades                                               16
# num_even_trades                                                  0
# pct_profitable_trades                                        68.00
# avg_profit_per_trade                                      88318.42
# avg_profit_per_winning_trade                             140317.13
# avg_loss_per_losing_trade                                -22178.83
# ratio_avg_profit_win_loss                                     6.33
# largest_profit_winning_trade                             839954.16
# largest_loss_losing_trade                               -197964.45
# num_winning_points                                         6393.24
# num_losing_points                                          -405.75
# total_net_points                                           5987.49
# avg_points                                                  119.75
# largest_points_winning_trade                               1226.21
# largest_points_losing_trade                                -240.54
# avg_pct_gain_per_trade                                       15.48
# largest_pct_winning_trade                                   120.93
# largest_pct_losing_trade                                    -17.03
# expected_shortfall                                               0
# max_consecutive_winning_trades                                   8
# max_consecutive_losing_trades                                    4
# avg_bars_winning_trades                                     434.74
# avg_bars_losing_trades                                      103.19
# max_closed_out_drawdown                                     -36.86
# max_closed_out_drawdown_peak_date                       1937-03-10
# max_closed_out_drawdown_trough_date                     1941-11-13
# max_closed_out_drawdown_recovery_date                   1945-05-03
# drawdown_loss_period                                          1709
# drawdown_recovery_period                                      1267
# annualized_return_over_max_drawdown                           0.17
# max_intra_day_drawdown                                      -36.86
# avg_yearly_closed_out_drawdown                               -9.64
# max_yearly_closed_out_drawdown                              -35.09
# avg_monthly_closed_out_drawdown                              -2.35
# max_monthly_closed_out_drawdown                             -31.47
# avg_weekly_closed_out_drawdown                               -0.90
# max_weekly_closed_out_drawdown                              -28.51
# avg_yearly_closed_out_runup                                  17.01
# max_yearly_closed_out_runup                                  61.85
# avg_monthly_closed_out_runup                                  2.87
# max_monthly_closed_out_runup                                 26.55
# avg_weekly_closed_out_runup                                   1.04
# max_weekly_closed_out_runup                                  23.14
# pct_profitable_years                                         61.77
# best_year                                                    53.98
# worst_year                                                  -28.66
# avg_year                                                      7.19
# annual_std                                                   13.08
# pct_profitable_months                                        43.91
# best_month                                                   22.49
# worst_month                                                 -30.91
# avg_month                                                     0.55
# monthly_std                                                   3.29
# pct_profitable_weeks                                         39.13
# best_week                                                    23.14
# worst_week                                                  -27.33
# avg_week                                                      0.14
# weekly_std                                                    1.75
# pct_profitable_days                                          35.85
# best_day                                                     16.60
# worst_day                                                   -20.47
# avg_day                                                       0.03
# daily_std                                                     0.81
# sharpe_ratio                                                  0.55
# sharpe_ratio_max                                              0.57
# sharpe_ratio_min                                              0.53
# sortino_ratio                                                 0.55
# dtype: object

# %% [markdown]
# Run Benchmark

# %%
benchmark = pf.Benchmark(symbol, capital, start, end, use_adj=use_adj)
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Plot Trades

# %%
pf.plot_trades(dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Strategy vs Benchmark

# %%
df = pf.summary(stats, benchmark.stats, metrics=pf.currency_metrics)
df
# Out:
#                         strategy      benchmark
# beginning_balance     $10,000.00     $10,000.00
# ending_balance     $4,425,921.21  $3,414,042.76
# total_net_profit   $4,415,921.21  $3,404,042.76
# gross_profit       $4,770,782.55  $3,404,042.76
# gross_loss          -$354,861.34          $0.00

# %%
extras = ('avg_month',)

df = pf.plot_bar_graph(stats, benchmark.stats, extras=extras)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                       6.44       6.16
# max_closed_out_drawdown                -36.86     -86.16
# annualized_return_over_max_drawdown      0.17       0.07
# best_month                              22.49      61.49
# worst_month                            -30.91     -42.17
# sharpe_ratio                             0.55       0.41
# sortino_ratio                            0.55       0.52
# monthly_std                              3.29       5.29
# annual_std                              13.08      19.83
# avg_month                                0.55       0.62
