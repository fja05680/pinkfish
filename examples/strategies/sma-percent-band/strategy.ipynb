# %% [markdown]
# # SMA Percent Band
#
#     1. The SPY closes above its upper band, buy
#     2. If the SPY closes below its lower band, sell your long position.

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd

import pinkfish as pf
import strategy

# Format price data
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# Set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
symbol = '^GSPC'
#symbol = 'SPY'
#symbol = 'ES=F'
#symbol = 'DIA'
#symbol = 'QQQ'
#symbol = 'IWM'
#symbol = 'TLT'
#symbol = 'GLD'
#symbol = 'AAPL'
#symbol = 'BBRY'
#symbol = 'GDX'
capital = 10000
start = datetime.datetime(1900, 1, 1)
#start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()

# %%
options = {
    'use_adj' : True,
    'use_cache' : True,
    'sma' : 200,
    'band' : 3.0
}

# %% [markdown]
# Run Strategy

# %%
s = strategy.Strategy(symbol, capital, start, end, options)
s.run()

# %% [markdown]
# View logs

# %%
s.tlog.tail(10)
# Out:
#    entry_date  entry_price  exit_date  exit_price  pl_points    pl_cash   qty  \
# 47 2009-06-11       944.89 2010-05-26     1067.95     123.06  147794.98  1201
# 48 2010-10-05      1160.75 2011-08-04     1200.07      39.32   43448.54  1105
# 49 2012-01-18      1308.04 2015-08-21     1970.89     662.85  672129.88  1014
# 50 2016-04-13      2082.42 2018-10-24     2656.10     573.68  550159.29   959
# 51 2019-03-21      2854.88 2020-02-28     2954.22      99.34   88611.36   892
# 52 2020-06-03      3122.87 2022-02-22     4304.76    1181.89  997514.86   844
# 53 2022-03-29      4631.60 2022-04-22     4271.78    -359.82 -282099.12   784
# 54 2023-01-31      4076.60 2025-03-13     5521.52    1444.92 1187724.18   822
# 55 2025-05-16      5958.38 2026-03-27     6368.85     410.47  312778.30   762
# 56 2026-04-13      6886.24 2026-06-08     7405.73     519.49  365720.78   704
#
#     cumul_total direction symbol
# 47   1272964.65      LONG  ^GSPC
# 48   1316413.20      LONG  ^GSPC
# 49   1988543.07      LONG  ^GSPC
# 50   2538702.36      LONG  ^GSPC
# 51   2627313.72      LONG  ^GSPC
# 52   3624828.58      LONG  ^GSPC
# 53   3342729.46      LONG  ^GSPC
# 54   4530453.63      LONG  ^GSPC
# 55   4843231.94      LONG  ^GSPC
# 56   5208952.72      LONG  ^GSPC

# %%
s.dbal.tail(10)
# Out:
#                  high        low      close  shares       cash  leverage state
# date
# 2026-05-26 5298779.37 5298779.37 5298779.37     704    5318.81      1.00     -
# 2026-05-27 5299652.15 5299652.15 5299652.15     704    5318.81      1.00     -
# 2026-05-28 5330114.25 5330114.25 5330114.25     704    5318.81      1.00     -
# 2026-05-29 5341681.09 5341681.09 5341681.09     704    5318.81      1.00     -
# 2026-06-01 5355690.62 5355690.62 5355690.62     704    5318.81      1.00     -
# 2026-06-02 5362603.78 5362603.78 5362603.78     704    5318.81      1.00     -
# 2026-06-03 5323109.65 5323109.65 5323109.65     704    5318.81      1.00     -
# 2026-06-04 5344673.09 5344673.09 5344673.09     704    5318.81      1.00     -
# 2026-06-05 5203471.94 5203471.94 5203471.94     704    5318.81      1.00     -
# 2026-06-08 5218952.72 5218952.72 5218952.72       0 5218952.72      1.00     X

# %% [markdown]
# Display all available stats

# %%
pf.print_full(s.stats)
# Out:
# start                                                   1928-10-16
# end                                                     2026-06-08
# beginning_balance                                            10000
# ending_balance                                          5218952.72
# total_net_profit                                        5208952.72
# gross_profit                                            5612375.37
# gross_loss                                              -403422.65
# profit_factor                                                13.91
# return_on_initial_capital                                 52089.53
# annual_return_rate                                            6.62
# trading_period                           97 years 7 months 23 days
# pct_time_in_market                                           66.59
# margin                                                           1
# avg_leverage                                                  1.00
# max_leverage                                                  1.00
# min_leverage                                                  1.00
# total_num_trades                                                57
# trades_per_year                                               0.58
# num_winning_trades                                              35
# num_losing_trades                                               22
# num_even_trades                                                  0
# pct_profitable_trades                                        61.40
# avg_profit_per_trade                                      91385.14
# avg_profit_per_winning_trade                             160353.58
# avg_loss_per_losing_trade                                -18337.39
# ratio_avg_profit_win_loss                                     8.74
# largest_profit_winning_trade                            1187724.18
# largest_loss_losing_trade                               -282099.12
# num_winning_points                                         6634.72
# num_losing_points                                          -506.47
# total_net_points                                           6128.25
# avg_points                                                  107.51
# largest_points_winning_trade                               1444.92
# largest_points_losing_trade                                -359.82
# avg_pct_gain_per_trade                                       14.05
# largest_pct_winning_trade                                   116.43
# largest_pct_losing_trade                                    -16.41
# expected_shortfall                                          -16.41
# max_consecutive_winning_trades                                   6
# max_consecutive_losing_trades                                    6
# avg_bars_winning_trades                                     425.97
# avg_bars_losing_trades                                       67.18
# max_closed_out_drawdown                                     -52.93
# max_closed_out_drawdown_peak_date                       1932-09-07
# max_closed_out_drawdown_trough_date                     1933-03-21
# max_closed_out_drawdown_recovery_date                   1936-02-11
# drawdown_loss_period                                           195
# drawdown_recovery_period                                      1057
# annualized_return_over_max_drawdown                           0.13
# max_intra_day_drawdown                                      -52.93
# avg_yearly_closed_out_drawdown                               -9.01
# max_yearly_closed_out_drawdown                              -52.93
# avg_monthly_closed_out_drawdown                              -2.28
# max_monthly_closed_out_drawdown                             -27.18
# avg_weekly_closed_out_drawdown                               -0.87
# max_weekly_closed_out_drawdown                              -21.05
# avg_yearly_closed_out_runup                                  17.21
# max_yearly_closed_out_runup                                  70.84
# avg_monthly_closed_out_runup                                  2.80
# max_monthly_closed_out_runup                                 27.02
# avg_weekly_closed_out_runup                                   1.01
# max_weekly_closed_out_runup                                  16.07
# pct_profitable_years                                         63.45
# best_year                                                    64.80
# worst_year                                                  -47.79
# avg_year                                                      7.54
# annual_std                                                   13.71
# pct_profitable_months                                        43.81
# best_month                                                   27.02
# worst_month                                                 -27.06
# avg_month                                                     0.57
# monthly_std                                                   3.29
# pct_profitable_weeks                                         38.99
# best_week                                                    15.91
# worst_week                                                  -21.05
# avg_week                                                      0.14
# weekly_std                                                    1.68
# pct_profitable_days                                          35.83
# best_day                                                     11.81
# worst_day                                                    -8.88
# avg_day                                                       0.03
# daily_std                                                     0.76
# sharpe_ratio                                                  0.59
# sharpe_ratio_max                                              0.61
# sharpe_ratio_min                                              0.57
# sortino_ratio                                                 0.61
# dtype: object

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats

# %%
benchmark = pf.Benchmark(symbol, s.capital, s.start, s.end, use_adj=s.options['use_adj'])
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Plot Trades

# %%
pf.plot_trades(s.dbal, benchmark=benchmark.dbal)

# %%
print('trading period:  {} to {}'.format(s.stats['start'], s.stats['end']))
df = pf.summary(s.stats, benchmark.stats, metrics=pf.currency_metrics)
df
# Out:
# trading period:  1928-10-16 to 2026-06-08
#                         strategy      benchmark
# beginning_balance     $10,000.00     $10,000.00
# ending_balance     $5,218,952.72  $3,414,042.76
# total_net_profit   $5,208,952.72  $3,404,042.76
# gross_profit       $5,612,375.37  $3,404,042.76
# gross_loss          -$403,422.65          $0.00

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                       6.62       6.16
# max_closed_out_drawdown                -52.93     -86.16
# annualized_return_over_max_drawdown      0.13       0.07
# best_month                              27.02      61.49
# worst_month                            -27.06     -42.17
# sharpe_ratio                             0.59       0.41
# sortino_ratio                            0.61       0.52
# monthly_std                              3.29       5.29
# annual_std                              13.71      19.83

# %% [markdown]
# Print the raw transaction log

# %%
pd.set_option('display.max_rows', len(s.rlog))
s.rlog
# Out:
#           date  seq_num   price  shares entry_exit direction symbol
# 0   1932-08-10        0    7.65    1307      entry      LONG  ^GSPC
# 1   1932-08-12        1    7.00    1307       exit      LONG  ^GSPC
# 2   1932-08-16        2    7.68    1191      entry      LONG  ^GSPC
# 3   1932-10-10        3    6.42    1191       exit      LONG  ^GSPC
# 4   1932-10-14        4    7.13    1072      entry      LONG  ^GSPC
# 5   1932-11-02        5    6.52    1072       exit      LONG  ^GSPC
# 6   1932-11-07        6    7.24     966      entry      LONG  ^GSPC
# 7   1932-12-02        7    6.47     966       exit      LONG  ^GSPC
# 8   1932-12-07        8    6.89     907      entry      LONG  ^GSPC
# 9   1933-02-14        9    6.32     907       exit      LONG  ^GSPC
# 10  1933-03-15       10    6.81     842      entry      LONG  ^GSPC
# 11  1933-03-21       11    6.20     842       exit      LONG  ^GSPC
# 12  1933-04-19       12    7.14     731      entry      LONG  ^GSPC
# 13  1934-05-07       13    9.81     731       exit      LONG  ^GSPC
# 14  1935-04-22       14    9.41     762      entry      LONG  ^GSPC
# 15  1937-04-26       15   16.16     762       exit      LONG  ^GSPC
# 16  1938-06-29       16   11.72    1050      entry      LONG  ^GSPC
# 17  1939-03-22       17   11.75    1050       exit      LONG  ^GSPC
# 18  1939-09-05       18   12.64     976      entry      LONG  ^GSPC
# 19  1940-05-10       19   11.76     976       exit      LONG  ^GSPC
# 20  1940-11-07       20   11.39    1008      entry      LONG  ^GSPC
# 21  1940-12-19       21   10.40    1008       exit      LONG  ^GSPC
# 22  1941-07-28       22   10.47    1002      entry      LONG  ^GSPC
# 23  1941-10-16       23    9.58    1002       exit      LONG  ^GSPC
# 24  1942-09-22       24    8.68    1105      entry      LONG  ^GSPC
# 25  1943-11-08       25   11.26    1105       exit      LONG  ^GSPC
# 26  1944-03-13       26   12.24    1017      entry      LONG  ^GSPC
# 27  1946-08-26       27   17.47    1017       exit      LONG  ^GSPC
# 28  1947-07-01       28   15.46    1149      entry      LONG  ^GSPC
# 29  1947-12-05       29   14.63    1149       exit      LONG  ^GSPC
# 30  1948-04-21       30   15.54    1082      entry      LONG  ^GSPC
# 31  1948-11-09       31   15.01    1082       exit      LONG  ^GSPC
# 32  1949-08-08       32   15.51    1047      entry      LONG  ^GSPC
# 33  1950-07-17       33   16.68    1047       exit      LONG  ^GSPC
# 34  1950-07-31       34   17.84     979      entry      LONG  ^GSPC
# 35  1953-04-22       35   24.46     979       exit      LONG  ^GSPC
# 36  1954-01-06       36   25.14     952      entry      LONG  ^GSPC
# 37  1956-10-01       37   44.70     952       exit      LONG  ^GSPC
# 38  1957-05-20       38   47.35     899      entry      LONG  ^GSPC
# 39  1957-08-23       39   44.51     899       exit      LONG  ^GSPC
# 40  1958-05-02       40   43.69     915      entry      LONG  ^GSPC
# 41  1959-09-21       41   55.27     915       exit      LONG  ^GSPC
# 42  1959-12-30       42   59.77     846      entry      LONG  ^GSPC
# 43  1960-01-28       43   56.13     846       exit      LONG  ^GSPC
# 44  1960-12-21       44   57.55     825      entry      LONG  ^GSPC
# 45  1962-04-27       45   66.30     825       exit      LONG  ^GSPC
# 46  1962-12-06       46   62.93     870      entry      LONG  ^GSPC
# 47  1965-06-25       47   83.06     870       exit      LONG  ^GSPC
# 48  1965-09-10       48   89.12     810      entry      LONG  ^GSPC
# 49  1966-05-09       49   86.32     810       exit      LONG  ^GSPC
# 50  1967-01-18       50   85.79     815      entry      LONG  ^GSPC
# 51  1968-02-08       51   90.90     815       exit      LONG  ^GSPC
# 52  1968-04-11       52   96.53     768      entry      LONG  ^GSPC
# 53  1969-02-25       53   97.98     768       exit      LONG  ^GSPC
# 54  1969-05-08       54  105.10     716      entry      LONG  ^GSPC
# 55  1969-06-11       55   99.05     716       exit      LONG  ^GSPC
# 56  1970-10-02       56   85.16     833      entry      LONG  ^GSPC
# 57  1971-10-20       57   95.65     833       exit      LONG  ^GSPC
# 58  1971-12-21       58  101.80     782      entry      LONG  ^GSPC
# 59  1973-03-22       59  108.84     782       exit      LONG  ^GSPC
# 60  1975-02-12       60   79.92    1065      entry      LONG  ^GSPC
# 61  1976-11-10       61   98.81    1065       exit      LONG  ^GSPC
# 62  1976-12-27       62  106.06     992      entry      LONG  ^GSPC
# 63  1977-02-24       63   99.60     992       exit      LONG  ^GSPC
# 64  1978-04-25       64   96.64    1023      entry      LONG  ^GSPC
# 65  1978-10-31       65   93.15    1023       exit      LONG  ^GSPC
# 66  1979-01-26       66  101.86     935      entry      LONG  ^GSPC
# 67  1979-02-27       67   96.13     935       exit      LONG  ^GSPC
# 68  1979-03-27       68  102.48     877      entry      LONG  ^GSPC
# 69  1980-03-17       69  102.26     877       exit      LONG  ^GSPC
# 70  1980-05-23       70  110.62     811      entry      LONG  ^GSPC
# 71  1981-07-06       71  127.37     811       exit      LONG  ^GSPC
# 72  1982-08-26       72  118.55     871      entry      LONG  ^GSPC
# 73  1984-02-06       73  158.08     871       exit      LONG  ^GSPC
# 74  1984-08-09       74  165.54     832      entry      LONG  ^GSPC
# 75  1987-10-16       75  282.70     832       exit      LONG  ^GSPC
# 76  1988-06-14       76  274.30     857      entry      LONG  ^GSPC
# 77  1990-01-26       77  325.80     857       exit      LONG  ^GSPC
# 78  1990-05-14       78  354.75     787      entry      LONG  ^GSPC
# 79  1990-08-06       79  334.43     787       exit      LONG  ^GSPC
# 80  1991-01-31       80  343.93     765      entry      LONG  ^GSPC
# 81  1994-03-30       81  445.55     765       exit      LONG  ^GSPC
# 82  1994-08-29       82  474.59     718      entry      LONG  ^GSPC
# 83  1998-08-28       83 1027.14     718       exit      LONG  ^GSPC
# 84  1998-11-02       84 1111.60     663      entry      LONG  ^GSPC
# 85  1999-10-15       85 1247.41     663       exit      LONG  ^GSPC
# 86  1999-10-29       86 1362.93     607      entry      LONG  ^GSPC
# 87  2000-10-09       87 1402.03     607       exit      LONG  ^GSPC
# 88  2003-04-22       88  911.37     934      entry      LONG  ^GSPC
# 89  2004-08-06       89 1063.97     934       exit      LONG  ^GSPC
# 90  2004-11-04       90 1161.67     855      entry      LONG  ^GSPC
# 91  2007-08-15       91 1406.70     855       exit      LONG  ^GSPC
# 92  2007-09-18       92 1519.78     792      entry      LONG  ^GSPC
# 93  2007-11-19       93 1433.27     792       exit      LONG  ^GSPC
# 94  2009-06-11       94  944.89    1201      entry      LONG  ^GSPC
# 95  2010-05-26       95 1067.95    1201       exit      LONG  ^GSPC
# 96  2010-10-05       96 1160.75    1105      entry      LONG  ^GSPC
# 97  2011-08-04       97 1200.07    1105       exit      LONG  ^GSPC
# 98  2012-01-18       98 1308.04    1014      entry      LONG  ^GSPC
# 99  2015-08-21       99 1970.89    1014       exit      LONG  ^GSPC
# 100 2016-04-13      100 2082.42     959      entry      LONG  ^GSPC
# 101 2018-10-24      101 2656.10     959       exit      LONG  ^GSPC
# 102 2019-03-21      102 2854.88     892      entry      LONG  ^GSPC
# 103 2020-02-28      103 2954.22     892       exit      LONG  ^GSPC
# 104 2020-06-03      104 3122.87     844      entry      LONG  ^GSPC
# 105 2022-02-22      105 4304.76     844       exit      LONG  ^GSPC
# 106 2022-03-29      106 4631.60     784      entry      LONG  ^GSPC
# 107 2022-04-22      107 4271.78     784       exit      LONG  ^GSPC
# 108 2023-01-31      108 4076.60     822      entry      LONG  ^GSPC
# 109 2025-03-13      109 5521.52     822       exit      LONG  ^GSPC
# 110 2025-05-16      110 5958.38     762      entry      LONG  ^GSPC
# 111 2026-03-27      111 6368.85     762       exit      LONG  ^GSPC
# 112 2026-04-13      112 6886.24     704      entry      LONG  ^GSPC
# 113 2026-06-08      113 7405.73     704       exit      LONG  ^GSPC
