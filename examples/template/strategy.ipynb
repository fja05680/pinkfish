# %% [markdown]
# #Double 7's (Short Term Trading Strategies that Work)
#
#     1. The SPY is above its 200-day moving average
#     2. The SPY closes at a 7-day low, buy.
#     3. If the SPY closes at a 7-day high, sell your long position.

# %%
# %matplotlib inline

# %% [markdown]
# Use future imports for python 3.0 forward compatibility

# %%
from __future__ import print_function
from __future__ import unicode_literals
from __future__ import division
from __future__ import absolute_import

# %% [markdown]
# Other imports

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime
from talib.abstract import *
import pinkfish as pf
import strategy

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# Double the DPI, so we are making 2x plots:
matplotlib.rcParams['savefig.dpi'] = 2 * matplotlib.rcParams['savefig.dpi']

# %% [markdown]
# Some global data

# %%
#symbol = '^GSPC'
symbol = 'SPY'
#symbol = 'DIA'
#symbol = 'QQQ'
#symbol = 'IWM'
#symbol = 'TLT'
#symbol = 'GLD'
#symbol = 'AAPL'
#symbol = 'BBRY'
#symbol = 'GDX'
capital = 100000
start = datetime.datetime(1990, 1, 1)
#end = datetime.datetime(1970 12, 1)
end = datetime.datetime.now()

# %% [markdown]
# Define high low trade periods

# %%
period = 7

# %% [markdown]
# Run Strategy

# %%
s = strategy.Strategy(symbol, capital, start, end, int(period))
s.run()

# %% [markdown]
# Retrieve log DataFrames

# %%
s.tlog, s.dbal = s.get_logs()
s.stats = s.stats()

# %%
s.tlog.tail(100)
# Out:
#     entry_date  entry_price long_short     qty            exit_date  \
# 121 2006-03-28       129.22       long 2348.00  2006-04-04 00:00:00
# 122 2006-04-07       129.54       long 2367.00  2006-04-18 00:00:00
# 123 2006-05-12       129.24       long 2394.00  2006-05-25 00:00:00
# 124 2006-08-24       129.65       long 2358.00  2006-08-29 00:00:00
# 125 2006-09-07       129.91       long 2370.00  2006-09-12 00:00:00
# 126 2006-09-22       131.47       long 2374.00  2006-09-26 00:00:00
# 127 2006-11-01       136.86       long 2317.00  2006-11-06 00:00:00
# 128 2006-11-27       138.42       long 2312.00  2006-12-04 00:00:00
# 129 2006-12-21       141.62       long 2306.00  2006-12-27 00:00:00
# 130 2007-01-05       140.54       long 2339.00  2007-01-11 00:00:00
# 131 2007-01-25       142.26       long 2337.00  2007-02-01 00:00:00
# 132 2007-02-09       143.94       long 2348.00  2007-02-14 00:00:00
# 133 2007-02-23       145.30       long 2353.00  2007-03-09 00:00:00
# 134 2007-05-24       151.06       long 2193.00  2007-05-30 00:00:00
# 135 2007-06-06       151.84       long 2216.00  2007-06-14 00:00:00
# 136 2007-06-22       150.55       long 2250.00  2007-07-02 00:00:00
# 137 2007-07-20       153.50       long 2225.00  2007-08-07 00:00:00
# 138 2007-10-15       155.01       long 2121.00  2007-10-29 00:00:00
# 139 2007-11-01       151.03       long 2165.00  2007-11-28 00:00:00
# 140 2009-06-15        92.90       long 3429.00  2009-06-29 00:00:00
# 141 2009-07-02        89.81       long 3539.00  2009-07-13 00:00:00
# 142 2009-08-11        99.73       long 3198.00  2009-08-13 00:00:00
# 143 2009-08-17        98.31       long 3304.00  2009-08-21 00:00:00
# 144 2009-08-31       102.46       long 3320.00  2009-09-09 00:00:00
# 145 2009-09-24       105.01       long 3280.00  2009-10-08 00:00:00
# 146 2009-10-23       108.08       long 3235.00  2009-11-05 00:00:00
# 147 2009-12-08       109.61       long 3153.00  2009-12-11 00:00:00
# 148 2009-12-31       111.44       long 3144.00  2010-01-04 00:00:00
# 149 2010-01-15       113.64       long 3136.00  2010-01-19 00:00:00
# 150 2010-01-21       111.70       long 3230.00  2010-02-02 00:00:00
# ..         ...          ...        ...     ...                  ...
# 191 2013-12-03       179.75       long 2550.00  2013-12-09 00:00:00
# 192 2013-12-11       178.72       long 2588.00  2013-12-18 00:00:00
# 193 2014-01-03       182.89       long 2571.00  2014-01-10 00:00:00
# 194 2014-01-13       181.69       long 2606.00  2014-01-15 00:00:00
# 195 2014-01-23       182.79       long 2632.00  2014-02-07 00:00:00
# 196 2014-03-13       185.18       long 2554.00  2014-03-20 00:00:00
# 197 2014-03-26       184.97       long 2593.00  2014-03-31 00:00:00
# 198 2014-04-07       184.34       long 2630.00  2014-04-21 00:00:00
# 199 2014-05-06       186.78       long 2634.00  2014-05-12 00:00:00
# 200 2014-05-15       187.40       long 2667.00  2014-05-22 00:00:00
# 201 2014-07-17       195.71       long 2584.00  2014-07-22 00:00:00
# 202 2014-07-29       196.95       long 2600.00  2014-08-13 00:00:00
# 203 2014-09-09       199.32       long 2542.00  2014-09-17 00:00:00
# 204 2014-09-23       198.01       long 2577.00  2014-10-21 00:00:00
# 205 2014-12-10       203.16       long 2462.00  2014-12-18 00:00:00
# 206 2014-12-31       205.54       long 2477.00  2015-01-21 00:00:00
# 207 2015-01-28       200.14       long 2513.00  2015-02-05 00:00:00
# 208 2015-03-04       210.23       long 2464.00  2015-03-16 00:00:00
# 209 2015-03-25       205.76       long 2498.00  2015-04-09 00:00:00
# 210 2015-04-17       207.95       long 2509.00  2015-04-22 00:00:00
# 211 2015-04-30       208.46       long 2535.00  2015-05-08 00:00:00
# 212 2015-05-26       210.70       long 2546.00  2015-06-18 00:00:00
# 213 2015-06-25       209.86       long 2582.00  2015-07-13 00:00:00
# 214 2015-07-23       210.18       long 2577.00  2015-08-10 00:00:00
# 215 2015-08-19       208.32       long 2604.00  2015-09-15 00:00:00
# 216 2015-11-11       207.74       long 2488.00  2015-11-18 00:00:00
# 217 2015-12-02       208.53       long 2490.00  2015-12-16 00:00:00
# 218 2016-03-24       203.12       long 2551.00  2016-03-29 00:00:00
# 219 2016-04-07       203.95       long 2565.00  2016-04-13 00:00:00
# 220 2016-04-28       207.45       long 2572.00  2016-05-10 00:00:00
#
#      exit_price  pl_points   pl_cash  cumul_total
# 121      130.56       1.34   3146.31    206670.21
# 122      130.70       1.16   2745.73    209415.94
# 123      127.73      -1.51  -3614.94    205801.00
# 124      130.58       0.93   2192.96    207993.95
# 125      131.69       1.78   4218.60    212212.55
# 126      133.58       2.11   5009.14    217221.69
# 127      138.08       1.22   2826.74    220048.43
# 128      141.29       2.87   6635.43    226683.86
# 129      142.51       0.89   2052.34    228736.20
# 130      142.16       1.62   3789.21    232525.41
# 131      144.61       2.35   5491.96    238017.37
# 132      145.61       1.67   3921.16    241938.53
# 133      140.78      -4.52 -10635.57    231302.96
# 134      153.48       2.42   5307.06    236610.02
# 135      152.86       1.02   2260.33    238870.35
# 136      151.79       1.24   2789.98    241660.33
# 137      147.77      -5.73 -12749.24    228911.08
# 138      154.13      -0.88  -1866.46    227044.63
# 139      147.13      -3.90  -8443.49    218601.14
# 140       92.70      -0.20   -685.82    217915.32
# 141       90.10       0.29   1026.31    218941.63
# 142      101.57       1.84   5884.31    224825.94
# 143      102.97       4.66  15396.65    240222.59
# 144      103.73       1.27   4216.41    244439.00
# 145      106.61       1.60   5248.00    249687.00
# 146      106.85      -1.23  -3979.06    245707.94
# 147      111.11       1.50   4729.50    250437.44
# 148      113.33       1.89   5942.16    256379.60
# 149      115.06       1.42   4453.12    260832.72
# 150      110.38      -1.32  -4263.60    256569.12
# ..          ...        ...       ...          ...
# 191      181.40       1.65   4207.48    362616.13
# 192      181.70       2.98   7712.23    370328.36
# 193      184.14       1.25   3213.75    373542.11
# 194      184.66       2.97   7739.83    381281.93
# 195      179.68      -3.11  -8185.52    373096.41
# 196      187.75       2.57   6563.80    379660.21
# 197      187.01       2.04   5289.70    384949.92
# 198      187.04       2.70   7100.99    392050.91
# 199      189.79       3.01   7928.32    399979.23
# 200      189.59       2.19   5840.74    405819.97
# 201      198.20       2.49   6434.13    412254.10
# 202      194.84      -2.11  -5486.00    406768.10
# 203      200.75       1.43   3635.04    410403.14
# 204      194.07      -3.94 -10153.35    400249.79
# 205      206.78       3.62   8912.43    409162.22
# 206      203.08      -2.46  -6093.40    403068.82
# 207      206.12       5.98  15027.73    418096.55
# 208      208.58      -1.65  -4065.59    414030.97
# 209      208.90       3.14   7843.72    421874.68
# 210      210.63       2.68   6724.14    428598.82
# 211      211.62       3.16   8010.57    436609.39
# 212      212.78       2.08   5295.69    441905.08
# 213      209.76      -0.10   -258.22    441646.86
# 214      210.57       0.39   1005.07    442651.93
# 215      198.45      -9.87 -25701.51    416950.42
# 216      208.73       0.99   2463.10    419413.52
# 217      208.03      -0.50  -1245.00    418168.52
# 218      205.12       2.00   5102.00    423270.52
# 219      208.00       4.05  10388.26    433658.78
# 220      208.45       1.00   2572.00    436230.78
#
# [100 rows x 9 columns]

# %%
s.dbal.tail()
# Out:
#                 high       low     close  shares      cash  state
# date
# 2016-05-06 529337.84 524476.76 529209.23 2572.00     97.39      1
# 2016-05-09 530958.17 528283.31 529646.46 2572.00     97.39      1
# 2016-05-10 536282.23 531575.46 536230.78 2572.00     97.39      2
# 2016-05-11 536230.78 536230.78 536230.78    0.00 536230.78      1
# 2016-05-12 536230.78 536230.78 536230.78    0.00 536230.78      1

# %% [markdown]
# Generate strategy stats - display all available stats

# %%
pf.print_full(s.stats)
# Out:
# start                                                  1993-11-11
# end                                                    2016-05-12
# beginning_balance                                          100000
# ending_balance                                          536230.78
# total_net_profit                                        436230.78
# gross_profit                                            730224.04
# gross_loss                                             -293993.27
# profit_factor                                                2.48
# return_on_initial_capital                                  436.23
# annual_return_rate                                           7.75
# trading_period                           22 years 6 months 1 days
# pct_time_in_market                                          33.45
# total_num_trades                                              221
# num_winning_trades                                            173
# num_losing_trades                                              47
# num_even_trades                                                 1
# pct_profitable_trades                                       78.28
# avg_profit_per_trade                                      1973.89
# avg_profit_per_winning_trade                              4220.95
# avg_loss_per_losing_trade                                -6255.18
# ratio_avg_profit_win_loss                                    0.67
# largest_profit_winning_trade                             16560.76
# largest_loss_losing_trade                               -29141.61
# num_winning_points                                         319.22
# num_losing_points                                         -123.51
# total_net_points                                           195.70
# avg_points                                                   0.89
# largest_points_winning_trade                                 9.47
# largest_points_losing_trade                                -10.25
# avg_pct_gain_per_trade                                       0.78
# largest_pct_winning_trade                                    6.92
# largest_pct_losing_trade                                    -7.64
# max_consecutive_winning_trades                                 18
# max_consecutive_losing_trades                                   4
# avg_bars_winning_trades                                      6.73
# avg_bars_losing_trades                                      15.38
# max_closed_out_drawdown                                    -14.66
# max_closed_out_drawdown_start_date                     2000-07-03
# max_closed_out_drawdown_end_date                       2002-05-07
# max_closed_out_drawdown_recovery_date                  2003-12-11
# drawdown_recovery                                           -1.84
# drawdown_annualized_return                                  -1.89
# max_intra_day_drawdown                                     -16.31
# avg_yearly_closed_out_drawdown                              -6.48
# max_yearly_closed_out_drawdown                             -14.04
# avg_monthly_closed_out_drawdown                             -1.48
# max_monthly_closed_out_drawdown                            -14.04
# avg_weekly_closed_out_drawdown                              -0.49
# max_weekly_closed_out_drawdown                             -12.82
# avg_yearly_closed_out_runup                                 13.01
# max_yearly_closed_out_runup                                 41.26
# avg_monthly_closed_out_runup                                 1.96
# max_monthly_closed_out_runup                                12.91
# avg_weekly_closed_out_runup                                  0.65
# max_weekly_closed_out_runup                                  7.81
# pct_profitable_years                                        77.60
# best_year                                                   40.54
# worst_year                                                  -7.68
# avg_year                                                     8.34
# annual_std                                                   9.24
# pct_profitable_months                                       50.57
# best_month                                                  12.91
# worst_month                                                -13.54
# avg_month                                                    0.62
# monthly_std                                                  2.11
# pct_profitable_weeks                                        28.42
# best_week                                                    7.81
# worst_week                                                 -12.82
# avg_week                                                     0.16
# weekly_std                                                   1.22
# sharpe_ratio                                                 0.80
# sortino_ratio                                                0.60
# dtype: object

# %% [markdown]
# Equity curve

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats

# %%
benchmark = pf.Benchmark(symbol, capital, s._start, s._end)
benchmark.run()
benchmark.tlog, benchmark.dbal = benchmark.get_logs()
benchmark.stats = benchmark.stats()
# Out:
# 1993-11-11 00:00:00 BUY  3270 SPY @ 30.58
# 2016-05-12 00:00:00 SELL 3270.0 SPY @ 206.56

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Plot Trades

# %%
pf.plot_trades(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
metrics = ('annual_return_rate',
           'max_closed_out_drawdown',
           'drawdown_annualized_return',
           'drawdown_recovery',
           'best_month',
           'worst_month',
           'sharpe_ratio',
           'sortino_ratio',
           'monthly_std')

df = pf.plot_bar_graph(s.stats, benchmark.stats, *metrics)
df
# Out:
#                             strategy  benchmark
# annual_return_rate              7.75       8.86
# max_closed_out_drawdown       -14.66     -55.19
# drawdown_annualized_return     -1.89      -6.23
# drawdown_recovery              -1.84      -1.42
# best_month                     12.91      23.62
# worst_month                   -13.54     -29.41
# sharpe_ratio                    0.80       0.54
# sortino_ratio                   0.60       0.71
# monthly_std                     2.11       4.50
