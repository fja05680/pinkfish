# %% [markdown]
# # Double 7's (Short Term Trading Strategies that Work)
#
#     1. The SPY is above its 200-day moving average
#     2. The SPY closes at a X-day low, buy some shares.
#        If it falls further, buy some more, etc...
#     3. If the SPY closes at a X-day high, sell your entire long position.
#
#     (Scaling in; compare regular trade log vs merged trade log)

# %%
# use future imports for python 3.x forward compatibility
from __future__ import print_function
from __future__ import unicode_literals
from __future__ import division
from __future__ import absolute_import

# other imports
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from talib.abstract import *

# project imports
import pinkfish as pf
import strategy

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
capital = 10000
start = datetime.datetime(2000, 1, 1)
end = datetime.datetime.now()

# %% [markdown]
# Define symbols

# %%
symbols = ['SPY', 'SPY_merged']

# %% [markdown]
# Define high low trade periods

# %%
period = 8

# %% [markdown]
# Define max number of positions to scale into

# %%
max_positions = 4

# %% [markdown]
# Run Strategy

# %%
merge_trades = False
strategies = pd.Series()
for symbol in symbols:
    strategies[symbol] = strategy.Strategy(symbols[0], capital, start, end,
                                           period=period,max_positions=max_positions)
    strategies[symbol].run()
    _, strategies[symbol].tlog, strategies[symbol].dbal = strategies[symbol].get_logs(merge_trades)
    strategies[symbol].stats = strategies[symbol].get_stats()
    merge_trades = True

# %% [markdown]
# Summarize results

# %%
metrics = strategies[symbol].stats.index

df = strategy.summary(strategies, *metrics)
pd.set_option('display.max_columns', len(df.columns))
pd.set_option('display.max_rows', len(df))
df
# Out:
#                                                               SPY  \
# start                                                  2000-01-03
# end                                                    2019-12-19
# beginning_balance                                           10000
# ending_balance                                           23647.55
# total_net_profit                                         13647.55
# gross_profit                                             20393.99
# gross_loss                                               -6746.45
# profit_factor                                                3.02
# return_on_initial_capital                                  136.48
# annual_return_rate                                           4.41
# trading_period                         19 years 11 months 16 days
# pct_time_in_market                                          27.73
# total_num_trades                                              404
# trades_per_year                                             20.24
# num_winning_trades                                            320
# num_losing_trades                                              84
# num_even_trades                                                 0
# pct_profitable_trades                                       79.21
# avg_profit_per_trade                                        33.78
# avg_profit_per_winning_trade                                63.73
# avg_loss_per_losing_trade                                  -80.31
# ratio_avg_profit_win_loss                                    0.79
# largest_profit_winning_trade                               287.04
# largest_loss_losing_trade                                 -289.42
# num_winning_points                                         838.09
# num_losing_points                                         -288.57
# total_net_points                                           549.53
# avg_points                                                   1.36
# largest_points_winning_trade                                11.96
# largest_points_losing_trade                                -14.32
# avg_pct_gain_per_trade                                       0.87
# largest_pct_winning_trade                                    6.69
# largest_pct_losing_trade                                    -7.64
# max_consecutive_winning_trades                                 32
# max_consecutive_losing_trades                                   5
# avg_bars_winning_trades                                      7.20
# avg_bars_losing_trades                                      16.49
# max_closed_out_drawdown                                    -13.36
# max_closed_out_drawdown_start_date                     2011-07-21
# max_closed_out_drawdown_end_date                       2011-08-08
# max_closed_out_drawdown_recovery_date                  2012-12-31
# drawdown_recovery                                           -0.05
# drawdown_annualized_return                                  -3.03
# max_intra_day_drawdown                                     -15.68
# avg_yearly_closed_out_drawdown                              -4.12
# max_yearly_closed_out_drawdown                             -13.36
# avg_monthly_closed_out_drawdown                             -0.77
# max_monthly_closed_out_drawdown                            -13.36
# avg_weekly_closed_out_drawdown                              -0.26
# max_weekly_closed_out_drawdown                             -12.73
# avg_yearly_closed_out_runup                                  7.47
# max_yearly_closed_out_runup                                 18.48
# avg_monthly_closed_out_runup                                 1.07
# max_monthly_closed_out_runup                                 7.38
# avg_weekly_closed_out_runup                                  0.35
# max_weekly_closed_out_runup                                  7.38
# pct_profitable_years                                        75.19
# best_year                                                   17.08
# worst_year                                                  -7.17
# avg_year                                                     4.42
# annual_std                                                   4.84
# pct_profitable_months                                       50.46
# best_month                                                   7.38
# worst_month                                                -11.68
# avg_month                                                    0.34
# monthly_std                                                  1.24
# pct_profitable_weeks                                        27.56
# best_week                                                    7.38
# worst_week                                                 -12.73
# avg_week                                                     0.09
# weekly_std                                                   0.79
# sharpe_ratio                                                 0.70
# sortino_ratio                                                0.44
#
#                                                        SPY_merged
# start                                                  2000-01-03
# end                                                    2019-12-19
# beginning_balance                                           10000
# ending_balance                                           23647.55
# total_net_profit                                         13647.55
# gross_profit                                             19201.36
# gross_loss                                               -5553.82
# profit_factor                                                3.46
# return_on_initial_capital                                  136.48
# annual_return_rate                                           4.41
# trading_period                         19 years 11 months 16 days
# pct_time_in_market                                          27.73
# total_num_trades                                              168
# trades_per_year                                              8.42
# num_winning_trades                                            143
# num_losing_trades                                              25
# num_even_trades                                                 0
# pct_profitable_trades                                       85.12
# avg_profit_per_trade                                        81.24
# avg_profit_per_winning_trade                               134.28
# avg_loss_per_losing_trade                                 -222.15
# ratio_avg_profit_win_loss                                    0.60
# largest_profit_winning_trade                               586.33
# largest_loss_losing_trade                                -1077.68
# num_winning_points                                         784.78
# num_losing_points                                         -235.25
# total_net_points                                           549.53
# avg_points                                                   3.27
# largest_points_winning_trade                                25.65
# largest_points_losing_trade                                -52.00
# avg_pct_gain_per_trade                                       2.08
# largest_pct_winning_trade                                   12.80
# largest_pct_losing_trade                                   -28.10
# max_consecutive_winning_trades                                 26
# max_consecutive_losing_trades                                   3
# avg_bars_winning_trades                                      7.71
# avg_bars_losing_trades                                      18.32
# max_closed_out_drawdown                                    -13.36
# max_closed_out_drawdown_start_date                     2011-07-21
# max_closed_out_drawdown_end_date                       2011-08-08
# max_closed_out_drawdown_recovery_date                  2012-12-31
# drawdown_recovery                                           -0.05
# drawdown_annualized_return                                  -3.03
# max_intra_day_drawdown                                     -15.68
# avg_yearly_closed_out_drawdown                              -4.12
# max_yearly_closed_out_drawdown                             -13.36
# avg_monthly_closed_out_drawdown                             -0.77
# max_monthly_closed_out_drawdown                            -13.36
# avg_weekly_closed_out_drawdown                              -0.26
# max_weekly_closed_out_drawdown                             -12.73
# avg_yearly_closed_out_runup                                  7.47
# max_yearly_closed_out_runup                                 18.48
# avg_monthly_closed_out_runup                                 1.07
# max_monthly_closed_out_runup                                 7.38
# avg_weekly_closed_out_runup                                  0.35
# max_weekly_closed_out_runup                                  7.38
# pct_profitable_years                                        75.19
# best_year                                                   17.08
# worst_year                                                  -7.17
# avg_year                                                     4.42
# annual_std                                                   4.84
# pct_profitable_months                                       50.46
# best_month                                                   7.38
# worst_month                                                -11.68
# avg_month                                                    0.34
# monthly_std                                                  1.24
# pct_profitable_weeks                                        27.56
# best_week                                                    7.38
# worst_week                                                 -12.73
# avg_week                                                     0.09
# weekly_std                                                   0.79
# sharpe_ratio                                                 0.70
# sortino_ratio                                                0.44
