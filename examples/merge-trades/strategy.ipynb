# %% [markdown]
# # Double 7's (Short Term Trading Strategies that Work)
#
#     1. The SPY is above its 200-day moving average
#     2. The SPY closes at a X-day low, buy some shares.
#        If it falls further, buy some more, etc...
#     3. If the SPY closes at a X-day high, sell your entire long position.
#
#     (Scaling in; compare regular trade log vs merged trade log)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from talib.abstract import *

import pinkfish as pf
import strategy

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
capital = 10000
start = datetime.datetime(2000, 1, 1)
end = datetime.datetime.now()

# %% [markdown]
# Define symbols

# %%
symbols = ['SPY', 'SPY_merged']

# %% [markdown]
# Define high low trade periods

# %%
period = 8

# %% [markdown]
# Define max number of positions to scale into

# %%
max_positions = 4

# %% [markdown]
# Run Strategy

# %%
merge_trades = False
strategies = pd.Series(dtype=object)
for symbol in symbols:
    strategies[symbol] = strategy.Strategy(symbols[0], capital, start, end,
                                           period=period,max_positions=max_positions)
    strategies[symbol].run()
    _, strategies[symbol].tlog, strategies[symbol].dbal = strategies[symbol].get_logs(merge_trades)
    strategies[symbol].stats = strategies[symbol].get_stats()
    merge_trades = True

# %% [markdown]
# Summarize results

# %%
metrics = strategies[symbol].stats.index

df = strategy.summary(strategies, metrics)
pd.set_option('display.max_columns', len(df.columns))
pd.set_option('display.max_rows', len(df))
df
# Out:
#                                                              SPY  \
# start                                                 2000-01-03
# end                                                   2021-03-26
# beginning_balance                                          10000
# ending_balance                                          21149.64
# total_net_profit                                        11149.64
# gross_profit                                            22323.72
# gross_loss                                             -11174.08
# profit_factor                                               2.00
# return_on_initial_capital                                 111.50
# annual_return_rate                                          3.59
# trading_period                         21 years 2 months 23 days
# pct_time_in_market                                         27.82
# margin                                                         1
# avg_leverage                                                1.00
# max_leverage                                                1.00
# min_leverage                                                1.00
# total_num_trades                                             429
# trades_per_year                                            20.21
# num_winning_trades                                           339
# num_losing_trades                                             90
# num_even_trades                                                0
# pct_profitable_trades                                      79.02
# avg_profit_per_trade                                       25.99
# avg_profit_per_winning_trade                               65.85
# avg_loss_per_losing_trade                                -124.16
# ratio_avg_profit_win_loss                                   0.53
# largest_profit_winning_trade                              287.04
# largest_loss_losing_trade                               -1228.76
# num_winning_points                                        972.10
# num_losing_points                                        -531.95
# total_net_points                                          440.16
# avg_points                                                  1.03
# largest_points_winning_trade                               16.88
# largest_points_losing_trade                               -72.28
# avg_pct_gain_per_trade                                      0.73
# largest_pct_winning_trade                                   6.69
# largest_pct_losing_trade                                  -21.67
# expected_shortfall                                        -18.32
# max_consecutive_winning_trades                                32
# max_consecutive_losing_trades                                  5
# avg_bars_winning_trades                                     7.22
# avg_bars_losing_trades                                     16.79
# max_closed_out_drawdown                                   -30.83
# max_closed_out_drawdown_peak_date                     2018-09-13
# max_closed_out_drawdown_trough_date                   2020-03-23
# max_closed_out_drawdown_recovery_date          Not Recovered Yet
# drawdown_loss_period                           Not Recovered Yet
# drawdown_recovery_period                       Not Recovered Yet
# annualized_return_over_max_drawdown                         0.12
# max_intra_day_drawdown                                    -32.45
# avg_yearly_closed_out_drawdown                             -5.34
# max_yearly_closed_out_drawdown                            -29.92
# avg_monthly_closed_out_drawdown                            -0.90
# max_monthly_closed_out_drawdown                           -29.36
# avg_weekly_closed_out_drawdown                             -0.30
# max_weekly_closed_out_drawdown                            -17.78
# avg_yearly_closed_out_runup                                 8.00
# max_yearly_closed_out_runup                                25.46
# avg_monthly_closed_out_runup                                1.16
# max_monthly_closed_out_runup                               16.91
# avg_weekly_closed_out_runup                                 0.39
# max_weekly_closed_out_runup                                16.91
# pct_profitable_years                                       71.65
# best_year                                                  25.22
# worst_year                                                -28.26
# avg_year                                                    3.43
# annual_std                                                  6.43
# pct_profitable_months                                      50.58
# best_month                                                 16.91
# worst_month                                               -29.36
# avg_month                                                   0.29
# monthly_std                                                 1.77
# pct_profitable_weeks                                       27.34
# best_week                                                  16.91
# worst_week                                                -17.78
# avg_week                                                    0.07
# weekly_std                                                  1.03
# pct_profitable_days                                        15.69
# best_day                                                    8.93
# worst_day                                                 -10.81
# avg_day                                                     0.02
# daily_std                                                   0.54
# sharpe_ratio                                                0.45
# sharpe_ratio_max                                            0.50
# sharpe_ratio_min                                            0.41
# sortino_ratio                                               0.26
#
#                                                       SPY_merged
# start                                                 2000-01-03
# end                                                   2021-03-26
# beginning_balance                                          10000
# ending_balance                                          21149.64
# total_net_profit                                        22189.29
# gross_profit                                            21017.72
# gross_loss                                              -9868.08
# profit_factor                                               2.13
# return_on_initial_capital                                 221.89
# annual_return_rate                                          3.59
# trading_period                         21 years 2 months 23 days
# pct_time_in_market                                         27.82
# margin                                                         1
# avg_leverage                                                1.00
# max_leverage                                                1.00
# min_leverage                                                1.00
# total_num_trades                                             177
# trades_per_year                                             8.34
# num_winning_trades                                           151
# num_losing_trades                                             26
# num_even_trades                                                0
# pct_profitable_trades                                      85.31
# avg_profit_per_trade                                      125.36
# avg_profit_per_winning_trade                              139.19
# avg_loss_per_losing_trade                                -379.54
# ratio_avg_profit_win_loss                                   0.37
# largest_profit_winning_trade                              586.33
# largest_loss_losing_trade                               -4314.27
# num_winning_points                                        910.66
# num_losing_points                                        -470.50
# total_net_points                                          440.16
# avg_points                                                  2.49
# largest_points_winning_trade                               27.90
# largest_points_losing_trade                              -235.25
# avg_pct_gain_per_trade                                      1.76
# largest_pct_winning_trade                                  12.80
# largest_pct_losing_trade                                  -73.63
# expected_shortfall                                        -73.63
# max_consecutive_winning_trades                                26
# max_consecutive_losing_trades                                  3
# avg_bars_winning_trades                                     7.81
# avg_bars_losing_trades                                     18.58
# max_closed_out_drawdown                                   -30.83
# max_closed_out_drawdown_peak_date                     2018-09-13
# max_closed_out_drawdown_trough_date                   2020-03-23
# max_closed_out_drawdown_recovery_date          Not Recovered Yet
# drawdown_loss_period                           Not Recovered Yet
# drawdown_recovery_period                       Not Recovered Yet
# annualized_return_over_max_drawdown                         0.12
# max_intra_day_drawdown                                    -32.45
# avg_yearly_closed_out_drawdown                             -5.34
# max_yearly_closed_out_drawdown                            -29.92
# avg_monthly_closed_out_drawdown                            -0.90
# max_monthly_closed_out_drawdown                           -29.36
# avg_weekly_closed_out_drawdown                             -0.30
# max_weekly_closed_out_drawdown                            -17.78
# avg_yearly_closed_out_runup                                 8.00
# max_yearly_closed_out_runup                                25.46
# avg_monthly_closed_out_runup                                1.16
# max_monthly_closed_out_runup                               16.91
# avg_weekly_closed_out_runup                                 0.39
# max_weekly_closed_out_runup                                16.91
# pct_profitable_years                                       71.65
# best_year                                                  25.22
# worst_year                                                -28.26
# avg_year                                                    3.43
# annual_std                                                  6.43
# pct_profitable_months                                      50.58
# best_month                                                 16.91
# worst_month                                               -29.36
# avg_month                                                   0.29
# monthly_std                                                 1.77
# pct_profitable_weeks                                       27.34
# best_week                                                  16.91
# worst_week                                                -17.78
# avg_week                                                    0.07
# weekly_std                                                  1.03
# pct_profitable_days                                        15.69
# best_day                                                    8.93
# worst_day                                                 -10.81
# avg_day                                                     0.02
# daily_std                                                   0.54
# sharpe_ratio                                                0.45
# sharpe_ratio_max                                            0.50
# sharpe_ratio_min                                            0.41
# sortino_ratio                                               0.26
