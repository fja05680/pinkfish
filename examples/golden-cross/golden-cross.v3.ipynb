# %% [markdown]
# # Golden Cross / Death Cross S&P 500 index (^GSPC)

# %%
# %matplotlib inline

# %% [markdown]
# Use future imports for python 3.0 forward compatibility

# %%
from __future__ import print_function
from __future__ import unicode_literals
from __future__ import division
from __future__ import absolute_import

# %% [markdown]
# Other imports

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime
from talib.abstract import *
import pinkfish as pf

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# Double the DPI, so we are making 2x plots:
matplotlib.rcParams['savefig.dpi'] = 2 * matplotlib.rcParams['savefig.dpi']

# %% [markdown]
# Some global data

# %%
symbol = '^GSPC'
#symbol = 'SPY'
#symbol = 'DIA'
#symbol = 'QQQ'
#symbol = 'IWM'
#symbol = 'TLT'
#symbol = 'GLD'
#symbol = 'AAPL'
#symbol = 'BBRY'
capital = 10000
start = datetime.datetime(2000, 1, 1)
end = datetime.datetime(2015, 5, 1)

# %% [markdown]
# Fetch symbol data from internet

# %%
ts = pf.fetch_timeseries(symbol)

# %%
ts.head()
# Out:
#             open  high   low  close  adj_close   volume
# date
# 1950-01-03 16.66 16.66 16.66  16.66      16.66  1260000
# 1950-01-04 16.85 16.85 16.85  16.85      16.85  1890000
# 1950-01-05 16.93 16.93 16.93  16.93      16.93  2550000
# 1950-01-06 16.98 16.98 16.98  16.98      16.98  2010000
# 1950-01-09 17.09 17.09 17.08  17.08      17.08  3850000

# %% [markdown]
# Select timeseries between start and end. Back adjust prices relative to adj_close for dividends and splits.

# %%
ts = pf.select_tradeperiod(ts, start, end, use_adj=True)

# %%
ts.head()
# Out:
#               open    high     low   close  adj_close     volume
# date
# 1999-01-04 1229.23 1248.81 1219.10 1228.10    1228.10  877000000
# 1999-01-05 1228.10 1246.11 1228.10 1244.78    1244.78  775000000
# 1999-01-06 1244.78 1272.50 1244.78 1272.34    1272.34  986900000
# 1999-01-07 1272.34 1272.34 1257.68 1269.73    1269.73  863000000
# 1999-01-08 1269.73 1278.24 1261.82 1275.09    1275.09  937800000

# %% [markdown]
# Add technical indicator: 50 day ma, and 200 day ma

# %%
sma50 = SMA(ts, timeperiod=50)
ts['sma50'] = sma50

sma200 = SMA(ts, timeperiod=200)
ts['sma200'] = sma200

# %%
ts.tail()
# Out:
#               open    high     low   close  adj_close      volume   sma50  \
# date
# 2015-04-27 2119.29 2125.92 2107.04 2108.92    2108.92  3438750000 2090.08
# 2015-04-28 2108.35 2116.04 2094.89 2114.76    2114.76  3546270000 2090.43
# 2015-04-29 2112.49 2113.65 2097.41 2106.85    2106.85  4074970000 2090.56
# 2015-04-30 2105.52 2105.52 2077.59 2085.51    2085.51  4509680000 2090.28
# 2015-05-01 2087.38 2108.41 2087.38 2108.29    2108.29  3379390000 2090.49
#
#             sma200
# date
# 2015-04-27 2024.07
# 2015-04-28 2024.81
# 2015-04-29 2025.45
# 2015-04-30 2026.02
# 2015-05-01 2026.65

# %% [markdown]
# Plot closing price along with moving averages

# %%
fig = plt.figure()
axes = fig.add_subplot(111,  ylabel='Price in $')

ts['close'].plot(ax=axes, label='close', color='k')
ts['sma50'].plot(ax=axes, label='sma50', color='r')
ts['sma200'].plot(ax=axes, label='sma200', color='b')
plt.legend(loc='best')

# %% [markdown]
# Create Trade Log (tlog); Create Daily Balance (dbal)

# %%
tlog = pf.TradeLog()
dbal = pf.DailyBal()

# %% [markdown]
# Algo: Buy when 50 day ma crosses above 200 day ma.  Sell when 50 day ma crosses below 200 day ma.

# %%
cash = capital
shares = 0
start_flag = True

import time
t0 = time.time()


for i in range(len(ts.index)):

    date = ts.index[i]
    high = ts['high'][i]
    low = ts['low'][i]
    close = ts['close'][i]
    sma50 = ts['sma50'][i]
    sma200 = ts['sma200'][i]

    if pd.isnull(sma200) or ts.index[i] < start:
        continue
    elif start_flag:
        start_flag = False
        # set start and end
        start = ts.index[i]
        end = ts.index[-1]

    # buy
    if tlog.num_open_trades() == 0:
        if sma50 > sma200 and ts['sma50'][i-1] <= ts['sma200'][i-1]:

            # calculate shares to buy and remaining cash
            shares, cash = tlog.calc_shares(cash, close)

            # enter buy in trade log
            tlog.enter_trade(date, close, shares)
            print("{0} BUY  {1} {2} @ {3:.2f}".format(date, shares, symbol, close))

            # record daily balance
            dbal.append(date, high, low, close, shares, cash, pf.TradeState.OPEN)
        else:
            # hold
            dbal.append(date, high, low, close, shares, cash, pf.TradeState.HOLD)

    # sell
    elif (sma50 < sma200 and ts['sma50'][i-1] >= ts['sma200'][i-1]) or \
         (i == len(ts.index) - 1):

            # enter sell in trade log
            idx = tlog.exit_trade(date, close)
            shares = tlog.get_log()['qty'][idx]
            print("{0} SELL {1} {2} @ {3:.2f}".format(date, shares, symbol, close))

            # record daily balance
            dbal.append(date, high, low, close, shares, cash, pf.TradeState.CLOSE)   
            
            # update cash
            cash = tlog.calc_cash(cash, close, shares)
            
            # update shares
            shares = 0

    # hold
    else:
        dbal.append(date, high, low, close, shares, cash, pf.TradeState.HOLD)    

t1 = time.time()
total = t1-t0
print(total)
# Out:
# 2003-05-14 00:00:00 BUY  10 ^GSPC @ 939.28
# 2004-08-18 00:00:00 SELL 10 ^GSPC @ 1095.17
# 2004-11-05 00:00:00 BUY  9 ^GSPC @ 1166.17
# 2006-07-19 00:00:00 SELL 9 ^GSPC @ 1259.81
# 2006-09-12 00:00:00 BUY  9 ^GSPC @ 1313.00
# 2007-12-21 00:00:00 SELL 9 ^GSPC @ 1484.46
# 2009-06-23 00:00:00 BUY  15 ^GSPC @ 895.10
# 2010-07-02 00:00:00 SELL 15 ^GSPC @ 1022.58
# 2010-10-22 00:00:00 BUY  13 ^GSPC @ 1183.08
# 2011-08-12 00:00:00 SELL 13 ^GSPC @ 1178.81
# 2012-01-31 00:00:00 BUY  12 ^GSPC @ 1312.41
# 2015-05-01 00:00:00 SELL 12 ^GSPC @ 2108.29
# 2.95002388954

# %% [markdown]
# Retrieve log DataFrames

# %%
tlog = tlog.get_log()

# %%
tlog.tail(100)
# Out:
#   entry_date  entry_price long_short qty            exit_date  exit_price  \
# 0 2003-05-14       939.28       long  10  2004-08-18 00:00:00     1095.17
# 1 2004-11-05      1166.17       long   9  2006-07-19 00:00:00     1259.81
# 2 2006-09-12      1313.00       long   9  2007-12-21 00:00:00     1484.46
# 3 2009-06-23       895.10       long  15  2010-07-02 00:00:00     1022.58
# 4 2010-10-22      1183.08       long  13  2011-08-12 00:00:00     1178.81
# 5 2012-01-31      1312.41       long  12  2015-05-01 00:00:00     2108.29
#
#    pl_points  pl_cash  cumul_total
# 0     155.89  1558.90      1558.90
# 1      93.64   842.76      2401.66
# 2     171.46  1543.14      3944.80
# 3     127.48  1912.20      5857.00
# 4      -4.27   -55.51      5801.49
# 5     795.88  9550.56     15352.05

# %%
dbal = dbal.get_log()

# %%
dbal.tail()
# Out:
#                high      low    close  shares  cash  state
# date
# 2015-04-27 25563.61 25337.05 25359.61      12 52.57      1
# 2015-04-28 25445.05 25191.25 25429.69      12 52.57      1
# 2015-04-29 25416.37 25221.49 25334.77      12 52.57      1
# 2015-04-30 25318.81 24983.65 25078.69      12 52.57      1
# 2015-05-01 25353.49 25101.13 25352.05      12 52.57      2

# %% [markdown]
# Generate strategy stats - display all available stats

# %%
stats = pf.stats(ts, tlog, dbal, start, end, capital)
pf.print_full(stats)
# Out:
# start                                                   2000-01-03
# end                                                     2015-05-01
# beginning_balance                                            10000
# ending_balance                                            25352.05
# total_net_profit                                          15352.05
# gross_profit                                              15407.56
# gross_loss                                                  -55.51
# profit_factor                                               277.57
# return_on_initial_capital                                   153.52
# annual_return_rate                                            6.26
# trading_period                           15 years 3 months 28 days
# pct_time_in_market                                           61.00
# total_num_trades                                                 6
# num_winning_trades                                               5
# num_losing_trades                                                1
# num_even_trades                                                  0
# pct_profitable_trades                                        83.33
# avg_profit_per_trade                                       2558.68
# avg_profit_per_winning_trade                               3081.51
# avg_loss_per_losing_trade                                   -55.51
# ratio_avg_profit_win_loss                                    55.51
# largest_profit_winning_trade                               9550.56
# largest_loss_losing_trade                                   -55.51
# num_winning_points                                         1344.35
# num_losing_points                                            -4.27
# total_net_points                                           1340.08
# avg_points                                                  223.35
# largest_points_winning_trade                                795.88
# largest_points_losing_trade                                  -4.27
# avg_pct_gain_per_trade                                       18.70
# largest_pct_winning_trade                                    60.64
# largest_pct_losing_trade                                     -0.36
# max_consecutive_winning_trades                                   4
# max_consecutive_losing_trades                                    1
# avg_bars_winning_trades                                     429.60
# avg_bars_losing_trades                                      204.00
# max_closed_out_drawdown                                     -19.96
# max_closed_out_drawdown_start_date                      2010-04-23
# max_closed_out_drawdown_end_date                        2011-08-08
# max_closed_out_drawdown_recovery_date                   2013-03-14
# drawdown_recovery                                            -1.29
# drawdown_annualized_return                                   -3.19
# max_intra_day_drawdown                                      -21.36
# avg_yearly_closed_out_drawdown                               -6.40
# max_yearly_closed_out_drawdown                              -17.44
# avg_monthly_closed_out_drawdown                              -1.84
# max_monthly_closed_out_drawdown                             -16.32
# avg_weekly_closed_out_drawdown                               -0.73
# max_weekly_closed_out_drawdown                              -12.65
# avg_yearly_closed_out_runup                                  12.11
# max_yearly_closed_out_runup                                  37.01
# avg_monthly_closed_out_runup                                  2.27
# max_monthly_closed_out_runup                                 14.38
# avg_weekly_closed_out_runup                                   0.86
# max_weekly_closed_out_runup                                   6.74
# pct_profitable_years                                         63.32
# best_year                                                    34.66
# worst_year                                                  -13.09
# avg_year                                                      6.71
# annual_std                                                    8.85
# pct_profitable_months                                        42.54
# best_month                                                   14.38
# worst_month                                                 -14.75
# avg_month                                                     0.52
# monthly_std                                                   2.51
# pct_profitable_weeks                                         35.65
# best_week                                                     6.70
# worst_week                                                  -12.65
# avg_week                                                      0.13
# weekly_std                                                    1.38
# sharpe_ratio                                                  0.64
# sortino_ratio                                                 0.66
# dtype: object
# /home/farrell/src/pinkfish/pinkfish/statistics.py:240: FutureWarning: pd.expanding_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.expanding(min_periods=1).max()
#   running_max = pd.expanding_max(close)
# /home/farrell/src/pinkfish/pinkfish/statistics.py:264: FutureWarning: pd.expanding_max is deprecated for Series and will be removed in a future version, replace with
# 	Series.expanding(min_periods=1).max()
#   running_max = pd.expanding_max(high)

# %% [markdown]
# Run Benchmark

# %%
benchmark = pf.Benchmark(symbol, capital, start, end)
benchmark.run()
# Out:
# 2000-01-03 00:00:00 BUY  6 ^GSPC @ 1455.22
# 2015-05-01 00:00:00 SELL 6 ^GSPC @ 2108.29

# %% [markdown]
# Retrieve benchmark logs

# %%
benchmark.tlog, benchmark.dbal = benchmark.get_logs()

# %% [markdown]
# Generate benchmark stats

# %%
benchmark.stats = benchmark.stats()
pf.print_full(benchmark.stats)
# Out:
# start                                                   2000-01-03
# end                                                     2015-05-01
# beginning_balance                                            10000
# ending_balance                                            13918.42
# total_net_profit                                           3918.42
# gross_profit                                               3918.42
# gross_loss                                                    0.00
# profit_factor                                                 1000
# return_on_initial_capital                                    39.18
# annual_return_rate                                            2.18
# trading_period                           15 years 3 months 28 days
# pct_time_in_market                                          100.00
# total_num_trades                                                 1
# num_winning_trades                                               1
# num_losing_trades                                                0
# num_even_trades                                                  0
# pct_profitable_trades                                       100.00
# avg_profit_per_trade                                       3918.42
# avg_profit_per_winning_trade                               3918.42
# avg_loss_per_losing_trade                                        0
# ratio_avg_profit_win_loss                                     1000
# largest_profit_winning_trade                               3918.42
# largest_loss_losing_trade                                        0
# num_winning_points                                          653.07
# num_losing_points                                                0
# total_net_points                                            653.07
# avg_points                                                  653.07
# largest_points_winning_trade                                653.07
# largest_points_losing_trade                                      0
# avg_pct_gain_per_trade                                       44.88
# largest_pct_winning_trade                                    44.88
# largest_pct_losing_trade                                         0
# max_consecutive_winning_trades                                   1
# max_consecutive_losing_trades                                    0
# avg_bars_winning_trades                                    3856.00
# avg_bars_losing_trades                                           0
# max_closed_out_drawdown                                     -50.02
# max_closed_out_drawdown_start_date                      2007-10-09
# max_closed_out_drawdown_end_date                        2009-03-09
# max_closed_out_drawdown_recovery_date                   2013-03-28
# drawdown_recovery                                            -1.42
# drawdown_annualized_return                                  -22.93
# max_intra_day_drawdown                                      -50.87
# avg_yearly_closed_out_drawdown                              -14.14
# max_yearly_closed_out_drawdown                              -45.79
# avg_monthly_closed_out_drawdown                              -3.78
# max_monthly_closed_out_drawdown                             -24.27
# avg_weekly_closed_out_drawdown                               -1.54
# max_weekly_closed_out_drawdown                              -15.41
# avg_yearly_closed_out_runup                                  18.81
# max_yearly_closed_out_runup                                  53.35
# avg_monthly_closed_out_runup                                  4.13
# max_monthly_closed_out_runup                                 18.69
# avg_weekly_closed_out_runup                                   1.63
# max_weekly_closed_out_runup                                  14.92
# pct_profitable_years                                         69.76
# best_year                                                    52.24
# worst_year                                                  -42.14
# avg_year                                                      3.42
# annual_std                                                   15.48
# pct_profitable_months                                        59.93
# best_month                                                   17.90
# worst_month                                                 -24.09
# avg_month                                                     0.26
# monthly_std                                                   3.99
# pct_profitable_weeks                                         54.82
# best_week                                                    14.92
# worst_week                                                  -15.41
# avg_week                                                      0.07
# weekly_std                                                    2.15
# sharpe_ratio                                                  0.21
# sortino_ratio                                                 0.28
# dtype: object

# %% [markdown]
# Equity curve

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Plot Trades

# %%
pf.plot_trades(dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
metrics = ('annual_return_rate',
           'max_closed_out_drawdown',
           'drawdown_annualized_return',
           'drawdown_recovery',
           'best_month',
           'worst_month',
           'sharpe_ratio',
           'sortino_ratio',
           'monthly_std')
df = pf.plot_bar_graph(stats, benchmark.stats, *metrics)
df
# Out:
#                             strategy  benchmark
# annual_return_rate              6.26       2.18
# max_closed_out_drawdown       -19.96     -50.02
# drawdown_annualized_return     -3.19     -22.93
# drawdown_recovery              -1.29      -1.42
# best_month                     14.38      17.90
# worst_month                   -14.75     -24.09
# sharpe_ratio                    0.64       0.21
# sortino_ratio                   0.66       0.28
# monthly_std                     2.51       3.99
